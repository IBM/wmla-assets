# %% [markdown]
# # HyperParameter Tuning with Elastic Distributed Training example notebook for WMLA
#
# This is a sample notebook showing how to use the "Bring Your Own Framework" API of WMLA to tune community PyTorch
# Vision model with HyperParameter Optimization and Elastic Distributed Training of Watson ML Accelerator.
#
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
#
# This example uses a Elastic Distributed instance group.
#
# [Kelvin Lui](https://w3.ibm.com/search/#/search?query=Kelvin%20lui)
#
#
# BYOF creates execution tasks via API - this is the equivalent of running this command via the `dlicmd` command locally on the cluster. Details of the `dlicmd` command can be found in [dlicmd.py reference](https://www.ibm.com/support/knowledgecenter/en/SSFHA8_1.2.1/cm/dlicmd.html) in Knowledge Centre.
#
# Note: this setup assumes that models can access data sources local to the WMLA cluster - although this data could be downloaded during the model training phase.

# %% [markdown]
# ## Contents:
# <a id='WMLA-HPO-Hyperband-Wells-EDT'></a>
# - [Log on](#Log-on)
# - [Health Check](#Health-Check)
# - [Update Model](#Update-model)
# - [Launch HPO Task](#Launch-HPO-Task)
# - [Check HPO Status](#Check-HPO-Status)
# - [Manage HPO tasks](#Manage-HPO-Task)

# %% [markdown]
# ### Common Setup

# %% [markdown]
# For WMLA cluster, URLs required are:
# ```
# $ egosh client view ASCD_REST_BASE_URL_1 | grep DESCRIPTION | cut -d' ' -f2
# http://hostname.local:8280/platform/rest/
# ```
# Giving: http://hostname.local:8280/platform/rest/conductor/v1
#
# ```
# $ egosh client view DLPD_REST_BASE_URL_1 | grep DESCRIPTION | cut -d' ' -f2
# http://hostname.local:9243/platform/rest/
# ```
# Giving: http://hostname.local:9243/platform/rest/deeplearning/v1
#
# API documentation links (can also be found on both links above):
#
# - IBM Spectrum Conductor RESTful APIs: http://hostname.local:8280/cloud/apis/explorer/
# - IBM Spectrum Conductor Deep Learning Impact RESTful APIs: http://hostname.local:9243/cloud/apis/explorer/
# - Also further details on Knowledge Centre: https://www.ibm.com/support/knowledgecenter/en/SSWQ2D_1.2.1/cm/deeplearning.html

# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

import json
import time
import urllib
import pandas as pd

# %%
# Environment details:

master_host = '**** ADD HERE ****'
dli_rest_port = '**** ADD HERE ****' #'9280'
sc_rest_port = '**** ADD HERE ****' #'8280'
protocol = 'http'

sc_rest_url =  protocol+'://'+master_host+':'+sc_rest_port+'/platform/rest/conductor/v1'
dl_rest_url = protocol+'://'+master_host+':'+dli_rest_port+'/platform/rest/deeplearning/v1'

print (sc_rest_url)
print (dl_rest_url)

# User login details
wmla_user = '**** ADD HERE ****'
wmla_pwd = '**** ADD HERE ****'


myauth = (wmla_user, wmla_pwd)

# Spark instance group details
sig_name = '**** ADD HERE ****'


# REST call variables
commonHeaders = {'Accept': 'application/json'}


#startTuneUrl='%s://%s:%s/platform/rest/deeplearning/v1/hypersearch' % (protocol, master_host, dli_rest_port)
#sc_rest_url ='%s://%s:%d/platform/rest/conductor/v1' % (protocol, hostname, conductorport)

req = requests.Session()
# Out:
# http://colonia04.platform:8280/platform/rest/conductor/v1
# http://colonia04.platform:9280/platform/rest/deeplearning/v1

# %% [markdown]
# ## Log On
# <a id='Log-on'></a>
#
# [back to top](#WMLA-HPO-Hyperband-Wells-EDT)
#
# Obtain login session tokens to be used for session authentication within the RESTful API. Tokens are valid for 8 hours.

# %%
r = requests.get(sc_rest_url+'/auth/logon', verify=False, auth=myauth, headers=commonHeaders) 

if r.ok:
    print ('\nLogon succeeded')
    
else: 
    print('\nLogon failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Logon succeeded

# %% [markdown]
# ### Health Check
# [back to top](#WMLA-HPO-Hyperband-Wells-EDT)

# %% [markdown]
# Check if there is any existing hpo tasks and also verify the platform health

# %% [markdown]
# Rest API: **GET platform/rest/deeplearning/v1/hypersearch**
# - Description: Get all the hpo task that the login user can access.
# - OUTPUT: A list of hpo tasks and each one with the same format which can be found in the api doc.

# %%
getTuneStatusUrl = dl_rest_url + '/hypersearch'
print ('getTuneStatusUrl: %s' %getTuneStatusUrl)
r = req.get(getTuneStatusUrl, headers=commonHeaders, verify=False, auth=myauth)

if not r.ok:
    print('check hpo task status failed: code=%s, %s'%(r.status_code, r.content))
else:
    if len(r.json()) == 0:
        print('There is no hpo task been created')
    for item in r.json():
        print('Hpo task: %s, State: %s'%(item['hpoName'], item['state']))
        #print('Best:%s'%json.dumps(item.get('best'), sort_keys=True, indent=4))
# Out:
# getTuneStatusUrl: http://colonia04.platform:9280/platform/rest/deeplearning/v1/hypersearch
# Hpo task: Admin-hpo-865764150117434, State: FAILED
# Hpo task: Admin-hpo-1101261874485516, State: FAILED
# Hpo task: Admin-hpo-3651752950675102, State: FAILED
# Hpo task: Admin-hpo-3651791970264588, State: FAILED
# Hpo task: Admin-hpo-3652656031423039, State: FAILED
# Hpo task: Admin-hpo-3652848133085365, State: FAILED
# Hpo task: Admin-hpo-4402508485777365, State: RECOVERPEND
# Hpo task: Admin-hpo-4404453847231966, State: FINISHED
# Hpo task: Admin-hpo-4405121817174855, State: RECOVERPEND
# Hpo task: Admin-hpo-17975643951593, State: FAILED
# Hpo task: Admin-hpo-18176491357360, State: FAILED
# Hpo task: Admin-hpo-26662761022292, State: FAILED
# Hpo task: Admin-hpo-29763538447983, State: FAILED
# Hpo task: Admin-hpo-41642042184978, State: FAILED
# Hpo task: Admin-hpo-42385955978459, State: FINISHED
# Hpo task: Admin-hpo-45405500448823, State: FINISHED
# Hpo task: Admin-hpo-45723267117425, State: FINISHED
# Hpo task: Admin-hpo-46153013776230, State: FINISHED
# Hpo task: Admin-hpo-63180378205900, State: FINISHED
# Hpo task: Admin-hpo-67304712365680, State: FINISHED
# Hpo task: Admin-hpo-69265660731839, State: FINISHED
# Hpo task: Admin-hpo-81103168190973, State: FAILED
# Hpo task: Admin-hpo-83966261958354, State: FINISHED
# Hpo task: Admin-hpo-87038657810309, State: FAILED
# Hpo task: Admin-hpo-87482324743298, State: FAILED
# Hpo task: Admin-hpo-88012895662112, State: FINISHED
# Hpo task: Admin-hpo-389761848418821, State: FINISHED
# Hpo task: Admin-hpo-446861797606487, State: FINISHED
# Hpo task: Admin-hpo-470996705325006, State: FINISHED
# Hpo task: Admin-hpo-557106790244503, State: FAILED
# Hpo task: Admin-hpo-557386867420795, State: FINISHED
# Hpo task: Admin-hpo-559169605924197, State: FINISHED
# Hpo task: Admin-hpo-606424273611363, State: FINISHED
# Hpo task: Admin-hpo-606677097588552, State: FINISHED
# Hpo task: Admin-hpo-607368853527081, State: FINISHED
# Hpo task: Admin-hpo-608844830397827, State: FINISHED
# Hpo task: Admin-hpo-609194284938035, State: FINISHED
# Hpo task: Admin-hpo-609556557992080, State: FINISHED
# Hpo task: Admin-hpo-617791427561063, State: FINISHED
# Hpo task: Admin-hpo-618444097370237, State: FINISHED
# Hpo task: Admin-hpo-1161366121811487, State: FAILED
# Hpo task: Admin-hpo-1161798424168716, State: FAILED
# Hpo task: Admin-hpo-1167963322865448, State: FAILED
# Hpo task: Admin-hpo-1168189178261145, State: FINISHED
# Hpo task: Admin-hpo-1168517132139967, State: FINISHED
# Hpo task: Admin-hpo-1169021314895654, State: FINISHED
# Hpo task: Admin-hpo-1566215048207446, State: FINISHED
# Hpo task: Admin-hpo-1566338679263207, State: FINISHED
# Hpo task: Admin-hpo-1566523649870405, State: FINISHED
# Hpo task: Admin-hpo-1566781334871123, State: FINISHED
# Hpo task: Admin-hpo-1567145515152659, State: FINISHED
# Hpo task: Admin-hpo-1567334554890746, State: FINISHED
# Hpo task: Admin-hpo-1568532179824168, State: FINISHED
# Hpo task: Admin-hpo-1569330129356702, State: FINISHED
# Hpo task: Admin-hpo-1898512439712804, State: FAILED
# Hpo task: Admin-hpo-1900263284000323, State: FAILED
# Hpo task: Admin-hpo-1900335486254509, State: FAILED
# Hpo task: Admin-hpo-1900656823910456, State: FINISHED
# Hpo task: Admin-hpo-1901456134303343, State: FINISHED
# Hpo task: Admin-hpo-1903573948892416, State: FINISHED
# Hpo task: Admin-hpo-2146582700656527, State: FINISHED
# Hpo task: Admin-hpo-2146591994601826, State: FINISHED
# Hpo task: Admin-hpo-2146649597597590, State: FINISHED
# Hpo task: Admin-hpo-2153130229843508, State: FAILED
# Hpo task: Admin-hpo-2153558909501098, State: FAILED
# Hpo task: Admin-hpo-2153687660264341, State: FAILED
# Hpo task: Admin-hpo-2153961023309354, State: FAILED
# Hpo task: Admin-hpo-2154886461231315, State: FINISHED
# Hpo task: Admin-hpo-2156650551587127, State: FINISHED
# Hpo task: Admin-hpo-2158842191013843, State: FAILED
# Hpo task: Admin-hpo-2159662713931510, State: FAILED
# Hpo task: Admin-hpo-2159835421481356, State: FINISHED
# Hpo task: Admin-hpo-2160984232559120, State: FINISHED
# Hpo task: Admin-hpo-2163398104247968, State: FINISHED
# Hpo task: Admin-hpo-2234900686966786, State: FINISHED
# Hpo task: Admin-hpo-2239018333806010, State: FINISHED
# Hpo task: Admin-hpo-2242935737224386, State: FINISHED
# Hpo task: Admin-hpo-2307649793377906, State: FINISHED
# Hpo task: Admin-hpo-2307674584046913, State: FINISHED
# Hpo task: Admin-hpo-2790563413573252, State: FINISHED
# Hpo task: Admin-hpo-2791372015805076, State: FAILED
# Hpo task: Admin-hpo-2791559858612346, State: FINISHED
# Hpo task: Admin-hpo-2805125680235872, State: FINISHED
# Hpo task: Admin-hpo-40894637677181, State: FINISHED
# Hpo task: Admin-hpo-41486071064170, State: FINISHED
# Hpo task: Admin-hpo-42306620676909, State: FINISHED
# Hpo task: Admin-hpo-43989551935312, State: FAILED
# Hpo task: Admin-hpo-64737517805674, State: FAILED
# Hpo task: Admin-hpo-121935856803278, State: FINISHED
# Hpo task: Admin-hpo-738373071509316, State: FAILED
# Hpo task: Admin-hpo-738739774847379, State: FAILED
# Hpo task: Admin-hpo-738930529288227, State: FAILED
# Hpo task: Admin-hpo-739278498851266, State: FAILED
# Hpo task: Admin-hpo-739423876295559, State: FAILED
# Hpo task: Admin-hpo-739906264563547, State: FAILED
# Hpo task: Admin-hpo-740054011079503, State: FAILED
# Hpo task: Admin-hpo-740363184609365, State: FAILED
# Hpo task: Admin-hpo-740781608704470, State: FAILED
# Hpo task: Admin-hpo-741133495482657, State: FAILED
# Hpo task: Admin-hpo-741412551610451, State: FINISHED
# Hpo task: Admin-hpo-741903729361931, State: FAILED
# Hpo task: Admin-hpo-742227038621024, State: FAILED
# Hpo task: Admin-hpo-742299703652403, State: FINISHED
# Hpo task: Admin-hpo-742368331242798, State: FINISHED
# Hpo task: Admin-hpo-754810816615675, State: FINISHED
# Hpo task: Admin-hpo-755496000997484, State: FAILED
# Hpo task: Admin-hpo-755574084707714, State: FAILED
# Hpo task: Admin-hpo-755680135155285, State: FAILED
# Hpo task: Admin-hpo-758371806102875, State: FINISHED
# Hpo task: Admin-hpo-821939808891847, State: FINISHED
# Hpo task: Admin-hpo-116316534499867, State: FAILED
# Hpo task: Admin-hpo-116521512935854, State: FAILED
# Hpo task: Admin-hpo-117404793807015, State: FAILED
# Hpo task: Admin-hpo-124800747212736, State: FINISHED
# Hpo task: Admin-hpo-124954893644731, State: RECOVERPEND
# Hpo task: Admin-hpo-128724212896952, State: FINISHED
# Hpo task: Admin-hpo-131842408409190, State: FAILED
# Hpo task: Admin-hpo-214057387623548, State: FAILED
# Hpo task: Admin-hpo-214334662281022, State: FINISHED
# Hpo task: Admin-hpo-214707651328489, State: FINISHED
# Hpo task: Admin-hpo-215275905995267, State: FINISHED
# Hpo task: Admin-hpo-215983651795270, State: FINISHED
# Hpo task: Admin-hpo-280613752667465, State: FINISHED
# Hpo task: Admin-hpo-281460162456310, State: FINISHED
# Hpo task: Admin-hpo-578445117275847, State: FAILED
# Hpo task: Admin-hpo-578716216772159, State: FINISHED
# Hpo task: Admin-hpo-584914877877339, State: FINISHED

# %% [markdown]
# ## Update Model
# [back to top](#WMLA-HPO-Hyperband-Wells-EDT)
#
# We will update the model to enable:
#  * Elastic Distributed Training
#  * Hyper-parameter Optimization

# %% [markdown]
# ###  Model file update to run Elastic Distributed Training
#
# Elastic Distributed Training (EDT) takes a model built on a standalone system,  and distributes model training across multiple GPUs and compute nodes in elastic fashion.   EDT starts job execution with minimal 1 GPU,  and GPUs can be added or removed dynamically while executing.
#
# We will use Elastic Distributed Training to distribute a single HPO task with multiple gpus.
#
#
# In this sample we will update the PyTorch RestNet18 model and enable Elastic Distributed Training: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
#
# Model changes required from 3 perspective:
# * Import Elastic Distributed Training library and environment variable
# * Replace the data loading functions with ones that are compatible with EDT - the data loading function must return a tuple containing two items of type torch.utils.data.Dataset
# * Replace the training and testing loops with EDT’s train function
#
#
# ##### Model update part 1.  Import Elastic Distributed Training library and environment variable
#
# <pre>
# path=os.path.join(os.getenv("FABRIC_HOME"), "libs", "fabric.zip")
# print(path)
# sys.path.insert(0,path)
# from fabric_model import FabricModel
# from edtcallback import EDTLoggerCallback
#
# dataDir = environ.get("DATA_DIR")
# if dataDir is not None:
#     print("dataDir is: %s"%dataDir)
# else:
#     print("Warning: not found DATA_DIR from os env!")
# </pre>
#
#
#
# ##### Model update part 2.  Replace the data loading functions with ones that are compatible with EDT - the data loading function must return a tuple containing two items of type torch.utils.data.Dataset
#
# * Download the Dataset from https://download.pytorch.org/tutorial/hymenoptera_data.zip
#
# <pre>
# def getDatasets():
#
#     data_transforms = {
#     'train': transforms.Compose([
#         transforms.RandomResizedCrop(224),
#        transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#     ]),
#     'val': transforms.Compose([
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#     ]),
#     }
#
#     return (datasets.ImageFolder(os.path.join(dataDir, 'train'), data_transforms['train']),
#            datasets.ImageFolder(os.path.join(dataDir, 'val'), data_transforms['val']))
# </pre>
#
# ##### Model update part 3.  Replace the training and testing loops with EDT’s train function
#
#  a. Instantiate Elastic Distributed Training instance
#  <pre>
#  edt_m = FabricModel(model, getDatasets, loss_function, optimizer, driver_logger=EDTLoggerCallback())
#  </pre>
#  b. Launch EDT job with specific parameters
#  <pre>
#  edt_m.train(epoch_number, effective_batch_size, max_number_GPUs_assigned_to_EDT_job)
#  </pre>

# %% [markdown]
# ### Model file update to Run HPO
#
# Model changes required from 2 perspective:
# - Inject hyper-parameters for the sub-training during search
# - Retrieve sub-training result metric

# %% [markdown]
# ##### Model update part 1 - Inject hyper-parameters

# %% [markdown]
# The hyper-parameters will be supplied in a file called **config.json** with JSON format,located in the current working directory and can be read direcly as the following example snippet.
#
# <pre>
# hyper_params = json.loads(open("<b>config.json</b>").read())
# learning_rate = float(hyper_params.get("<b>learning_rate</b>", "0.01"))
# </pre>
#
# After this, you can use these hyper-parameters during the model trainings. The **hyper-parameter name** and **value** type is defined through the search space part in body of REST call when launching a new hpo task.

# %% [markdown]
# ##### Model update part 2 - Retrieve sub-training result metric

# %% [markdown]
# At the end of your training run, your code will need to create a file called **val_dict_list.json** with test metrics generated during training. These metrics will be used by the search algorithm to propose new sets of hyper-parameters. Please note that **val_dict_list.json** should be created under the result directory which can be retrieved through the environment variable **RESULT_DIR**.
#
# <pre>
# with open('{}/val_dict_list.json'.format(os.environ['<b>RESULT_DIR</b>']), 'w') as f:
#     json.dump(test_metrics, f)
# </pre>
#
# We add this code in the function def on_train_end(self) defined in edtcallback.py
#
# The content of **val_dict_list.json** will be some thing as below, **step** is some thing optional meaning the training iteration or epochs, one of **loss** and **accuracy** can be the name of target metric to optimize, at least one metric need to be included here. The specific name of metric used to optimize (minimize or maximize) is defined in the body of REST call when launching a new hpo task.
#
# ```
# [
# {‘step’: 1, ‘loss’:0.2487, ‘accuracy’: 0.4523},
# {‘step’: 2, ‘loss’:0.1487, ‘accuracy’: 0.5523},
# {‘step’: 3, ‘loss’:0.1087, ‘accuracy’: 0.6523},
# …
# ]
# ```

# %% [markdown]
# ## Launch HPO task

# %% [markdown]
# REST API: **POST /platform/rest/deeplearning/v1/hypersearch**
# - Description: Start a new HPO task
# - Content-type: Multi-Form
# - Multi-Form Data:
#   - files: Model files tar package, ending with `.modelDir.tar`
#   - form-filed: {‘data’: ‘String format of input parameters to start hpo task, let’s call it as **hpo_input** and show its specification later’}

# %% [markdown]
# ##### Package model files for training

# %% [markdown]
# Package the updated model files into a tar file ending with `.modelDir.tar`

# %%
import tarfile
import tempfile
import os
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))
MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
make_tarfile(tempFile, '/Users/Kelvin/Downloads/WellsFargo/CSSC_EDT/pytorch_edt_cssc')
files = {'file': open(tempFile, 'rb')}

# %% [markdown]
# ##### Construct POST request data

# %% [markdown]
# **hpo_input** will be a Python dict or json format as below, convert to string when calling REST.

# %%
#'args': '--exec-start edtPyTorch --cs-datastore-meta type=fs, data_path=/dli_data_fs \
#                     --gpuPerWorker 1 --model-main pytorch_mnist.py --edt-options maxWorkers=8 \
#                     --model-dir pytorch_edt_hpo'

data =  {
        'modelSpec': # Define the model training related parameters
        {
            # Spark instance group which will be used to run the HPO sub-trainings. The Spark instance group selected
            # here should match the sub-training args, for example, if the sub-training args try to run a EDT job,
            # then we should put a Spark instance group with capability to run EDT job here.
            'sigName': sigName,

            # These are the arguments we'll pass to the execution engine; they follow the same conventions
            # of the dlicmd.py command line launcher
            #
            # See:
            #   https://www.ibm.com/support/knowledgecenter/en/SSFHA8_1.2.1/cm/dlicmd.html
            # In this example, args after --model-dir are all the required parameter for the original model itself.
            # maxWorker is the number of GPUs assigned to single HPO task
            # 
            'args': '--model-dir pytorch_edt_cssc --exec-start edtPyTorch  \
                     --cs-datastore-meta type=fs,data_path=hymenopteradata --gpuPerWorker 1 \
                     --edt-options maxWorkers=2 --model-main pytorch_mnist_HPO_EDT.py \
                     --batchsize 16 --debug-level debug  \
                    '

        },    
        'algoDef': # Define the parameters for search algorithms
        {
            # Name of the search algorithm, one of Random, Bayesian, Tpe, Hyperband
            'algorithm': 'Hyperband', 
            # Max running time of the hpo task in minutes, -1 means unlimited
            'maxRunTime': -1,  
            # Max number of training job to submitted for hpo task, -1 means unlimited’,
            'maxJobNum': 121,            
            # Max number of training job to run in parallel, default 1. It depends on both the
            # avaiable resource and if the search algorithm support to run in parallel, current only Random
            # fully supports to run in parallel, Hyperband and Tpe supports to to in parellel in some phase,
            # Bayesian runs in sequence now.
            'maxParalleJobNum': 2, 
            # Name of the target metric that we are trying to optimize when searching hyper-parameters.
            # It is the same metric name that the model update part 2 trying to dump.
            'objectiveMetric' : 'loss',
            # Strategy as how to optimize the hyper-parameters, minimize means to find better hyper-parameters to
            # make the above objectiveMetric as small as possible, maximize means the opposite.
            'objective' : 'minimize',
            # eta value to control the hyper-band search process
            'hyperbandEta': 3.0,
            #Additional parameters for the specified search algorithm and hyper-band get following too.
            'algoParams' : 
                [
                    {
                        # Name of the the maximum amount of resource that can be allocated to a single configuration
                        'name':'ResourceName', 
                        'value': 'epochs'
                    },
                    {
                        # Value of the the maximum amount of resource that can be allocated to a single configuration
                        'name':'ResourceValue',
                        'value':'81'
                    }
                    # This resource parameter will change during hyperband searching phase and its value will be put
                    # into the config.json for each sub-training too, here with the 'epoch' as key and value in the
                    # range 1-10.
                ]
        },
    
        # Define the hyper-paremeters to search and the corresponding search space.
        'hyperParams':
        [
             {
                 # Hyperparameter name, which will be the hyper-parameter key in config.json
                 'name': 'learning_rate',
                 # One of Range, Discrete
                 'type': 'Range',
                 # one of int, double, str
                 'dataType': 'DOUBLE',
                 # lower bound and upper bound when type=range and dataType=double
                 'minDbVal': 0.001,
                 'maxDbVal': 0.1,
                 # lower bound and upper bound when type=range and dataType=int
                 'minIntVal': 0,
                 'maxIntVal': 0,
                 # Discrete value list when type=discrete
                 'discreteDbVal': [],
                 'discreteIntVal': [],
                 'discreateStrVal': [],
                 #step size to split the Range space. ONLY valid when type is Range
                 'step': '0.002',
             }
         ]
    }
mydata={'data':json.dumps(data)}

# %% [markdown]
# ##### Submit the Post request

# %% [markdown]
# Submit hpo task through the Post call and a hpo name/id as string format will get back.

# %%
startTuneUrl=dl_rest_url + '/hypersearch'
r = req.post(startTuneUrl, headers=commonHeaders, data=mydata, files=files, verify=False, auth=myauth)
if r.ok:
    hpoName = r.json()
    json_out_1 = r.json()
    print ('HPO Application: %s' %json_out_1)

else: 
    print('\nModel submission failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# HPO Application: Admin-hpo-584914877877339

# %% [markdown]
# ## Check HPO task status

# %% [markdown]
# REST API: **GET /platform/rest/deeplearning/v1/hypersearch/{hponame}**
# - Description: Retrieve the hpo task details with the specified hpo task name/id in URL.
# - OUTPUT: A particular hpo task with details of the specified hponame

# %%
import time

getHpoUrl = dl_rest_url +'/hypersearch/'+ hpoName

res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=('Admin', 'Admin'))
if not res.ok:
    print('get hpo task failed: code=%s, %s'%(res.status_code, res.content))
else:
    json_out=res.json()

    while json_out['state'] in ['RUNNING']:
        print('Hpo task %s state %s progress %s%%'%(hpoName, json_out['state'], json_out['progress']))
        time.sleep(60)
        res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=myauth)
        json_out=res.json()

    print('Hpo task %s completes with state %s'%(hpoName, json_out['state']))
    print(json.dumps(json_out, indent=4, sort_keys=True))
# Out:
# Hpo task Admin-hpo-584914877877339 completes with state FINISHED
# {
#     "best": {
#         "appId": "Admin-589646909629184-1272803389",
#         "driverId": "driver-20200127070751-0242-15067803-3314-4bb0-b7ef-2801a3ad9ffe",
#         "endTime": "2020-01-27 07:13:00",
#         "hyperParams": [
#             {
#                 "dataType": "double",
#                 "fixedVal": "0.095",
#                 "name": "learning_rate",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "str",
#                 "fixedVal": "1",
#                 "name": "epochs",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "str",
#                 "fixedVal": "3",
#                 "name": "epochs",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "str",
#                 "fixedVal": "9",
#                 "name": "epochs",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "str",
#                 "fixedVal": "27",
#                 "name": "epochs",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "str",
#                 "fixedVal": "81",
#                 "name": "epochs",
#                 "userDefined": false
#             }
#         ],
#         "id": 120,
#         "maxiteration": 0,
#         "metricVal": -30419.58203125,
#         "startTime": "2020-01-27 07:07:51",
#         "state": "FINISHED"
#     },
#     "complete": 121,
#     "createtime": "2020-01-27 05:48:58",
#     "creator": "Admin",
#     "duration": "01:24:02",
#     "experiments": [
#         {
#             "appId": "Admin-584915749976667-1449800410",
#             "driverId": "driver-20200127054900-0122-5dda5de4-bddf-40e1-b22f-cabaa03d2a4d",
#             "endTime": "2020-01-27 05:50:13",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.029",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 0,
#             "maxiteration": 0,
#             "metricVal": -33.44986343383789,
#             "startTime": "2020-01-27 05:49:00",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-584921779943562-893901806",
#             "driverId": "driver-20200127054906-0123-7385edcb-1314-4290-8be9-9b734b64eaa6",
#             "endTime": "2020-01-27 05:50:13",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.019",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 1,
#             "maxiteration": 0,
#             "metricVal": -8.758189010620118,
#             "startTime": "2020-01-27 05:49:06",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-584990512920889-303791236",
#             "driverId": "driver-20200127055015-0124-475340c1-7b9c-40f9-92c0-43cd8ab90876",
#             "endTime": "2020-01-27 05:51:28",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.037",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 2,
#             "maxiteration": 0,
#             "metricVal": -17.32741012573242,
#             "startTime": "2020-01-27 05:50:15",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-584996546722551-1747982201",
#             "driverId": "driver-20200127055021-0125-e5abd239-4511-4d46-bcce-10a4d7b3f332",
#             "endTime": "2020-01-27 05:51:27",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.009",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 3,
#             "maxiteration": 0,
#             "metricVal": -4.0624229431152346,
#             "startTime": "2020-01-27 05:50:21",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585064799683104-1213262250",
#             "driverId": "driver-20200127055129-0126-9f9b4d61-1a1b-47fd-9373-3a836b370a44",
#             "endTime": "2020-01-27 05:52:43",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.021",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 4,
#             "maxiteration": 0,
#             "metricVal": -9.704300689697266,
#             "startTime": "2020-01-27 05:51:29",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585070789594039-1953140455",
#             "driverId": "driver-20200127055135-0127-6170b78e-e718-4f5e-95d5-c9a4ea3257b2",
#             "endTime": "2020-01-27 05:52:42",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.041",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 5,
#             "maxiteration": 0,
#             "metricVal": -48.56553268432617,
#             "startTime": "2020-01-27 05:51:35",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585139860980397-205119041",
#             "driverId": "driver-20200127055244-0128-a9d4dca1-1fec-4e8c-a7a3-f0ac7d41b4e3",
#             "endTime": "2020-01-27 05:53:57",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.073",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 6,
#             "maxiteration": 0,
#             "metricVal": -33.99801788330078,
#             "startTime": "2020-01-27 05:52:44",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585145930251668-1133939150",
#             "driverId": "driver-20200127055250-0129-bb5fbece-211d-48b1-a106-cdad5b940543",
#             "endTime": "2020-01-27 05:53:57",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.077",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 7,
#             "maxiteration": 0,
#             "metricVal": -35.47801666259765,
#             "startTime": "2020-01-27 05:52:50",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585214300401627-253988504",
#             "driverId": "driver-20200127055359-0130-5ddd58fb-97ce-4019-87a3-c871f48a8ef3",
#             "endTime": "2020-01-27 05:55:11",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.003",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 8,
#             "maxiteration": 0,
#             "metricVal": -3.3527066707611084,
#             "startTime": "2020-01-27 05:53:59",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585220470228086-1153671365",
#             "driverId": "driver-20200127055405-0131-6e528a65-0650-4705-b58d-441030ba7e13",
#             "endTime": "2020-01-27 05:55:12",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.037",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 9,
#             "maxiteration": 0,
#             "metricVal": -42.97467803955078,
#             "startTime": "2020-01-27 05:54:05",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585289150271607-1136395923",
#             "driverId": "driver-20200127055513-0132-f615e8d5-3e0c-4269-bc5d-a57a84846c2d",
#             "endTime": "2020-01-27 05:56:27",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 10,
#             "maxiteration": 0,
#             "metricVal": -107.14070129394531,
#             "startTime": "2020-01-27 05:55:14",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585295220284310-2011716448",
#             "driverId": "driver-20200127055520-0133-516773eb-d542-4e27-b6df-935867034a03",
#             "endTime": "2020-01-27 05:56:26",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.021",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 11,
#             "maxiteration": 0,
#             "metricVal": -9.427920913696289,
#             "startTime": "2020-01-27 05:55:20",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585363829720441-1467366926",
#             "driverId": "driver-20200127055628-0134-6c11cc2c-b2af-49a5-a5f2-5534f298d9b1",
#             "endTime": "2020-01-27 05:57:41",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.079",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 12,
#             "maxiteration": 0,
#             "metricVal": -94.17361450195312,
#             "startTime": "2020-01-27 05:56:28",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585369970425145-251330267",
#             "driverId": "driver-20200127055634-0135-a02866a0-678b-42d1-aa8a-c3dbb63a8d32",
#             "endTime": "2020-01-27 05:57:41",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.099",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 13,
#             "maxiteration": 0,
#             "metricVal": -43.8145248413086,
#             "startTime": "2020-01-27 05:56:35",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585438589800386-1446017836",
#             "driverId": "driver-20200127055743-0136-de3ca6c3-b486-4d91-a6a3-1adf1da8dc07",
#             "endTime": "2020-01-27 05:58:55",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.017",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 14,
#             "maxiteration": 0,
#             "metricVal": -19.604755401611328,
#             "startTime": "2020-01-27 05:57:43",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585444703916490-350671365",
#             "driverId": "driver-20200127055749-0137-46dd54ce-ed68-4c18-b794-d495bb0a69c2",
#             "endTime": "2020-01-27 05:58:56",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.009",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 15,
#             "maxiteration": 0,
#             "metricVal": -4.108378219604492,
#             "startTime": "2020-01-27 05:57:49",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585513232657735-432510042",
#             "driverId": "driver-20200127055858-0138-4fa0b1c6-099a-471f-8768-79dc0b6b6dcd",
#             "endTime": "2020-01-27 06:00:11",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.075",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 16,
#             "maxiteration": 0,
#             "metricVal": -87.58419799804688,
#             "startTime": "2020-01-27 05:58:58",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585519340117649-1987208647",
#             "driverId": "driver-20200127055904-0139-e3f60c50-b1cf-4887-af2c-2b48ae8ce042",
#             "endTime": "2020-01-27 06:00:10",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.099",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 17,
#             "maxiteration": 0,
#             "metricVal": -111.2845458984375,
#             "startTime": "2020-01-27 05:59:04",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585587850012476-1035938300",
#             "driverId": "driver-20200127060012-0140-04ae7291-76ac-4b07-810f-4d47ed763825",
#             "endTime": "2020-01-27 06:01:25",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.085",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 18,
#             "maxiteration": 0,
#             "metricVal": -104.86073303222656,
#             "startTime": "2020-01-27 06:00:12",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585594024447888-144592145",
#             "driverId": "driver-20200127060018-0141-5cf25ef8-151d-44f8-a670-bf7fd38c285f",
#             "endTime": "2020-01-27 06:01:25",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "81",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 19,
#             "maxiteration": 0,
#             "metricVal": -111.11449432373047,
#             "startTime": "2020-01-27 06:00:19",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585662579943689-1004548835",
#             "driverId": "driver-20200127060127-0142-80541ee1-0004-4611-b440-c0fc4d280615",
#             "endTime": "2020-01-27 06:02:40",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.009",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 20,
#             "maxiteration": 0,
#             "metricVal": -4.083802032470703,
#             "startTime": "2020-01-27 06:01:27",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585668700153867-112460739",
#             "driverId": "driver-20200127060133-0143-8622cba8-4e0a-4a63-912c-711564c3b2ff",
#             "endTime": "2020-01-27 06:02:40",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.027",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 21,
#             "maxiteration": 0,
#             "metricVal": -32.25065231323242,
#             "startTime": "2020-01-27 06:01:33",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585737259340247-1464532652",
#             "driverId": "driver-20200127060242-0144-4b928119-59c6-4bea-a50a-f31c376060ea",
#             "endTime": "2020-01-27 06:03:54",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.1",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 22,
#             "maxiteration": 0,
#             "metricVal": -118.27165222167969,
#             "startTime": "2020-01-27 06:02:42",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585743552621239-2011019699",
#             "driverId": "driver-20200127060248-0145-e011e592-c259-41be-b835-cc7aee862ed3",
#             "endTime": "2020-01-27 06:03:55",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.059",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 23,
#             "maxiteration": 0,
#             "metricVal": -27.361083984375,
#             "startTime": "2020-01-27 06:02:48",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585812139465769-1563436662",
#             "driverId": "driver-20200127060357-0146-e111ffc1-a63a-40e5-a469-593eb0f23c0b",
#             "endTime": "2020-01-27 06:05:10",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.051",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 24,
#             "maxiteration": 0,
#             "metricVal": -23.449813079833984,
#             "startTime": "2020-01-27 06:03:57",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585818259966664-280802699",
#             "driverId": "driver-20200127060403-0147-195e175c-6137-410d-b3be-53a5d956c990",
#             "endTime": "2020-01-27 06:05:09",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.007",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 25,
#             "maxiteration": 0,
#             "metricVal": -8.447346687316895,
#             "startTime": "2020-01-27 06:04:03",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585886739326813-1635782212",
#             "driverId": "driver-20200127060511-0148-75bfc922-8d21-43ba-8c6a-1e0c09e87582",
#             "endTime": "2020-01-27 06:06:24",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.021",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 26,
#             "maxiteration": 0,
#             "metricVal": -9.769256591796875,
#             "startTime": "2020-01-27 06:05:11",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585892860026997-1204466415",
#             "driverId": "driver-20200127060517-0149-ce3636b2-19d7-48fc-8c98-ee855bcfde10",
#             "endTime": "2020-01-27 06:06:24",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.005",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 27,
#             "maxiteration": 0,
#             "metricVal": -2.312787342071533,
#             "startTime": "2020-01-27 06:05:17",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585961520267446-1175658686",
#             "driverId": "driver-20200127060626-0150-772d644c-3906-47e6-b7a5-dbdbc50fde94",
#             "endTime": "2020-01-27 06:07:39",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.045",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 28,
#             "maxiteration": 0,
#             "metricVal": -53.20034408569336,
#             "startTime": "2020-01-27 06:06:26",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-585967640209338-666691559",
#             "driverId": "driver-20200127060632-0151-b1a37b0b-5668-482b-a6a5-b9ce5634eaa9",
#             "endTime": "2020-01-27 06:07:39",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.025",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 29,
#             "maxiteration": 0,
#             "metricVal": -11.254994964599609,
#             "startTime": "2020-01-27 06:06:32",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586036249645353-2093849325",
#             "driverId": "driver-20200127060741-0152-11a3e620-0cd8-47bf-809e-385c968a0385",
#             "endTime": "2020-01-27 06:08:53",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.013",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 30,
#             "maxiteration": 0,
#             "metricVal": -5.682522583007812,
#             "startTime": "2020-01-27 06:07:41",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586042460542442-1837983540",
#             "driverId": "driver-20200127060747-0153-80f1b8db-5d45-4e76-821f-aa9cd80fb23d",
#             "endTime": "2020-01-27 06:08:54",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.031",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 31,
#             "maxiteration": 0,
#             "metricVal": -36.62467956542969,
#             "startTime": "2020-01-27 06:07:47",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586110989229140-2051118802",
#             "driverId": "driver-20200127060855-0154-dae290f0-0fc5-442e-8f51-b3d3ff9b922e",
#             "endTime": "2020-01-27 06:10:08",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.047",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 32,
#             "maxiteration": 0,
#             "metricVal": -54.6843376159668,
#             "startTime": "2020-01-27 06:08:56",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586117120490491-1733412820",
#             "driverId": "driver-20200127060901-0155-61666529-1e65-4cfd-b24b-6f7a30908004",
#             "endTime": "2020-01-27 06:10:08",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.071",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 33,
#             "maxiteration": 0,
#             "metricVal": -32.920352172851565,
#             "startTime": "2020-01-27 06:09:02",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586185629348279-1170035152",
#             "driverId": "driver-20200127061010-0156-3661ce6a-5faa-402d-942b-53d91e16ba3a",
#             "endTime": "2020-01-27 06:11:23",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.035",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 34,
#             "maxiteration": 0,
#             "metricVal": -41.115535736083984,
#             "startTime": "2020-01-27 06:10:10",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586191710178233-258407833",
#             "driverId": "driver-20200127061016-0157-ad62c24f-6a67-437b-a939-d9cf8ae792f1",
#             "endTime": "2020-01-27 06:11:23",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.005",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 35,
#             "maxiteration": 0,
#             "metricVal": -5.904241561889648,
#             "startTime": "2020-01-27 06:10:16",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586260429382547-197392105",
#             "driverId": "driver-20200127061125-0158-eae69bae-467e-4e5c-ac31-13a59cabe0e2",
#             "endTime": "2020-01-27 06:12:37",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.041",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 36,
#             "maxiteration": 0,
#             "metricVal": -19.220616149902344,
#             "startTime": "2020-01-27 06:11:25",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586266549925419-594086739",
#             "driverId": "driver-20200127061131-0159-474bc30c-d851-4746-8fba-04beaea15308",
#             "endTime": "2020-01-27 06:12:38",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.055",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 37,
#             "maxiteration": 0,
#             "metricVal": -25.26109161376953,
#             "startTime": "2020-01-27 06:11:31",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586335155728917-630015260",
#             "driverId": "driver-20200127061240-0160-f111813c-35e8-4e7d-8e56-714d682f2956",
#             "endTime": "2020-01-27 06:13:52",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.025",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 38,
#             "maxiteration": 0,
#             "metricVal": -11.554006958007813,
#             "startTime": "2020-01-27 06:12:40",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586341379288607-1656149177",
#             "driverId": "driver-20200127061246-0161-e9889b4d-7df6-44ae-9286-12989739da69",
#             "endTime": "2020-01-27 06:13:53",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.073",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 39,
#             "maxiteration": 0,
#             "metricVal": -32.41727142333984,
#             "startTime": "2020-01-27 06:12:46",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586409969804019-1453213480",
#             "driverId": "driver-20200127061354-0162-fe267c3f-f7c1-4059-a466-09f8143bc191",
#             "endTime": "2020-01-27 06:15:07",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.077",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 40,
#             "maxiteration": 0,
#             "metricVal": -88.56201171875,
#             "startTime": "2020-01-27 06:13:54",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586416078463968-110902477",
#             "driverId": "driver-20200127061400-0163-6ced2dbe-6ca8-43ed-bca8-968e970b3bfe",
#             "endTime": "2020-01-27 06:15:07",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.071",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 41,
#             "maxiteration": 0,
#             "metricVal": -80.43238067626953,
#             "startTime": "2020-01-27 06:14:01",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586484670045582-914900007",
#             "driverId": "driver-20200127061509-0164-dac8948a-8137-44b2-b473-6cf50d0e6505",
#             "endTime": "2020-01-27 06:16:22",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.035",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 42,
#             "maxiteration": 0,
#             "metricVal": -40.54814529418945,
#             "startTime": "2020-01-27 06:15:09",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586490800151222-2004263",
#             "driverId": "driver-20200127061515-0165-70565c17-5b3a-40d7-bdde-5e4f2fd2e87b",
#             "endTime": "2020-01-27 06:16:22",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.093",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 43,
#             "maxiteration": 0,
#             "metricVal": -99.2490463256836,
#             "startTime": "2020-01-27 06:15:15",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586559359243970-289251228",
#             "driverId": "driver-20200127061624-0166-c49011c4-5810-4eba-97f9-abefc89745ee",
#             "endTime": "2020-01-27 06:17:36",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.071",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 44,
#             "maxiteration": 0,
#             "metricVal": -85.21854400634766,
#             "startTime": "2020-01-27 06:16:24",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586565490949355-863310625",
#             "driverId": "driver-20200127061630-0167-22f7dd7b-2d8e-438c-96cd-b398b1c6d6bd",
#             "endTime": "2020-01-27 06:17:37",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.025",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 45,
#             "maxiteration": 0,
#             "metricVal": -11.41065559387207,
#             "startTime": "2020-01-27 06:16:30",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586633981036855-712004524",
#             "driverId": "driver-20200127061738-0168-7020b42c-86b1-4e6b-a8c2-17d6cbcf7629",
#             "endTime": "2020-01-27 06:18:52",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.041",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 46,
#             "maxiteration": 0,
#             "metricVal": -50.735008239746094,
#             "startTime": "2020-01-27 06:17:39",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586640249331777-1069199760",
#             "driverId": "driver-20200127061745-0169-08f37066-568e-4941-b0b0-1ab9e831d2a5",
#             "endTime": "2020-01-27 06:18:51",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.087",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 47,
#             "maxiteration": 0,
#             "metricVal": -103.72713470458984,
#             "startTime": "2020-01-27 06:17:45",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586708840354856-2006323523",
#             "driverId": "driver-20200127061853-0170-4895c079-d7c0-4c68-8566-5fbc0f79bc2d",
#             "endTime": "2020-01-27 06:20:06",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.063",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 48,
#             "maxiteration": 0,
#             "metricVal": -28.059872436523438,
#             "startTime": "2020-01-27 06:18:53",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-586714979867214-509280332",
#             "driverId": "driver-20200127061859-0171-4245343b-3422-4498-8815-0cb356275a26",
#             "endTime": "2020-01-27 06:20:06",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 49,
#             "maxiteration": 0,
# ...
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "81",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 109,
#             "maxiteration": 0,
#             "metricVal": -3061.930908203125,
#             "startTime": "2020-01-27 06:57:24",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589089209729668-242483066",
#             "driverId": "driver-20200127065834-0232-9d4bdf68-8a38-42bc-8b92-bf7334163482",
#             "endTime": "2020-01-27 06:59:47",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 110,
#             "maxiteration": 0,
#             "metricVal": -2630.57568359375,
#             "startTime": "2020-01-27 06:58:34",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589095411815932-890953113",
#             "driverId": "driver-20200127065840-0233-fd2372cf-73c1-4cec-a716-ffbbb66af76c",
#             "endTime": "2020-01-27 06:59:47",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.091",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 111,
#             "maxiteration": 0,
#             "metricVal": -2973.038818359375,
#             "startTime": "2020-01-27 06:58:40",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589164620364136-1222247979",
#             "driverId": "driver-20200127065949-0234-5deec296-a53f-459d-82bb-e57c081e156b",
#             "endTime": "2020-01-27 07:01:03",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.087",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 112,
#             "maxiteration": 0,
#             "metricVal": -1076.408203125,
#             "startTime": "2020-01-27 06:59:49",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589170819880547-1574398589",
#             "driverId": "driver-20200127065955-0235-63ae8176-ed19-4629-a9f5-d09fb15ff220",
#             "endTime": "2020-01-27 07:01:02",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.093",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 113,
#             "maxiteration": 0,
#             "metricVal": -2601.83642578125,
#             "startTime": "2020-01-27 06:59:55",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589239753313662-1883895248",
#             "driverId": "driver-20200127070104-0236-ef087152-c0f5-47f6-9f86-ba5d9139b021",
#             "endTime": "2020-01-27 07:02:17",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.085",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 114,
#             "maxiteration": 0,
#             "metricVal": -2562.31298828125,
#             "startTime": "2020-01-27 07:01:04",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589245711417087-663379610",
#             "driverId": "driver-20200127070110-0237-c9674909-16c1-406a-92cf-188a3fb08c16",
#             "endTime": "2020-01-27 07:02:17",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.085",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 115,
#             "maxiteration": 0,
#             "metricVal": -2726.427734375,
#             "startTime": "2020-01-27 07:01:10",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589315970108352-1291474716",
#             "driverId": "driver-20200127070220-0238-6546b822-71d0-41f1-820e-35acf873394d",
#             "endTime": "2020-01-27 07:03:26",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.075",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 116,
#             "maxiteration": 0,
#             "metricVal": -2422.295166015625,
#             "startTime": "2020-01-27 07:02:20",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589383470117329-1050454187",
#             "driverId": "driver-20200127070328-0239-bde0079a-ac33-4d29-93c4-7415de17a3f5",
#             "endTime": "2020-01-27 07:05:41",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "81",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 117,
#             "maxiteration": 0,
#             "metricVal": -9607.06640625,
#             "startTime": "2020-01-27 07:03:28",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589389562742724-1329802364",
#             "driverId": "driver-20200127070334-0240-dae5a511-d456-4b20-a66b-64e1e7144aca",
#             "endTime": "2020-01-27 07:05:42",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.091",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 118,
#             "maxiteration": 0,
#             "metricVal": -8823.6962890625,
#             "startTime": "2020-01-27 07:03:34",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589519307468462-866062701",
#             "driverId": "driver-20200127070544-0241-3282eea8-549e-4087-aaf6-bb7a04bf2000",
#             "endTime": "2020-01-27 07:07:50",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.085",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 119,
#             "maxiteration": 0,
#             "metricVal": -8655.8740234375,
#             "startTime": "2020-01-27 07:05:44",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-589646909629184-1272803389",
#             "driverId": "driver-20200127070751-0242-15067803-3314-4bb0-b7ef-2801a3ad9ffe",
#             "endTime": "2020-01-27 07:13:00",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.095",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "1",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "3",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "9",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "27",
#                     "name": "epochs",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "str",
#                     "fixedVal": "81",
#                     "name": "epochs",
#                     "userDefined": false
#                 }
#             ],
#             "id": 120,
#             "maxiteration": 0,
#             "metricVal": -30419.58203125,
#             "startTime": "2020-01-27 07:07:51",
#             "state": "FINISHED"
#         }
#     ],
#     "failed": 0,
#     "hpoName": "Admin-hpo-584914877877339",
#     "progress": "100",
#     "running": 0,
#     "state": "FINISHED"
# }

# %% [markdown]
# **Full Response of a hpo task status.**
#
# ```
# {
# "hpoName": "string, name/id of the hpo task",
# "state": "string, hpo task state, SUBMITTED, RUNNING, FAILED, FINISHED, STOPPED",
# "running": "int, number of training that is under-going right now",
# "complete": "int, number of training that has completes, including both succeeded and failed trainings",
# "failed": "int, number of training that failed",
# "progress": "string, progress of a percentage value",
# "createtime": "string, time this task was created",
# "creator": "string, user name who created this hpo task",
# "duration": "string, how long the task been run with format hh-mm-ss",
# "experiments": [
#                 {
#                 "id": "int, counter id of the experiment training, start from 0",
#                 "metricVal": "double, best metric value of the experiment training",
#                 "state": "string, state of the BYOF training task"
#                 "appId": "string, BYOF training task id",
#                 "driverId": "string, for internal usage, the real job id for training, currently it is the spark driver id",
#                 "hyperParams": [
#                                 {
#                                 "name": "string, name of the hyperparameter",
#                                 "dataType": "string, data type of the hyperparameter",
#                                 "fixedVal": "string, The hyperparamter value been used in this experiment training with the same datatype as input dataType"
#                                 }
#                                 ],
#                 }
#                 ],
# "best": {"one of the experiments with the best metric value, smallest or biggest one based on the original objective minimize or maximize"}
# }
#
# ```

# %% [markdown]
# ## Manage HPO tasks

# %% [markdown]
# #### Check HPO tasks

# %% [markdown]
# Same REST api as the early health check one.

# %%
#getTuneStatusUrl = 'https://{}:9243/platform/rest/deeplearning/v1/hypersearch'.format(hostname)
res = req.get(startTuneUrl, headers=commonHeaders, verify=False, auth=('Admin', 'Admin'))
if not res.ok:
    print('check tune job status failed: code=%s, %s'%(res.status_code, res.content))
else:
    #print(json.dumps(r.json(), sort_keys=True, indent=4))
    if len(res.json()) == 0:
        print('There is no hpo task been created')
    for item in res.json():
        #print(item['hpoName'])
        print('Hpo task: %s, State: %s'%(item['hpoName'], item['state']))
        #print('Hpo tasks detail:%s'%json.dumps(item, sort_keys=True, indent=4))

# %% [markdown]
# #### Stop Hpo task

# %% [markdown]
# REST API: **PUT /platform/rest/deeplearning/v1/hypersearch/{hponame}**
# - Description: Stop the specified hpo job with name/di {hponame}
# - OUTPUT: success http return code
#
# Since the hpo job has already finished, so nothing to stop here.

# %%
stopHpoUrl = 'https://{}:9243/platform/rest/deeplearning/v1/hypersearch/{}'.format(hostname, hpoName)
r=req.put(stopHpoUrl,headers=commonHeaders, verify=False, auth=('Admin','Admin'))
if not r.ok:
    print('stop hpo task failed: code=%s, %s'%(r.status_code, r.content))
else:
    print('stop hpo task succeeds')

# %% [markdown]
# #### Delete Hpo tasks

# %% [markdown]
# REST API: **DELETE /platform/rest/deeplearning/v1/hypersearch/{hponame}**
# - Description: Delete the specified hpo task with name/id {hponame}
# - OUTPUT: success http return code
#
# REST API: **DELETE /platform/rest/deeplearning/v1/hypersearch**
# - Description: Delete all the hpo task that the login user can access. But please be aware, the BYOF training been created by this hpo task will not be deleted.
# - OUTPUT: success http return code

# %%
deleteHpoUrl = 'https://{}:9243/platform/rest/deeplearning/v1/hypersearch/Admin-hpo-214707651328489'.format(hostname)
r=req.delete(deleteHpoUrl,headers=commonHeaders, verify=False, auth=('Admin','Admin'))
if not r.ok:
    print('delete hpo task failed: code=%s, %s'%(r.status_code, r.content))
else:
    print('delete hpo task succeeds')
