# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

import json
import time
import urllib

# set $DL_NFS_PATH to your path

  
    hostname = 'colonia04'
    myauth = ('username','password')
    protocol = 'http'
    port = 9280
    sigName = 'dli-hpo-rest'
    trainFile = '$DL_NFS_PATH/datasets/higgs/train/HIGGS_train.dmatrix'
    testFile = '$DL_NFS_PATH/datasets/higgs/test/HIGGS_test.dmatrix'
    valFile = '$DL_NFS_PATH/datasets/higgs/val/HIGGS_val.dmatrix'


commonHeaders={'accept': 'application/json'}

startTuneUrl='%s://%s:%d/platform/rest/deeplearning/v1/hypersearch' % (protocol, hostname, port)

req = requests.Session()

# %%
import tarfile
import tempfile
import os
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))


data =  {
        'modelSpec': 
        {
            'sigName': sigName,
            'args': '--exec-start XGboost --cs-datastore-meta type=fs \
                     --gpuPerWorker 1 --model-main main.py \
                     --model-dir xgb-model \
                     --trainFile %s \
                     --valFile %s \
                     --testFile %s' % (trainFile, valFile, testFile)
        },
'algoDef':
        {
            'algorithm': 'Random',
            'maxRunTime': 30,
            'maxJobNum': -1,
            'maxParalleJobNum': 8,
            'objectiveMetric' : 'auc_dev',
            'objective' : 'maximize'
        },
        'hyperParams':
        [
             {
                 'name': 'learning_rate',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': -3,
                 'maxDbVal': 0,
                 'power': 10,
             },
             {
                 'name': 'num_rounds',
                 'type': 'Range',
                 'dataType': 'INT',
                 'minIntVal': 1,
                 'maxIntVal': 1000,
                 'step': 1,
             },
             {
                 'name': 'max_depth',
                 'type': 'Range',
                 'dataType': 'INT',
                 'minIntVal': 1,
                 'maxIntVal': 14,
                 'step': 1,
             },
             {
                 'name': 'lambda',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': -2,
                 'maxDbVal': 5,
                 'power': 10,
             },
             {
                 'name': 'colsample_bytree',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': 0.01,
                 'maxDbVal': 1.0,
                 'step': 0.01,
             },


         ]
    }

mydata={'data':json.dumps(data)}

MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
make_tarfile(tempFile, './xgb-model')
files = {'file': open(tempFile, 'rb')}
create = req.post(startTuneUrl, headers=commonHeaders, data=mydata, files=files, verify=False, auth=myauth)
if not create.ok:
   print('submit tune job failed: code=%s, %s'%(create.status_code, create.content))
else:
   print('submit tune job succeed with hponame: %s'%create.json())
# Out:
# submit tune job succeed with hponame: tpa-hpo-4594325549197227

# %%
import time

hpoName = create.json()

getHpoUrl = '%s://%s:%d/platform/rest/deeplearning/v1/hypersearch/%s' % (protocol, hostname, port, hpoName)

res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=myauth)
if not res.ok:
    print('get hpo task failed: code=%s, %s'%(res.status_code, res.content))
else:
    json_out=res.json()

    while json_out['state'] in ['SUBMITTED','RUNNING']:
        print('Hpo task %s state %s progress %s%%'%(hpoName, json_out['state'], json_out['progress']))
        time.sleep(60)
        res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=myauth)
        json_out=res.json()

    print('Hpo task %s completes with state %s'%(hpoName, json_out['state']))
    print(json.dumps(json_out, indent=4, sort_keys=True))
# Out:
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 0/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 0/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 0/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 8/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 16/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 16/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 16/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 24/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 32/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 32/-%
# Hpo task tpa-hpo-4594325549197227 state RUNNING progress 32/-%
# Hpo task tpa-hpo-4594325549197227 completes with state FINISHED
# {
#     "best": {
#         "appId": "tpa-4594544409770941-268033939",
#         "driverId": "driver-20190702155023-0015-d43e3913-85f4-43cf-ad4a-ba0d4224060b",
#         "endTime": "2019-07-02 16:05:35",
#         "hyperParams": [
#             {
#                 "dataType": "double",
#                 "fixedVal": "0.45578172714493875",
#                 "name": "learning_rate",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "int",
#                 "fixedVal": "773",
#                 "name": "num_rounds",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "int",
#                 "fixedVal": "14",
#                 "name": "max_depth",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "double",
#                 "fixedVal": "60621.289402472976",
#                 "name": "lambda",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "double",
#                 "fixedVal": "0.84",
#                 "name": "colsample_bytree",
#                 "userDefined": false
#             }
#         ],
#         "id": 15,
#         "maxiteration": 0,
#         "metricVal": 0.8438104740169239,
#         "startTime": "2019-07-02 15:50:23",
#         "state": "FINISHED"
#     },
#     "complete": 40,
#     "createtime": "2019-07-02 15:46:43",
#     "creator": "tpa",
#     "duration": "00:30:37",
#     "experiments": [
#         {
#             "appId": "tpa-4594328153992633-1176584122",
#             "driverId": "driver-20190702154646-0000-5c0bfe75-06ff-4ce1-9639-2b69f33594ea",
#             "endTime": "2019-07-02 15:47:36",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5817355251424704",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "276",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "1",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "83427.40663826924",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.21",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 0,
#             "maxiteration": 0,
#             "metricVal": 0.7697116321925691,
#             "startTime": "2019-07-02 15:46:47",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594334315021786-1917042602",
#             "driverId": "driver-20190702154652-0001-45814778-96f6-4077-9103-9b8431dbb16b",
#             "endTime": "2019-07-02 15:48:37",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.04518145977140792",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "747",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "55650.61151998824",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.44",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 1,
#             "maxiteration": 0,
#             "metricVal": 0.8105282299790945,
#             "startTime": "2019-07-02 15:46:53",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594340231290321-1302844088",
#             "driverId": "driver-20190702154658-0002-ee6f5e9f-9027-410f-9a1c-2228b7aa63bf",
#             "endTime": "2019-07-02 15:48:38",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.9924948528636645",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "420",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "27247.351926755204",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.75",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 2,
#             "maxiteration": 0,
#             "metricVal": 0.8408719487321877,
#             "startTime": "2019-07-02 15:46:58",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594346016837242-1220835524",
#             "driverId": "driver-20190702154704-0003-60f3dbcd-7d85-4ac2-915c-ef2254c302fd",
#             "endTime": "2019-07-02 15:49:38",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.849583816281063",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "110",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "14",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "35919.88903882968",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.43",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 3,
#             "maxiteration": 0,
#             "metricVal": 0.825480114649231,
#             "startTime": "2019-07-02 15:47:04",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594351940185979-181238891",
#             "driverId": "driver-20190702154710-0004-5197f4c7-fdb3-4b54-9b00-7cfede6cb510",
#             "endTime": "2019-07-02 15:48:38",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8988646347953473",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "569",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "14",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "96719.5811174962",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.08",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 4,
#             "maxiteration": 0,
#             "metricVal": 0.8006328269418993,
#             "startTime": "2019-07-02 15:47:10",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594357978582734-1585620928",
#             "driverId": "driver-20190702154716-0005-0dae917b-edf9-4c06-b93e-e1986bebe9c9",
#             "endTime": "2019-07-02 15:48:36",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.023583067340975646",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "451",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "96605.5446182719",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.43",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 5,
#             "maxiteration": 0,
#             "metricVal": 0.7903787236592811,
#             "startTime": "2019-07-02 15:47:16",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594364038803539-895743649",
#             "driverId": "driver-20190702154722-0006-b394aafd-e3b9-45cf-a334-05b259935e08",
#             "endTime": "2019-07-02 15:48:37",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8210001660872515",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "334",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "9",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "21462.79499765249",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.83",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 6,
#             "maxiteration": 0,
#             "metricVal": 0.8414159968008896,
#             "startTime": "2019-07-02 15:47:22",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594369916024204-700661903",
#             "driverId": "driver-20190702154728-0007-b1e15443-9b81-48bc-b860-4abf1488e09b",
#             "endTime": "2019-07-02 15:47:35",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.12243650996637531",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "407",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "57172.92786451678",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.42",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 7,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-07-02 15:47:28",
#             "state": "FAILED"
#         },
#         {
#             "appId": "tpa-4594503545319788-1769840156",
#             "driverId": "driver-20190702154942-0008-8688373b-de86-4d27-a37e-d25862be6821",
#             "endTime": "2019-07-02 15:50:28",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.751342718435019",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "961",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "12",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "53302.32742325872",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.39",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 8,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-07-02 15:49:42",
#             "state": "FAILED"
#         },
#         {
#             "appId": "tpa-4594509393013887-1834940929",
#             "driverId": "driver-20190702154947-0009-a4670a27-812f-4f52-8a5d-c25857d13985",
#             "endTime": "2019-07-02 15:50:28",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5095000650838131",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "882",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "16409.729988574152",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.61",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 9,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-07-02 15:49:47",
#             "state": "FAILED"
#         },
#         {
#             "appId": "tpa-4594515060668582-830399574",
#             "driverId": "driver-20190702154953-0010-6e918655-b728-429b-b4b0-3186090945f8",
#             "endTime": "2019-07-02 15:50:29",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.08430838590134836",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "150",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "4",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "43299.34119355601",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.3",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 10,
#             "maxiteration": 0,
#             "metricVal": 0.7849093180621947,
#             "startTime": "2019-07-02 15:49:53",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594520792565333-307553454",
#             "driverId": "driver-20190702154959-0011-6cd7a2ce-891a-44c6-bb04-e5f1f1623ffa",
#             "endTime": "2019-07-02 15:51:32",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.22277352600190894",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "656",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "5",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "95211.15727819115",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.7",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 11,
#             "maxiteration": 0,
#             "metricVal": 0.818913418423156,
#             "startTime": "2019-07-02 15:49:59",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594526621674920-493730710",
#             "driverId": "driver-20190702155005-0012-f635b43e-b753-4eb2-9e23-9ceaf277e0a6",
#             "endTime": "2019-07-02 15:51:31",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.2812089901739929",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "767",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "59854.95295158581",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.71",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 12,
#             "maxiteration": 0,
#             "metricVal": 0.809832790991315,
#             "startTime": "2019-07-02 15:50:05",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594532530493200-726499998",
#             "driverId": "driver-20190702155011-0013-c7725374-ad2d-4c78-9a9e-f57ebd38a2a3",
#             "endTime": "2019-07-02 15:51:31",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5197182497734522",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "65",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "1",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "73775.04649742831",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.2",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 13,
#             "maxiteration": 0,
#             "metricVal": 0.752369465000701,
#             "startTime": "2019-07-02 15:50:11",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594538390839619-1919128715",
#             "driverId": "driver-20190702155017-0014-37279f79-32d4-4a7e-865b-b725e3f0ab07",
#             "endTime": "2019-07-02 15:51:31",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.001558452127790936",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "436",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "14",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "58676.10909455091",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.05",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 14,
#             "maxiteration": 0,
#             "metricVal": 0.7317152332000744,
#             "startTime": "2019-07-02 15:50:17",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4594544409770941-268033939",
#             "driverId": "driver-20190702155023-0015-d43e3913-85f4-43cf-ad4a-ba0d4224060b",
#             "endTime": "2019-07-02 16:05:35",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.45578172714493875",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "773",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "14",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "60621.289402472976",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.84",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 15,
#             "maxiteration": 0,
#             "metricVal": 0.8438104740169239,
#             "startTime": "2019-07-02 15:50:23",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595459831988552-1632411747",
#             "driverId": "driver-20190702160538-0016-289cbb3d-3195-4c7a-b0f7-465cb26bd89c",
#             "endTime": "2019-07-02 16:07:26",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8347799461865922",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "868",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "53551.2459125999",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.58",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 16,
#             "maxiteration": 0,
#             "metricVal": 0.8216051979695682,
#             "startTime": "2019-07-02 16:05:38",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595465663316951-1684385057",
#             "driverId": "driver-20190702160544-0017-aca4bfee-9e62-44ca-843b-f6d5a622fa80",
#             "endTime": "2019-07-02 16:06:25",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.7153270521910825",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "656",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "1",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "8065.25756009559",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.51",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 17,
#             "maxiteration": 0,
#             "metricVal": 0.7728270663622087,
#             "startTime": "2019-07-02 16:05:44",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595471447471351-1844747982",
#             "driverId": "driver-20190702160549-0018-a14a5a00-c9ee-4121-9977-081f02c8d686",
#             "endTime": "2019-07-02 16:07:27",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8999384451443596",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "562",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "1",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "21247.250472087184",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.67",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 18,
#             "maxiteration": 0,
#             "metricVal": 0.7726656163638314,
#             "startTime": "2019-07-02 16:05:49",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595477098895193-659254701",
#             "driverId": "driver-20190702160555-0019-7fb8a11f-fd75-43f7-a641-8140194c1bff",
#             "endTime": "2019-07-02 16:07:27",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.27134596233023656",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "110",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "9",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "19118.159718520325",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.51",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 19,
#             "maxiteration": 0,
#             "metricVal": 0.8195957632331726,
#             "startTime": "2019-07-02 16:05:55",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595482760499549-2076816678",
#             "driverId": "driver-20190702160601-0020-8543f1bb-4a99-4565-bed3-b599c12f145f",
#             "endTime": "2019-07-02 16:07:28",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.36627727848460484",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "88",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "12",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "23314.41570788777",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.48",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 20,
#             "maxiteration": 0,
#             "metricVal": 0.8204027829154752,
#             "startTime": "2019-07-02 16:06:01",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595488717544912-981880510",
#             "driverId": "driver-20190702160607-0021-f5ea7a1b-17cc-4667-b7f3-fe309e3d6ee0",
#             "endTime": "2019-07-02 16:07:29",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.1895922769620126",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "464",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "42965.7048213685",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.4",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 21,
#             "maxiteration": 0,
#             "metricVal": 0.8226240662964768,
#             "startTime": "2019-07-02 16:06:07",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595494652809103-2056522350",
#             "driverId": "driver-20190702160613-0022-fd40d8c5-977a-4f63-9644-f402195cb8c7",
#             "endTime": "2019-07-02 16:08:29",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.45059442263993166",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "814",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "90320.02655291026",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.66",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 22,
#             "maxiteration": 0,
#             "metricVal": 0.8363323057785166,
#             "startTime": "2019-07-02 16:06:13",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595500544425611-1606008071",
#             "driverId": "driver-20190702160619-0023-0932391e-f8ab-47be-a965-3f7fd3b3e7fc",
#             "endTime": "2019-07-02 16:08:29",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.2962580409757456",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "546",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "11",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "30568.1175704592",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.13",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 23,
#             "maxiteration": 0,
#             "metricVal": 0.8060261602423562,
#             "startTime": "2019-07-02 16:06:19",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595634734224256-62051221",
#             "driverId": "driver-20190702160833-0024-54d0ab6b-e7d7-47bd-b838-2c35ea2ffea4",
#             "endTime": "2019-07-02 16:09:21",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.7433632647346017",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "81",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "9",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "26753.18169296879",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.47",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 24,
#             "maxiteration": 0,
#             "metricVal": 0.8217313214114146,
#             "startTime": "2019-07-02 16:08:33",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595640343301855-687047618",
#             "driverId": "driver-20190702160838-0025-fb1fc631-70f4-4a03-b61a-99c61c3121fa",
#             "endTime": "2019-07-02 16:09:20",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8391916205008106",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "107",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "37530.090538640114",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.22",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 25,
#             "maxiteration": 0,
#             "metricVal": 0.8096171503860426,
#             "startTime": "2019-07-02 16:08:38",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595645965998282-795280390",
#             "driverId": "driver-20190702160844-0026-0ab5ae2d-5288-48b4-92ea-acc4cbf06b95",
#             "endTime": "2019-07-02 16:09:19",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.20837658487893462",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "22",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "11",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "50269.92068593951",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.03",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 26,
#             "maxiteration": 0,
#             "metricVal": 0.7155774633306302,
#             "startTime": "2019-07-02 16:08:44",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595651775745641-481441038",
#             "driverId": "driver-20190702160850-0027-09bb4b8b-2b94-4274-923b-f9dc1ec2de65",
#             "endTime": "2019-07-02 16:14:24",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.6043490513319062",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "417",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "13",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "67803.45001212816",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.87",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 27,
#             "maxiteration": 0,
#             "metricVal": 0.8398679996945319,
#             "startTime": "2019-07-02 16:08:50",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595657525312374-479272981",
#             "driverId": "driver-20190702160856-0028-20767b13-92a6-4cd9-9848-72925abac483",
#             "endTime": "2019-07-02 16:10:22",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.3525236508651234",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "661",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "5976.866354604905",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.99",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 28,
#             "maxiteration": 0,
#             "metricVal": 0.8416400198770041,
#             "startTime": "2019-07-02 16:08:56",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595663448762399-1687663144",
#             "driverId": "driver-20190702160902-0029-235b223f-a2e5-4939-b38a-f5e1d8b9046d",
#             "endTime": "2019-07-02 16:10:22",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.8656650099984861",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "33",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "28037.641953010156",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.95",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 29,
#             "maxiteration": 0,
#             "metricVal": 0.8107158742149835,
#             "startTime": "2019-07-02 16:09:02",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595669504479696-1122705833",
#             "driverId": "driver-20190702160908-0030-7a959833-e02d-450a-866c-b2783fe2b7ed",
#             "endTime": "2019-07-02 16:10:23",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.9916015816699891",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "554",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "80932.62134525245",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.94",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 30,
#             "maxiteration": 0,
#             "metricVal": 0.8385836527866174,
#             "startTime": "2019-07-02 16:09:08",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595675354440981-1092827248",
#             "driverId": "driver-20190702160913-0031-81349fa6-9b5d-4dec-a1db-ed3cfe19a128",
#             "endTime": "2019-07-02 16:10:23",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.6456776849810992",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "650",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "5",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "39416.454441104455",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.72",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 31,
#             "maxiteration": 0,
#             "metricVal": 0.8316022716667372,
#             "startTime": "2019-07-02 16:09:13",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595989390762598-776708848",
#             "driverId": "driver-20190702161427-0032-11342f10-8373-4ffc-9022-71be3d8252ea",
#             "endTime": "2019-07-02 16:17:19",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.21481579172883036",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "563",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "12",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "49208.976925935836",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.19",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 32,
#             "maxiteration": 0,
#             "metricVal": 0.8146603538881949,
#             "startTime": "2019-07-02 16:14:27",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4595995151982415-794878794",
#             "driverId": "driver-20190702161433-0033-86ef1233-a06e-4d2a-a973-39ada9d1ffaf",
#             "endTime": "2019-07-02 16:16:16",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.23366637365192217",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "278",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "85296.2206689824",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.31",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 33,
#             "maxiteration": 0,
#             "metricVal": 0.8077224677362391,
#             "startTime": "2019-07-02 16:14:33",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4596000817923492-1952677803",
#             "driverId": "driver-20190702161439-0034-596a3155-502a-4acb-8a1c-2b7be542ce57",
#             "endTime": "2019-07-02 16:17:19",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.4981085370009953",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "993",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "11",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "85204.65591779488",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.4",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 34,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-07-02 16:14:39",
#             "state": "FAILED"
#         },
#         {
#             "appId": "tpa-4596006488635411-1359405855",
#             "driverId": "driver-20190702161444-0035-340bd6ef-efe7-4a37-ac59-5ed1596ca5f8",
#             "endTime": "2019-07-02 16:16:17",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.20190419380997685",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "360",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "7645.352187924405",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.3",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 35,
#             "maxiteration": 0,
#             "metricVal": 0.8201345994982936,
#             "startTime": "2019-07-02 16:14:45",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4596012310119302-969407285",
#             "driverId": "driver-20190702161450-0036-4e559610-1fab-458f-8a93-26140cabaa3c",
#             "endTime": "2019-07-02 16:16:17",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.09207961374918891",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "339",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "95135.68109810384",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.73",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 36,
#             "maxiteration": 0,
#             "metricVal": 0.7930401152341556,
#             "startTime": "2019-07-02 16:14:50",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4596018210035429-777307829",
#             "driverId": "driver-20190702161456-0037-da8364e8-36e2-4af3-acb6-435b7103e478",
#             "endTime": "2019-07-02 16:16:18",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.48952631434885124",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "251",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "5",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "92193.6420958118",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.17",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 37,
#             "maxiteration": 0,
#             "metricVal": 0.7994882357049873,
#             "startTime": "2019-07-02 16:14:56",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4596024007125428-1652465674",
#             "driverId": "driver-20190702161502-0038-b39b386d-49e6-4b4c-a475-f3554f86ced6",
#             "endTime": "2019-07-02 16:17:18",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.7617531084112484",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "733",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "7",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "22048.51660784211",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.44",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 38,
#             "maxiteration": 0,
#             "metricVal": 0.8391700505683126,
#             "startTime": "2019-07-02 16:15:02",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "tpa-4596029992451388-1047815796",
#             "driverId": "driver-20190702161508-0039-f313f09f-d72f-4391-9e4e-cb85eec15a6e",
#             "endTime": "2019-07-02 16:16:16",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.39416869724203746",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "515",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "85889.19712462937",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.19",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 39,
#             "maxiteration": 0,
#             "metricVal": 0.8148932179464328,
#             "startTime": "2019-07-02 16:15:08",
#             "state": "FINISHED"
#         }
#     ],
#     "failed": 4,
#     "hpoName": "tpa-hpo-4594325549197227",
#     "progress": "40/-",
#     "running": 0,
#     "state": "FINISHED"
# }
