# %% [markdown]
# # Using WMLA Elastic Distributed Training via API - a sample notebook

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# ### Contents
#
# - [The big picture](#The-big-picture)
# - [Changes to your code](#Changes-to-your-code)
# - [Making dataset available](#Making-dataset-available)
# - [Set up API end point and log on](#Set-up-API-end-point-and-log-on)
# - [Submit job via API](#Submit-job-via-API)
# - [Monitor running job](#Monitor-running-job)
# - [Retrieve output and saved models](#Retrieve-output-and-saved-models)
#   - [Output - Retrieve training output](#Output:--Retrieve-Training-Metric)
#   - [Save Models](#Save-Model)
# - [Debugging any issues](#Debugging-any-issues)
# - [Further information and useful links](#Further-information-and-useful-links)
# - [Appendix](#Appendix)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# Final things to do:
# - add link to Learning Journey blog in sections: "The big picture" and "Changes to your code"
# </div>

# %% [markdown]
# ## The big picture
# [Back to top](#Contents)
#
# This notebook details the process of taking your existing model training code and making the changes required to run the code using [IBM Watson Machine Learning](https://developer.ibm.com/linuxonpower/deep-learning-powerai/powerai-enterprise/) (WMLA) using Elastic Distributed Training.
#
# <span style='color:deeppink'>**TODO:** Link to Learning Journey Blog</span>
#
# The image below shows the various elements required to use EDT. In this notebook we will step through each of these elements in more detail. Through this process you will offload your code to a WMLA cluster, monitor the running job, retrieve the output and debug any issues seen. A [static version](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/5_running_job.png) is also available.
#
# ![overall](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/5_running_job.gif)

# %% [markdown]
# ## Changes to your code
# [Back to top](#Contents)
#
# In this section we will take existing sample code and make the relevant changes required for use with EDT. An overview of these changes can be seen in the diagram below. A [static version](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/2_code_adaptations.png) is also available.
#
# ![code](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/2_code_adaptations.gif)

# %% [markdown]
# The key changes to your code in order to use EDT are the following:
# - Importing libraries and setting up environment variables
# - Data loading function for EDT
# - Extract parameters for training
# - Replace training and testing loops with EDT equivalents
#
# For the purpose of this tutorial we have adapted the following RestNet18 model for use with EDT: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
#
# Please see the blog associated with this notebook with more detailed explanation of the above changes.
#
# <span style='color:deeppink'>**TODO:** Add link to Learning Journey blog in line above</span>
#
# You can find the original code `pytorch_mnist.py` and the updated code `pytorch_mnist_EDT.py` in the zip file `pytorch_edt.tar.gz` contained in the [tutorial repository](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/elastic-distributed-training-module/pytorch_edt.tar.gz).
#
# You can run the following command to observe relative changes:
# `diff -U4 pytorch_mnist.py pytorch_mnist_EDT.py`
#
# Your modified code should be made available in a directory which also contains the EDT helper scripts: `edtcallback.py`, `emetrics.py` and `elog.py`. Sample versions can be found in the tarball in the tutorial repository; additionally they can be downloaded from http://ibm.biz/WMLA-samples.

# %% [markdown]
# ## Making dataset available
# [Back to top](#Contents)
#
# Next we will make our dataset available to the WMLA cluster as seen in the diagram below.
#
# ![data](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/3_dataset.png)

# %% [markdown]
# 1. Ask your system admin the path of $DLI_DATA_FS directory
#
# 2. ssh to WMLA-server and get access to $DLI_DATA_FS
#
#
#
# 3. Download dataset
#
# ```
# [WMLA-server dlidata]# wget https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/elastic-distributed-training-module/pytorch-mnist-dataset.zip
# --2020-05-12 22:27:07--  https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/elastic-distributed-training-module/pytorch-mnist-dataset.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/IBM/wmla-assets/master/WMLA-learning-journey/elastic-distributed-training-module/pytorch-mnist-dataset.zip [following]
# --2020-05-12 22:27:07--  https://raw.githubusercontent.com/IBM/wmla-assets/master/WMLA-learning-journey/elastic-distributed-training-module/pytorch-mnist-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.36.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.36.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23006288 (22M) [application/zip]
# Saving to: ‘pytorch-mnist-dataset.zip’
#
# 100%[=============================================================================================================================================>] 23,006,288  67.4MB/s   in 0.3s
#
# 2020-05-12 22:27:08 (67.4 MB/s) - ‘pytorch-mnist-dataset.zip’ saved [23006288/23006288]
#
# [WMLA-server dlidata]# unzip pytorch-mnist-dataset.zip
#
# ```
#
# 4. Unzip the zip file and modify file owner/group, that is equivalent to Instance Group Execution User (in this case it is egoadmin)
# ```
# [WMLA-server dlidata]# chown -R egoadmin:egoadmin pytorch-mnist/
# [WMLA-server hymenopteradata]# pwd
# /dlidata/pytorch-mnist
# [WMLA-server hymenopteradata]# ls -lt
# total 0
# drwxr-x--- 4 egoadmin egoadmin 34 Jan  7 23:54 MNIST
#
# ```
#
# 5. Take note of the path name of this dataset, note that your path will likely be different that seen here.
# ```
# /dlidata/pytorch-mnist
# ```

# %% [markdown]
# ## Set up API end point and log on
# [Back to top](#Contents)
#
# In this section we set up the API endpoint which will be used in this notebook.

# %% [markdown]
# 1. Source the environment
#
# $EGO_TOP is the installation directory.  The default value is /opt/ibm/spectrumcomputing
#
# ```
# . $EGO_TOP/profile.platform
#
# ```
# 2. Login
#
# ```
# egosh user logon -u <wmla_user>
# Logged on successfully
#
# ```
#
# 3. Retrieve Conductor Rest API Port
#
# ```
# egosh client view |grep -A 3 ASCD_REST_BASE_URL_1
# CLIENT NAME: ASCD_REST_BASE_URL_1
# DESCRIPTION: http://<WMLA-server>:8280/platform/rest/
#
# ```
#
# 4.  Retrieve DLI (Deep Learning Impact) Rest API Port
#
# ```
# egosh client view |grep -A 3 DLPD_REST_BASE_URL_1
# CLIENT NAME: DLPD_REST_BASE_URL_1
# DESCRIPTION: http://<WMLA-server>:9280/platform/rest/
#
# ```
#
# 5.  Note that the port numbers in your URL will depend on whether SSL has been enabled or not

# %% [markdown]
# ## Submit job via API
# [Back to top](#Contents)
#
# Now we need to structure our API job submission. There are various elements to this process as seen in the diagram below. Note that **this** jupyter notebook is the one referred to below. A [static version](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/4_api_setup.png) is also available.
#
# ![code](https://github.com/IBM/wmla-assets/raw/master/WMLA-learning-journey/shared-images/4_api_setup.gif)

# %% [markdown]
# The following sections use the Watson ML Accelerator API to complete the various tasks required.
# We've given examples of a number of tasks but you should refer to the documentation at to see more details
# of what is possible and sample output you might expect.
#
# - https://www.ibm.com/support/knowledgecenter/SSFHA8_1.2.1/cm/deeplearning.html
# - https://www.ibm.com/support/knowledgecenter/SSZU2E_2.4.0/reference_s/api_references.html

# %%
import requests, json
import pandas as pd
import datetime
# from IPython.display import display

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
# plt.rcParams['figure.figsize'] = [24, 8.0]
#import seaborn as sns

pd.set_option('display.max_columns', 999)
pd.set_option('max_colwidth', 300)

import tarfile
import tempfile
import os

# %%
#Construct API call

master_host = 'p10a117.pbm.ihost.com'


dli_rest_port = '9243'  #Deep Learning Impact Rest API Port
sc_rest_port = '8643' #Conductor Rest API Port

sc_rest_url = 'https://'+master_host+':'+sc_rest_port+'/platform/rest/conductor/v1'
dl_rest_url = 'https://'+master_host+':'+dli_rest_port+'/platform/rest/deeplearning/v1'

# User login details
wmla_user = 'id'
wmla_pwd = 'pwd'



myauth = (wmla_user, wmla_pwd)


# Instance Group to be used
sig_name =  'b0p036-dliauto-edt'


# REST call variables
headers = {'Accept': 'application/json'}
print (sc_rest_url)
print (dl_rest_url)

# Model Path
#model_path = '<path_to_your_local_model_directory>'
model_path = '/gpfs/software/wmla-p10a117/dli_data_fs/models/pytorch_edt'
# Out:
# https://p10a117.pbm.ihost.com:8643/platform/rest/conductor/v1
# https://p10a117.pbm.ihost.com:9243/platform/rest/deeplearning/v1

# %% [markdown]
# ### Package model files for training
# Package the updated model files into a tar file ending with `.modelDir.tar`

# %%
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))


MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
make_tarfile(tempFile, model_path)
print(" tempFile: " + tempFile)
files = {'file': open(tempFile, 'rb')}
# Out:
#  tempFile: /tmp/tmph_34mrhv.modelDir.tar

# %% [markdown]
# ### Log on
#
#
# Obtain login session tokens to be used for session authentication within the RESTful API. Tokens are valid for 8 hours.

# %%
r = requests.get(sc_rest_url+'/auth/logon', verify=False, auth=myauth, headers=headers) 

if r.ok:
    print ('\nLogon succeeded')
    
else: 
    print('\nLogon failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Logon succeeded
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### Check DL Frameworks details
#
# Check what framework plugins are available and see example execution commands.  In this demonstration we will use **edtPyTorch**

# %%
r = requests.get(dl_rest_url+'/execs/frameworks', auth=myauth, headers=headers, verify=False).json()
# Using the raw json, easier to see the examples given
print(json.dumps(r, indent=4))
# Out:
# [
#     {
#         "name": "tensorflow1100",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow. Tested for Tensorflow 1.10.0.",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow1100 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "tensorflow",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "disttensorflow",
#         "description": "",
#         "desc": [
#             "Distributed TensorFlow",
#             "Instead of passing parameters such as ps_hosts, worker_hosts, specify --numPs",
#             "as in example below. Parameter servers (ps) and worker hosts will be allocated",
#             "dynamically.",
#             "Use --gpuPerWorker flag to specify number of GPUs per worker.",
#             "The maximum number of worker is 2.",
#             "The maximum number of GPUs per worker is 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 1 --gpuPerWorker 1",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 2 --gpuPerWorker 1"
#         ]
#     },
#     {
#         "name": "tensorflow200_alpha",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow 2.0 preview",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow20_preview <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PowerAICaffeIBM",
#         "description": "",
#         "desc": [
#             "IBM PowerAI IBM Caffe",
#             "NOTES:",
#             "-You must specify --model-dir flag to point to a directory containing both solver",
#             " and network files, and in the solver file, the path for the network file must not be ",
#             " a full path.",
#             "-Other paths such as snapshot, data source, in solver and network files must be",
#             " on a shared file system.",
#             "-Caffe's --gpu option will be overriden with 'all' since DLI allocates ",
#             " and manages GPUs. Use --gpuPerWorker option as shown below to request for number of GPUs.",
#             " Currently max gpuPerWorker is set to 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-dir <model-dir> --model-main lenet_solver.prototxt train",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --gpuPerWorker 2 --model-dir <model-dir> --model-main lenet_solver.prototxt train"
#         ]
#     },
#     {
#         "name": "keras",
#         "description": "",
#         "desc": [
#             "Keras",
#             "Examples:",
#             "$ python dlicmd.py --exec-start keras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main keras_mnist_cnn.py"
#         ]
#     },
#     {
#         "name": "edtKeras",
#         "description": "",
#         "desc": [
#             "Keras - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtKeras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "ddlCaffe",
#         "description": "",
#         "desc": [
#             "Caffe - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start ddlCaffe --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 4 caffe train",
#             "  --model-main lenet_solver.prototxt --model-dir <modelDir>",
#             "  -ddl_update"
#         ]
#     },
#     {
#         "name": "PyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "ddlTensorFlow",
#         "description": "",
#         "desc": [
#             "Tensorflow - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start  ddlTensorFlow --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 2 python --model-main ddl_mnist.py",
#             "  --ddl_opts=_QUOTE_-mode r:2_QUOTE_ "
#         ]
#     },
#     {
#         "name": "edtPyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtPyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PyTorch041",
#         "description": "",
#         "desc": [
#             "PyTorch041. Tested for torch version 0.4.1.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch041 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     }
# ]
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### Arguments for API call
# Equivalent of flags used if running command directly on WMLA CLI, including:

# %%
framework_name = 'edtPyTorch' # DL Framework to use, from list given above
dataset_location = 'pytorch-mnist' # relative path of your data set under $DLI_DATA_FS
local_dir_containing_your_code = 'pytorch_edt'
number_of_GPU = '2' # number of GPUs for elastic distribution
name_of_your_code_file = 'pytorch_mnist_EDT.py' # Main model file as opened locally above


args = '--exec-start {} \
        --cs-datastore-meta type=fs,data_path={} \
        --model-dir {} \
        --edt-options maxWorkers={} \
        --model-main {} \
        --epochs 15  \
        '.format(framework_name, dataset_location, local_dir_containing_your_code, number_of_GPU, name_of_your_code_file)

print ("args: " + args)
# Out:
# args: --exec-start edtPyTorch         --cs-datastore-meta type=fs,data_path=pytorch-mnist         --model-dir pytorch_edt         --edt-options maxWorkers=2         --model-main pytorch_mnist_EDT.py         --epochs 15

# %% [markdown]
# ### Submit Job

# %%
r = requests.post(dl_rest_url+'/execs?sigName='+sig_name+'&args='+args, files=files,
                  auth=myauth, headers=headers, verify=False)

if r.ok:
    exec_id = r.json()['id']
    sig_id = r.json()['sigId']
    driver_id = r.json()['submissionId']
    print ('\nModel submitted successfully \Driver ID: {}'.format(driver_id))
    print ('Exec ID: {}'.format(exec_id))
    print ('SIG ID: {}'.format(sig_id))
else: 
    print('\nModel submission failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Model submitted successfully \Driver ID: driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50
# Exec ID: kelvinl-410210174708804-1704102731
# SIG ID: f6c8d084-73cb-427b-9c3d-77f298ab9e6b

# %% [markdown]
# ## Monitor running job
# [Back to top](#Contents)
#
# Once the job is submitted successfully we can monitor the running job.

# %%
# Check status of all RUNNING jobs in SIG (rerun cell to refresh)

monitor = []
monitor_output = []

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications?state=RUNNING', 
                auth=myauth, headers=headers, verify=False).json()


       
if (len(r) == 0):
    print ('No jobs running')
    
else:
    
    # Filter out the relevant information
    monitor.append([(
        job['driver']['id'],
        job['driver']['state'],
        job['apprunduration'],
        job['gpuslots'],
        job['gpumemused']['total'],
        job['gpudevutil']['total'],
    ) for job in r])

    monitor_output = pd.DataFrame([item for monitor in monitor for item in monitor])
    monitor_output.columns = [
        'Driver ID', 
        'State', 
        'Run duration (mins)',
        'GPU slots',
        'Total GPU memory used',
        'Total GPU utilsation (%) ',
    ]
    
    for job in r:
        executors = job['executors']
        

monitor_output
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#                                                          Driver ID    State  \
# 0  driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50  RUNNING
#
#    Run duration (mins)  GPU slots Total GPU memory used  \
# 0               2.5064          2                  1698
#
#   Total GPU utilsation (%)
# 0                      16.0

# %% [markdown]
# ## Retrieve output and saved models
# [Back to top](#Contents)
#
# After the job completes then we can retrieve the output, logs and saved models.

# %% [markdown]
# ### Output:  Retrieve Training Metric

# %%
r = requests.get(dl_rest_url+'/execs/'+exec_id+'/log', auth=myauth, headers=headers, verify=False).json()

from io import StringIO

cols = ['timestamp','global_steps','iteration','loss','accuracy']
final_data = pd.read_csv(StringIO(r.replace(':',',')), 
                 usecols=[4,6,8,10,12], 
                 names=cols)
final_data['timestamp2'] = final_data.timestamp.apply(pd.to_datetime, unit='ms')
final_data.head(10)
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#        timestamp  global_steps  iteration     loss  accuracy  \
# 0  1590084048447             1          4  0.03597   0.00063
# 1  1590084048448             2          4  0.03604   0.00070
# 2  1590084048572             3          6  0.03606   0.00068
# 3  1590084048574             4          6  0.03612   0.00082
# 4  1590084048697             5          8  0.03611   0.00097
# 5  1590084048698             6          8  0.03609   0.00104
# 6  1590084048822             7         10  0.03601   0.00123
# 7  1590084048824             8         10  0.03601   0.00117
# 8  1590084048949             9         12  0.03596   0.00113
# 9  1590084048951            10         12  0.03590   0.00123
#
#                timestamp2
# 0 2020-05-21 18:00:48.447
# 1 2020-05-21 18:00:48.448
# 2 2020-05-21 18:00:48.572
# 3 2020-05-21 18:00:48.574
# 4 2020-05-21 18:00:48.697
# 5 2020-05-21 18:00:48.698
# 6 2020-05-21 18:00:48.822
# 7 2020-05-21 18:00:48.824
# 8 2020-05-21 18:00:48.949
# 9 2020-05-21 18:00:48.951

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
# plt.rcParams['figure.figsize'] = [24, 8.0]
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize = (15,10))

sns.lineplot(final_data.timestamp2,final_data.global_steps, color="g", ax=axes[0,0])
axes[0,0].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
axes[0,0].set_xlabel("Time")

sns.lineplot(final_data.global_steps,final_data.loss, color="r", ax=axes[0,1])
sns.lineplot(final_data.global_steps,final_data.accuracy, color="b", ax=axes[1,0])

axes[1,1].axes.get_xaxis().set_visible(False)
axes[1,1].axes.get_yaxis().set_visible(False)
axes[1,1].text(0.05, 0.8, 'ID: '+exec_id, size=14)
axes[1,1].text(0.05, 0.65, 'SIG: '+sig_name, size=14)
#axes[1,1].text(0.05, 0.55, 'Status: '+status, size=14)

plt.show()

# %% [markdown]
# ### Save Model

# %%
# Get model from training job - downloads zip file (with progress bar) of saved model to directory local to this notebook
# (note that you need to save model in your code using the environment variable for location)

import requests, zipfile, io
#from tqdm.notebook import tqdm
import tqdm

r = requests.get(dl_rest_url+'/execs/'+exec_id+'/result', auth=myauth, stream=True)

total_size = int(r.headers.get('Content-Disposition').split('size=')[1])
block_size = 1024 #1 Kibibyte
t=tqdm(total=total_size, unit='iB', unit_scale=True)

with open('model.zip', 'wb') as f:
    for data in r.iter_content(block_size):
        t.update(len(data))
        f.write(data)
t.close()

# %% [markdown]
# ## Debugging any issues
# [Back to top](#Contents)
#
# In the case where you have issues during the process detailed above, there are a number of detailed logs that you can view to understand what is happening on the WMLA cluster.
#
# WMLA leverages Spark architecture for distributing Deep Learning/Machine Learning jobs.  In Spark,  when an item of processing has to be done, there is a “driver” process that is in charge of taking the user’s code and converting it into a set of multiple tasks. There are also “executor” processes, each operating on a separate node in the cluster, that are in charge of running the tasks, as delegated by the driver.
#
# You can monitor Deep Learning/Machine Learning application activity,  performance and resource usage in Driver Log & Executor Log.
# - Driver Log captures issues related to dependencies and environment variable,  for example,  missing dataset or invalid execution parameter flags.
# - Executor Log records Deep Learning/Machine Learning training process.

# %% [markdown]
# ### Retrieve Training Driver Stdout Log

# %%
# Get Spectrum Conductor logs for training run - shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# load extra config from : /gpfs/software/wmla-p10a117/dli_shared_fs/conf
# Setting up spark environment on node p10a118.pbm.ihost.com
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/gpfs/software/wmla-p10a117/dli_shared_fs;export DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export DLI_EXECID=kelvinl-410210174708804-1704102731;export PS_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export DATA_PATH=pytorch-mnist
# 20/05/21 14:00:25 INFO Conda variables: conda_home=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda, conda_env=moddlipy3, python=/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=moddlipy3
# 20/05/21 14:00:25 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/05/21 14:00:25 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/u5SXaRsY/0	2020-05-21 14:00:25.699252067 -0400
# [D]: >> 0-1: +++ /tmp/u5SXaRsY/1	2020-05-21 14:00:25.749252292 -0400
# [D]: >> 0-1: @@ -1,14 +1,154 @@
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLUGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1: +DATA_PATH=pytorch-mnist
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1:  DLI_BYOF_CONDA_ENV=moddlipy3
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=moddlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1: -DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/anaconda3
# [D]: >> 0-1: +DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/gpfs/software/wmla-p10a117/dli_data_fs
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=kelvinl-410210174708804-1704102731
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# [D]: >> 0-1:  DLI_IS_DRIVER=true
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/gpfs/software/wmla-p10a117/dli_result_fs
# [D]: >> 0-1: +DLI_SHARED_FS=/gpfs/software/wmla-p10a117/dli_shared_fs
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  DL_NFS_PATH=/gpfs/software/wmla-p10a117/dli_shared_fs
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1:  EGO_CONFDIR=/gpfs/software/wmla-p10a117/wmla/kernel/conf
# [D]: >> 0-1: @@ -17,17 +157,29 @@
# [D]: >> 0-1:  EGO_LIBDIR=/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1:  EGO_MASTER_LIST_PEM=p10a117.pbm.ihost.com
# [D]: >> 0-1:  EGO_TOP=/gpfs/software/wmla-p10a117/wmla
# [D]: >> 0-1: +FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# [D]: >> 0-1:  HADOOP_CONF_DIR=
# [D]: >> 0-1:  HADOOP_HOME=
# [D]: >> 0-1:  HOME=/gpfs/home/s4s004/b0p036aa
# [D]: >> 0-1: +HOSTNAME_F=p10a118.pbm.ihost.com
# [D]: >> 0-1:  IG_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# [D]: >> 0-1:  JAVA_HOME=/gpfs/software/wmla-p10a117/wmla/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1590005491488
# [D]: >> 0-1: -LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/143771:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: +LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/143771:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib:/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  NCCL_SOCKET_IFNAME=enP5p7s0f1
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/bin:/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1:  PS_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  PWD=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50
# [D]: >> 0-1: +PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils/:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=b0p036aa
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -87,7 +239,22 @@
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=b0p036aa
# [D]: >> 0-1:  USER=b0p036aa
# [D]: >> 0-1: +USER_UID=1295221806
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1:  additionalEnv_DLI_BYOF_CONDA_ENV=moddlipy3
# [D]: >> 0-1:  additionalEnv_IG_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/u5SXaRsY
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to
# Exposed the environment variable DATA_DIR to: /gpfs/software/wmla-p10a117/dli_data_fs/pytorch-mnist
# Exposed the environment variable RESULT_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731
# Exposed the environment variable LOG_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/log/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50.p10a118.pbm.ihost.com
# Exposed the environment variable SAVED_MODEL_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/model
# /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50.p10a118.pbm.ihost.com/
# 20/05/21 14:00:25 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=
# DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# DLI_FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# DL_NFS_PATH=/gpfs/software/wmla-p10a117/dli_shared_fs
# DLI_ELASTIC_CONF_DIR=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/143771:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib:/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils/:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:
# PATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/bin:/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=b0p036aa
# USER_UID=1295221806
# DLI_EXECID=kelvinl-410210174708804-1704102731
# SPARK_LOG_STDOUTSTDERR_DIR=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50.p10a118.pbm.ihost.com/
# 20/05/21 14:00:25 INFO finish spark environment setup.
# /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip
# <> DATA_DIR /gpfs/software/wmla-p10a117/dli_data_fs/pytorch-mnist
# <> RESULT_DIR /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731
# <> LOG_DIR /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/log/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50.p10a118.pbm.ihost.com
# <> SAVED_MODEL_DIR /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/model
# Using pytorch backend.
# libunformatworker.so loaded successfully
# Using spark scheduler.
# > fabric loaded from /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip
# dataDir is: /gpfs/software/wmla-p10a117/dli_data_fs/pytorch-mnist
# model_path: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/model/saved_model
# tb_directory: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/log/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50.p10a118.pbm.ihost.com/tb
# args:  Namespace(batchsize=64, epochs=15, gamma=0.7, log_interval=10, lr=0.01, momentum=0.5, no_cuda=False, numWorker=2, save_model=False, seed=1, test_batch_size=1000)
# numWorker args: 2
# batch_size args: 64
# epochs args: 15
# Warining! Ignore invalid input for 'scaleup_function'. It should be a function with two input arguments: epoch and max_engine_num,and returns scaled max_engine_num
# /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip/pyspark/context.py:248: RuntimeWarning: Failed to add file [.//fabric.zip] speficied in 'spark.submit.pyFiles' to Python path:
#   /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip
#   /tmp/f6c8d084-73cb-427b-9c3d-77f298ab9e6b_b0p036aa_b0p036aa/spark-98053724-e94f-450b-9bf2-ad3ef40ef159/userFiles-e2d6f669-ee54-4dbe-9430-8529892d20d9
#   /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50/fabric.zip
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/python/lib/py4j-0.10.7-src.zip
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/jars/ego/spark-core_2.11-2.3.3.jar
#   /gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils
#   /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip
#   /gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools
#   /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
#   /gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/driver-20200521140025-0003-a6d17fca-d558-4170-bc50-85e99c99bf50
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python27.zip
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/plat-linux2
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/lib-tk
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/lib-old
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/lib-dynload
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages
#   /gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tflms-2.0.1-py2.7.egg
#   RuntimeWarning)
# start message server 129.40.42.118:43717
# 2020-05-21 14:00:33,426 - root - INFO - client connect to server url: 129.40.42.118:43717
# --------START TRAINING--------
# --------END TRAINING: completed epoch 15 in time 901.541869879 --------

# %% [markdown]
# Note that the output from the training can be found in the `$DLI_WORK_DIR` referenced in this log, in the directory *under* `batchworkdir`. The structure of the files contained in this directory (which you will access via the API) are the following.
#
# ```
# $ tree -h
# .
# ├── [   6]  checkpoint
# ├── [ 247]  log
# │   ├── [   6]  0-97eb84d4-6e4b-4bb7-95e0-fc7bfda461dc.<wmla_server>
# │   ├── [   6]  1-a111dd6d-c406-48f2-89ce-1ef526d5b34b.<wmla_server>
# │   └── [  50]  driver-20200227104231-0007-3655c5b5-5d81-43ac-a8c6-c243635f60df.<wmla_server>
# │       ├── [ 19K]  evaluation-metrics.txt
# │       └── [7.1K]  stdout
# ├── [  19]  model
# │   └── [ 214]  train
# │       ├── [4.7K]  model_epoch_10_optimizer_state.pth
# │       ├── [ 43M]  model_epoch_10.pth
# │       ├── [4.7K]  model_epoch_5_optimizer_state.pth
# │       ├── [ 43M]  model_epoch_5.pth
# │       ├── [4.7K]  model_epoch_final_optimizer_state.pth
# │       └── [ 43M]  model_epoch_final.pth
# ├── [  25]  _submitted_code
# │   └── [ 133]  pytorch_edt
# │       ├── [1.6K]  edtcallback.py
# │       ├── [2.0K]  elog.py
# │       ├── [4.1K]  emetrics.py
# │       ├── [  67]  __pycache__
# │       │   ├── [2.0K]  edtcallback.cpython-36.pyc
# │       │   └── [2.4K]  elog.cpython-36.pyc
# │       ├── [3.1K]  pytorch_mnist_EDT.py
# │       └── [4.4K]  pytorch_mnist.py
# └── [2.5K]  val_dict_list.json
# ```

# %% [markdown]
# ### Retrieve Training Driver Stderr Log

# %%
# shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### Retrieve Training Executor Log
# #### Retrieve Executor ID
# - The deep learning training log per GPU is written in executor log
# - Execute following code to retrieve list of executor ID

# %%
for key in executors:    
    print ('executors: ' + key['id'])
# Out:
# executors: 1-18402651-e9f2-4365-8402-47615b476931
# executors: 0-ee39e183-f4af-4b72-9bd2-89e09cbef18d

# %% [markdown]
# ### Retrieve Executor Stdout log
# - set the parameter executor_id

# %%
executor_id = '0-ee39e183-f4af-4b72-9bd2-89e09cbef18d'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# load extra config from : /gpfs/software/wmla-p10a117/dli_shared_fs/conf
# Setting up spark environment on node p10a117.pbm.ihost.com
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/gpfs/software/wmla-p10a117/dli_shared_fs;export DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export DLI_EXECID=kelvinl-410210174708804-1704102731;export PS_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt;export DATA_PATH=pytorch-mnist
# 20/05/21 14:00:35 INFO Conda variables: conda_home=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda, conda_env=moddlipy3, python=/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=moddlipy3
# 20/05/21 14:00:35 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/05/21 14:00:35 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/YyPvTayL/0	2020-05-21 14:00:35.456118224 -0400
# [D]: >> 0-1: +++ /tmp/YyPvTayL/1	2020-05-21 14:00:35.526118532 -0400
# [D]: >> 0-1: @@ -1,14 +1,154 @@
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLUGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1:  CUDA_VISIBLE_DEVICES=1
# [D]: >> 0-1: +DATA_PATH=pytorch-mnist
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1:  DLI_BYOF_CONDA_ENV=moddlipy3
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=moddlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1: -DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/anaconda3
# [D]: >> 0-1: +DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/gpfs/software/wmla-p10a117/dli_data_fs
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=kelvinl-410210174708804-1704102731
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/gpfs/software/wmla-p10a117/dli_result_fs
# [D]: >> 0-1: +DLI_SHARED_FS=/gpfs/software/wmla-p10a117/dli_shared_fs
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  DL_NFS_PATH=/gpfs/software/wmla-p10a117/dli_shared_fs
# [D]: >> 0-1:  DRIVER_EXECUTOR_SHAREDKEY=d6e8c2dc-b6ff-4461-bcfc-a0a738be5752
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1: @@ -20,14 +160,27 @@
# [D]: >> 0-1:  EGO_TOP=/gpfs/software/wmla-p10a117/wmla
# [D]: >> 0-1:  FABRIC_BACKEND=pytorch
# [D]: >> 0-1:  FABRIC_FIRST_HOST_EXECUTOR=true
# [D]: >> 0-1: +FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# [D]: >> 0-1:  HOME=/gpfs/home/s4s004/b0p036aa
# [D]: >> 0-1: +HOSTNAME_F=p10a117.pbm.ihost.com
# [D]: >> 0-1:  IG_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# [D]: >> 0-1:  JAVA_HOME=/gpfs/software/wmla-p10a117/wmla/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1590005491488
# [D]: >> 0-1: -LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/70583:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: +LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/70583:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib:/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  NCCL_SOCKET_IFNAME=enP5p7s0f1
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/bin:/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +PS_PATH=/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt
# [D]: >> 0-1:  PWD=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/app-20200521140032-0003-d183c854-9681-4033-94b6-0e553d366ae6/executor-0-ee39e183-f4af-4b72-9bd2-89e09cbef18d
# [D]: >> 0-1: +PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils/:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=b0p036aa
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -96,5 +249,20 @@
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=b0p036aa
# [D]: >> 0-1:  USER=b0p036aa
# [D]: >> 0-1: +USER_UID=1295221806
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/YyPvTayL
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: final: >> CUDA_VISIBLE_DEVICES=1
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to 1
# Exposed the environment variable DATA_DIR to: /gpfs/software/wmla-p10a117/dli_data_fs/pytorch-mnist
# Exposed the environment variable RESULT_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731
# Exposed the environment variable LOG_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/log/0-ee39e183-f4af-4b72-9bd2-89e09cbef18d.p10a117.pbm.ihost.com
# Exposed the environment variable SAVED_MODEL_DIR to: /gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/model
# 20/05/21 14:00:35 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=1
# DLI_CONDA_HOME=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda
# DLI_FABRIC_HOME=/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3
# DL_NFS_PATH=/gpfs/software/wmla-p10a117/dli_shared_fs
# DLI_ELASTIC_CONF_DIR=/gpfs/software/wmla-p10a117/wmla/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/work/b0p036aa/70583:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib:/gpfs/software/wmla-p10a117/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/native:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/lib:/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/envs/moddlipy3/lib
# PYTHONPATH=/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils/:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/libs/fabric.zip:/gpfs/software/wmla-p10a117/dli_shared_fs/tools/dli_utils:/gpfs/software/wmla-p10a117/dli_shared_fs/fabric/1.2.3/tools:/gpfs/software/wmla-p10a117/dli_result_fs/b0p036aa/batchworkdir/kelvinl-410210174708804-1704102731/_submitted_code/pytorch_edt:
# PATH=/gpfs/software/wmla-p10a117/wmla_anaconda/b0p036/anaconda/bin:/usr/local/bin:/bin:/usr/bin:/gpfs/software/wmla-p10a117/wmla/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=b0p036aa
# USER_UID=1295221806
# DLI_EXECID=kelvinl-410210174708804-1704102731
# SPARK_LOG_STDOUTSTDERR_DIR=/gpfs/software/wmla-p10a117/wmla_sigs/b0p036-dliauto-edt/spark-2.3.3-hadoop-2.7/logs/app-20200521140032-0003-d183c854-9681-4033-94b6-0e553d366ae6/0-ee39e183-f4af-4b72-9bd2-89e09cbef18d.p10a117.pbm.ihost.com/
# 20/05/21 14:00:35 INFO finish spark environment setup.

# %% [markdown]
# ### Retrieve Executor Stderr log
# - set the parameter executor_id

# %%
executor_id = '0-ee39e183-f4af-4b72-9bd2-89e09cbef18d'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# /gpfs/software/wmla-p10a117/wmla_anaconda/b0p036a/anaconda/envs/powerai162/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p10a117.pbm.ihost.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ## Further information and useful links
# [Back to top](#Contents)
#
# **WMLA Introductory videos:**
# - WMLA overview video (6 mins): http://ibm.biz/WMLA-video
# - WMLA getting started (3 mins): http://ibm.biz/WMLA-start
# - Overview of adapting your code for Elastic Distributed Training via API: [video](https://youtu.be/RnZtYNX6meM) | [PDF](docs/wmla_api_pieces.pdf) (screenshot below)
#
# **Further WMLA information & documentation**
# - [Power Developer Portal (WMLCE frameworks information)](https://developer.ibm.com/linuxonpower/deep-learning-powerai/releases/)
# - WMLA tutorials: http://ibm.biz/WMLA-blog
# - Knowledge Centre links:
#   - [IBM Watson Machine Learning Accelerator](https://www.ibm.com/support/knowledgecenter/SSFHA8)
#   - [IBM Spectrum Conductor](https://www.ibm.com/support/knowledgecenter/en/SSZU2E/product_welcome_conductorspark.html)
#   - [IBM Spectrum Conductor Deep Learning Impact](https://www.ibm.com/support/knowledgecenter/SSWQ2D)
#
# **Further Power Systems information**
# - [AI on Power Systems Redbook (PDF)](https://www.redbooks.ibm.com/redbooks/pdfs/sg248435.pdf) (deep dive technical information)

# %% [markdown]
# ## Appendix
# [Back to top](#Contents)
#
# #### This notebook requires Watson ML Accelerator 1.2.1 + Interim Fix 527174 & 536919 to run.
# For details please refer to following link:
# https://www.ibm.com/support/knowledgecenter/en/SSFHA8_1.2.1/wmla_fix_pack.html
#
# #### This is version 1.0 and its content is copyright of IBM.   All rights reserved.
