# %% [markdown]
# # Using WMLA Elastic Distributed Training via API - a sample notebook

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Contents
#
# - [The big picture](#The-big-picture)
# - [Changes to your code](#Changes-to-your-code)
# - [Making dataset available](#Making-dataset-available)
# - [Set up API end point and log on](#Set-up-API-end-point-and-log-on)
# - [Submit job via API](#Submit-job-via-API)
# - [Monitor running job](#Monitor-running-job)
# - [Retrieve output and saved models](#Retrieve-output-and-saved-models)
#   - [Output](#Output)
#   - [Saved Models](#Saved-models)
# - [Debugging any issues](#Debugging-any-issues)
# - [Further information and useful links](#Further-information-and-useful-links)
#
# </div>

# %% [markdown]
# ## The big picture
# [Back to top](#Contents)
#
# This notebook details the process of taking your existing model training code and making the changes required to run the code using [IBM Watson Machine Learning](https://developer.ibm.com/linuxonpower/deep-learning-powerai/powerai-enterprise/) (WMLA) using Elastic Distributed Training.
#
# <span style='color:deeppink'>**TODO:** Link to blog with more details</span>
#
# The image below shows the various elements required to use EDT. In this notebook we will step through each of these elements in more detail. Through this process you will offload your code to a WMLA cluster, monitor the running job, retrieve the output and debug any issues seen. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/5_running_job.png) is also available.
#
# ![overall](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/5_running_job.gif)

# %% [markdown]
# ## Changes to your code
# [Back to top](#Contents)
#
# In this section we will take existing sample code and make the relevant changes required for use with EDT. An overview of these changes can be seen in the diagram below. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/2_code_adaptations.png) is also available.
#
# ![code](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/2_code_adaptations.gif)
#
# <span style='color:deeppink'>**TODO:** Add Kelvin's existing code here re changes to be made.</span>
#
# <span style='color:deeppink'>**TODO:** Add links to original code and updated code package which can be downloaded for testing / inspection.</span>

# %% [markdown]
# The original RestNet18 model comes from : https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
#
# You can find the original code (pytorch_mnist.py) and the updated code (pytorch_mnist_EDT.py) in zip file "pytorch_edt.tar.gz".
#
# You can run following to observe relative changes:
#
# diff -U4 pytorch_mnist.py pytorch_mnist_EDT.py

# %% [markdown]
# ## Making dataset available
# [Back to top](#Contents)
#
# Next we will make our dataset available to the WMLA cluster as seen in the diagram below.
#
# ![data](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/3_dataset.png)
#
# <span style='color:deeppink'>**TODO:** Add details of where this should go and with what permissions. Details of ssh commands needed here?</span>

# %% [markdown]
# 1. Ask your system admin the path of DLI_DATA_FS directory
#
# 2. ssh as an user with access to DLI_DATA_FS
#
# 3. Download dataset
#
# ```
# wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
#
# Resolving download.pytorch.org... 99.86.230.63, 99.86.230.94, 99.86.230.13, ...
# Connecting to download.pytorch.org|99.86.230.63|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: 'hymenoptera_data.zip'
#
# hymenoptera_data.zip          100%[================================================>]  45.10M  11.0MB/s    in 4.5s
#
# 2020-02-19 17:01:52 (10.1 MB/s) - 'hymenoptera_data.zip' saved [47286322/47286322]
#
# ```
#
# 3. Unzip the zip file and modify file owner/group, that is equivalent to Instance Group Execution User
# ```
# [root@colonia04 dlidata]# chown -R egoadmin:egoadmin hymenopteradata/
# [root@colonia04 hymenopteradata]# pwd
# /dlidata/hymenopteradata
# [root@colonia04 hymenopteradata]# ls -lt
# total 0
# drwxr-x--- 4 egoadmin egoadmin 34 Jan  7 23:54 MNIST
# drwxr-xr-x 4 egoadmin egoadmin 30 Jan  7 23:08 val
# drwxr-xr-x 4 egoadmin egoadmin 30 Jan  7 23:08 train
# ```
#
# 4. Take note of the path name of this dataset
# ```
# /dlidata/hymenopteradata
# ```

# %% [markdown]
# ## Set up API end point and log on
# [Back to top](#Contents)
#
# In this section we set up the API endpoint which will be used in this notebook.
#
# <span style='color:deeppink'>**TODO:** Add existing details as to how to find this, what it should look it and where to find documentation.</span>

# %% [markdown]
# 1. Source the environment
#
# $EGO_TOP is the installation directory.  The default value is /opt/ibm/spectrumcomputing
#
# ```
# . $EGO_TOP/profile.platform
#
# ```
# 2. Login
#
# ```
# egosh user logon -u Admin
# Logged on successfully
#
# ```
#
# 3. Retrieve Conductor Rest API Port
#
# ```
# egosh client view |grep -A 3 ASCD_REST_BASE_URL_1
# CLIENT NAME: ASCD_REST_BASE_URL_1
# DESCRIPTION: http://colonia04.platform:8280/platform/rest/
#
# ```
#
# 4.  Retrieve DLI (Deep Learning Impact) Rest API Port
#
# ```
# egosh client view |grep -A 3 DLPD_REST_BASE_URL_1
# CLIENT NAME: DLPD_REST_BASE_URL_1
# DESCRIPTION: http://colonia04.platform:9280/platform/rest/
#
# ```

# %% [markdown]
# ## Submit job via API
# [Back to top](#Contents)
#
# Now we need to structure our API job submission. There are various elements to this process as seen in the diagram below. Note that **this** jupyter notebook is the one referred to below. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/4_api_setup.png) is also available.
#
# ![code](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/4_api_setup.gif)
#
# <span style='color:deeppink'>**TODO:** Add existing code here re changes to be made. Include the first step as packaging the code we created in the last section.</span>
#
# <span style='color:deeppink'>**TODO:** Add existing code here to actually get the workload running! Should we add anything about watching GPU usage via various means? Or leave that to the blog?</span>

# %%
import requests, json
import pandas as pd
import datetime
# from IPython.display import display

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
# plt.rcParams['figure.figsize'] = [24, 8.0]
import seaborn as sns

pd.set_option('display.max_columns', 999)
pd.set_option('max_colwidth', 300)

import tarfile
import tempfile
import os

# %%
#Construct API call

#master_host = 'your_server'
master_host = 'colonia05.platform'
dli_rest_port = '9280'  #Deep Learning Impact Rest API Port
sc_rest_port = '8280' #Conductor Rest API Port

sc_rest_url = 'http://'+master_host+':'+sc_rest_port+'/platform/rest/conductor/v1'
dl_rest_url = 'http://'+master_host+':'+dli_rest_port+'/platform/rest/deeplearning/v1'

# User login details
wmla_user = '**** ADD HERE ****'
wmla_pwd = '**** ADD HERE ****'

wmla_user = 'Admin'
wmla_pwd = 'Admin'

myauth = (wmla_user, wmla_pwd)

# Instance Group to be used
sig_name =  '***ADD Here***'
sig_name = 'dli-edt'

# REST call variables
headers = {'Accept': 'application/json'}
print (sc_rest_url)
print (dl_rest_url)

# Model Path
model_path = '/Users/Kelvin/Github/wmla-assets/WMLA-learning-journey/pytorch_edt'
# Out:
# http://colonia05.platform:8280/platform/rest/conductor/v1
# http://colonia05.platform:9280/platform/rest/deeplearning/v1

# %% [markdown]
# ### Package model files for training
# Package the updated model files into a tar file ending with `.modelDir.tar`

# %%
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))


MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
make_tarfile(tempFile, model_path)
print(" tempFile: " + tempFile)
files = {'file': open(tempFile, 'rb')}
# Out:
#  tempFile: /var/folders/l8/5dhpt4mn5zs6rjblzhlxp5300000gp/T/tmpdn2ze3br.modelDir.tar

# %% [markdown]
# ### Log on
#
#
# Obtain login session tokens to be used for session authentication within the RESTful API. Tokens are valid for 8 hours.

# %%
r = requests.get(sc_rest_url+'/auth/logon', verify=False, auth=myauth, headers=headers) 

if r.ok:
    print ('\nLogon succeeded')
    
else: 
    print('\nLogon failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Logon succeeded

# %% [markdown]
# ### Check DL Frameworks details
#
# Check what framework plugins are available and see example execution commands.  In this demonstration we will use **edtPyTorch**

# %%
r = requests.get(dl_rest_url+'/execs/frameworks', auth=myauth, headers=headers, verify=False).json()
# Using the raw json, easier to see the examples given
print(json.dumps(r, indent=4))
# Out:
# [
#     {
#         "name": "edtKeras",
#         "description": "",
#         "desc": [
#             "Keras - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtKeras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "edtPyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtPyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "tensorflow1100",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow. Tested for Tensorflow 1.10.0.",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow1100 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PowerAICaffeIBM",
#         "description": "",
#         "desc": [
#             "IBM PowerAI IBM Caffe",
#             "NOTES:",
#             "-You must specify --model-dir flag to point to a directory containing both solver",
#             " and network files, and in the solver file, the path for the network file must not be ",
#             " a full path.",
#             "-Other paths such as snapshot, data source, in solver and network files must be",
#             " on a shared file system.",
#             "-Caffe's --gpu option will be overriden with 'all' since DLI allocates ",
#             " and manages GPUs. Use --gpuPerWorker option as shown below to request for number of GPUs.",
#             " Currently max gpuPerWorker is set to 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-dir <model-dir> --model-main lenet_solver.prototxt train",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --gpuPerWorker 2 --model-dir <model-dir> --model-main lenet_solver.prototxt train"
#         ]
#     },
#     {
#         "name": "ddlTensorFlow",
#         "description": "",
#         "desc": [
#             "Tensorflow - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start  ddlTensorFlow --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 2 python --model-main ddl_mnist.py",
#             "  --ddl_opts=_QUOTE_-mode r:2_QUOTE_ "
#         ]
#     },
#     {
#         "name": "tensorflow",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "ddlCaffe",
#         "description": "",
#         "desc": [
#             "Caffe - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start ddlCaffe --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 4 caffe train",
#             "  --model-main lenet_solver.prototxt --model-dir <modelDir>",
#             "  -ddl_update"
#         ]
#     },
#     {
#         "name": "PyTorch041",
#         "description": "",
#         "desc": [
#             "PyTorch041. Tested for torch version 0.4.1.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch041 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "keras",
#         "description": "",
#         "desc": [
#             "Keras",
#             "Examples:",
#             "$ python dlicmd.py --exec-start keras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main keras_mnist_cnn.py"
#         ]
#     },
#     {
#         "name": "disttensorflow",
#         "description": "",
#         "desc": [
#             "Distributed TensorFlow",
#             "Instead of passing parameters such as ps_hosts, worker_hosts, specify --numPs",
#             "as in example below. Parameter servers (ps) and worker hosts will be allocated",
#             "dynamically.",
#             "Use --gpuPerWorker flag to specify number of GPUs per worker.",
#             "The maximum number of worker is 2.",
#             "The maximum number of GPUs per worker is 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 1 --gpuPerWorker 1",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 2 --gpuPerWorker 1"
#         ]
#     },
#     {
#         "name": "tensorflow200_alpha",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow 2.0 preview",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow20_preview <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "daskDistribution",
#         "description": "",
#         "desc": [
#             "daskDistribution - IBM PowerAI 1.6.2",
#             "Notes:",
#             "  - Need to specify --numWorker for number of GPUs to be allocated",
#             "  - Use --model-main to specify the solver file",
#             "  - Use --dask-scheduler-args optionally to specify extra arguments",
#             "      to be passed to dask-scheduler command",
#             "  - Use --dask-cuda-worker-args optionally to specify extra arguments",
#             "      to be passed to dask-cuda-worker command",
#             "  - Use --keep-dask-logs optionally to skip cleaning up of dask cluster daemons logs",
#             "  - Use --skip-checks optionally to skip performing validations of",
#             "      the environment before launching dask cuda cluster daemons",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "Example:",
#             "python dlicmd.py --exec-start daskDistribution --master-host <masterHost> --ig <ig>",
#             "  --numWorker <n> --cs-datastore-meta type=fs --dask-scheduler-args",
#             "  \"<args of dask-scheduler command>\" --dask-cuda-worker-args",
#             "  \"<args of dask-cuda-worker command>\" --skip-checks --keep-dask-logs",
#             "  python --model-main <dask python application>"
#         ]
#     }
# ]

# %% [markdown]
# ### Arguments for API call
# Equivalent of flags used if running command directly on WMLA CLI, including:

# %%
framework_name = 'edtPyTorch' # DL Framework to use, from list given above
dataset_location = 'hymenoptera_data' # relative path of your data set 
local_dir_containing_your_code = 'pytorch_edt'
number_of_GPU = '2' # number of GPUs for elastic distribution
name_of_your_code_file = 'pytorch_mnist_EDT.py' # Main model file as opened locally above


args = '--exec-start {} \
        --cs-datastore-meta type=fs,data_path={} \
        --model-dir {} \
        --edt-options maxWorkers={} \
        --model-main {} \
        --epochs 50  \
        '.format(framework_name, dataset_location, local_dir_containing_your_code, number_of_GPU, name_of_your_code_file)

print ("args: " + args)
# Out:
# args: --exec-start edtPyTorch         --cs-datastore-meta type=fs,data_path=hymenoptera_data         --model-dir pytorch_edt         --edt-options maxWorkers=2         --model-main pytorch_mnist_EDT.py         --epochs 50

# %% [markdown]
# ### Submit Job

# %%
r = requests.post(dl_rest_url+'/execs?sigName='+sig_name+'&args='+args, files=files,
                  auth=myauth, headers=headers, verify=False)

if r.ok:
    exec_id = r.json()['id']
    sig_id = r.json()['sigId']
    driver_id = r.json()['submissionId']
    print ('\nModel submitted successfully \Driver ID: {}'.format(driver_id))
    print ('Exec ID: {}'.format(exec_id))
    print ('SIG ID: {}'.format(sig_id))
else: 
    print('\nModel submission failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Model submitted successfully \Driver ID: driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786
# Exec ID: Admin-3144597009192530-115196495
# SIG ID: 63027c69-543b-451c-9a03-9c850784725f

# %% [markdown]
# ## Monitor running job
# [Back to top](#Contents)
#
# Once the job is submitted successfully we can monitor the running job.
#
# <span style='color:deeppink'>**TODO:** Add existing code here re how to do this.</span>

# %%
# Check status of all RUNNING jobs in SIG (rerun cell to refresh)

monitor = []
monitor_output = []

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications?state=RUNNING', 
                auth=myauth, headers=headers, verify=False).json()


       
if (len(r) == 0):
    print ('No jobs running')
    
else:
    
    # Filter out the relevant information
    monitor.append([(
        job['driver']['id'],
        job['driver']['state'],
        job['apprunduration'],
        job['gpuslots'],
        job['gpumemused']['total'],
        job['gpudevutil']['total'],
    ) for job in r])

    monitor_output = pd.DataFrame([item for monitor in monitor for item in monitor])
    monitor_output.columns = [
        'Driver ID', 
        'State', 
        'Run duration (mins)',
        'GPU slots',
        'Total GPU memory used',
        'Total GPU utilsation (%) ',
    ]
    
    for job in r:
        executors = job['executors']
        

monitor_output
# Out:
#                                                          Driver ID    State  \
# 0  driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786  RUNNING
#
#    Run duration (mins)  GPU slots Total GPU memory used  \
# 0             2.113383          2                  2098
#
#   Total GPU utilsation (%)
# 0                       4.0

# %% [markdown]
# ## Retrieve output and saved models
# [Back to top](#Contents)
#
# After the job completes then we can retrieve the output, logs and saved models.

# %% [markdown]
# ### Output:  Retrieve Training Metric
#
# <span style='color:deeppink'>**TODO:** Plot the graph of metric of Loss and Accuracy.</span>

# %%
# Check status of job submitted 


r = requests.get(dl_rest_url+'/execs/'+exec_id+'/log', auth=myauth, headers=headers, verify=False).json()
print(r)
# Out:
# [2020-02-25 20:50:40] Train,	Timestamp: 1582660240617,	Global steps: 1,	Iteration: 2,	Loss: -0.00376,	Accuracy: 0.00609
# [2020-02-25 20:50:40] Train,	Timestamp: 1582660240717,	Global steps: 2,	Iteration: 3,	Loss: -0.00362,	Accuracy: 0.00617
# [2020-02-25 20:50:41] Train,	Timestamp: 1582660241166,	Global steps: 3,	Iteration: 4,	Loss: -0.10578,	Accuracy: 0.00594
# [2020-02-25 20:50:41] Train,	Timestamp: 1582660241589,	Global steps: 4,	Iteration: 0,	Loss: -0.38919,	Accuracy: 0.00712
# [2020-02-25 20:50:43] Train,	Timestamp: 1582660243836,	Global steps: 5,	Iteration: 2,	Loss: -0.67068,	Accuracy: 0.00621
# [2020-02-25 20:50:44] Train,	Timestamp: 1582660244395,	Global steps: 6,	Iteration: 3,	Loss: -0.75676,	Accuracy: 0.00639
# [2020-02-25 20:50:44] Train,	Timestamp: 1582660244893,	Global steps: 7,	Iteration: 4,	Loss: -1.00994,	Accuracy: 0.00582
# [2020-02-25 20:50:45] Train,	Timestamp: 1582660245299,	Global steps: 8,	Iteration: 0,	Loss: -2.12835,	Accuracy: 0.00519
# [2020-02-25 20:50:47] Train,	Timestamp: 1582660247478,	Global steps: 9,	Iteration: 2,	Loss: -2.49732,	Accuracy: 0.00543
# [2020-02-25 20:50:47] Train,	Timestamp: 1582660247953,	Global steps: 10,	Iteration: 3,	Loss: -2.59412,	Accuracy: 0.005
# [2020-02-25 20:50:48] Train,	Timestamp: 1582660248515,	Global steps: 11,	Iteration: 4,	Loss: -2.98492,	Accuracy: 0.00561
# [2020-02-25 20:50:48] Train,	Timestamp: 1582660248925,	Global steps: 12,	Iteration: 0,	Loss: -5.02779,	Accuracy: 0.00692
# [2020-02-25 20:50:51] Train,	Timestamp: 1582660251126,	Global steps: 13,	Iteration: 2,	Loss: -5.31193,	Accuracy: 0.00681
# [2020-02-25 20:50:51] Train,	Timestamp: 1582660251687,	Global steps: 14,	Iteration: 3,	Loss: -5.38399,	Accuracy: 0.00644
# [2020-02-25 20:50:52] Train,	Timestamp: 1582660252176,	Global steps: 15,	Iteration: 4,	Loss: -5.82434,	Accuracy: 0.00627
# [2020-02-25 20:50:52] Train,	Timestamp: 1582660252588,	Global steps: 16,	Iteration: 0,	Loss: -8.84175,	Accuracy: 0.00692
# [2020-02-25 20:50:54] Train,	Timestamp: 1582660254793,	Global steps: 17,	Iteration: 2,	Loss: -8.84429,	Accuracy: 0.00681
# [2020-02-25 20:50:55] Train,	Timestamp: 1582660255287,	Global steps: 18,	Iteration: 3,	Loss: -8.84243,	Accuracy: 0.00667
# [2020-02-25 20:53:27] Train,	Timestamp: 1582660407988,	Global steps: 185,	Iteration: 2,	Loss: -280.1988,	Accuracy: 0.00578
# [2020-02-25 20:53:28] Train,	Timestamp: 1582660408471,	Global steps: 186,	Iteration: 3,	Loss: -272.25975,	Accuracy: 0.00611
# [2020-02-25 20:53:28] Train,	Timestamp: 1582660408963,	Global steps: 187,	Iteration: 4,	Loss: -269.24267,	Accuracy: 0.00619
# [2020-02-25 20:53:29] Train,	Timestamp: 1582660409355,	Global steps: 188,	Iteration: 0,	Loss: -318.34837,	Accuracy: 0.005
# [2020-02-25 20:53:31] Train,	Timestamp: 1582660411626,	Global steps: 189,	Iteration: 2,	Loss: -287.36151,	Accuracy: 0.00578
# [2020-02-25 20:53:32] Train,	Timestamp: 1582660412171,	Global steps: 190,	Iteration: 3,	Loss: -278.96988,	Accuracy: 0.00611
# [2020-02-25 20:53:32] Train,	Timestamp: 1582660412654,	Global steps: 191,	Iteration: 4,	Loss: -275.73409,	Accuracy: 0.00602
# [2020-02-25 20:53:33] Train,	Timestamp: 1582660413056,	Global steps: 192,	Iteration: 0,	Loss: -324.8596,	Accuracy: 0.00558
# [2020-02-25 20:53:35] Train,	Timestamp: 1582660415248,	Global steps: 193,	Iteration: 2,	Loss: -291.6791,	Accuracy: 0.00509
# [2020-02-25 20:53:35] Train,	Timestamp: 1582660415745,	Global steps: 194,	Iteration: 3,	Loss: -284.12131,	Accuracy: 0.00556
# [2020-02-25 20:53:36] Train,	Timestamp: 1582660416294,	Global steps: 195,	Iteration: 4,	Loss: -281.72627,	Accuracy: 0.00586
# [2020-02-25 20:53:36] Train,	Timestamp: 1582660416694,	Global steps: 196,	Iteration: 0,	Loss: -337.02028,	Accuracy: 0.0075
# [2020-02-25 20:53:38] Train,	Timestamp: 1582660418825,	Global steps: 197,	Iteration: 2,	Loss: -303.08031,	Accuracy: 0.00716
# [2020-02-25 20:53:39] Train,	Timestamp: 1582660419323,	Global steps: 198,	Iteration: 3,	Loss: -292.73581,	Accuracy: 0.00689
# [2020-02-25 20:53:39] Train,	Timestamp: 1582660419862,	Global steps: 199,	Iteration: 4,	Loss: -288.51078,	Accuracy: 0.00652
# [2020-02-25 20:53:40] Train,	Timestamp: 1582660420267,	Global steps: 200,	Iteration: 0,	Loss: -342.9117,	Accuracy: 0.00673

# %% [markdown]
# ### Save Model

# %%
# Get model from training job - downloads zip file (with progress bar) of saved model to directory local to this notebook
# (note that you need to save model in your code using the environment variable for location)

import requests, zipfile, io
from tqdm.notebook import tqdm

r = requests.get(dl_rest_url+'/execs/'+exec_id+'/result', auth=myauth, stream=True)

total_size = int(r.headers.get('Content-Disposition').split('size=')[1])
block_size = 1024 #1 Kibibyte
t=tqdm(total=total_size, unit='iB', unit_scale=True)

with open('model.zip', 'wb') as f:
    for data in r.iter_content(block_size):
        t.update(len(data))
        f.write(data)
t.close()

# %% [markdown]
# ## Debugging any issues
# [Back to top](#Contents)
#
# In the case where you have issues during the process detailed above, there are a number of detailed logs that you can view to understand what is happening on the WMLA cluster.
#
# You can monitor Deep Learning/Machine Learning application activity,  performance and resource usage in Driver Log & Executor Log.
# - Driver Log captures issues related to dependencies and environment variable,  for example,  missing dataset or invalid execution parameter flags.
# - Executor Log records Deep Learning/Machine Learning training process.
#
# <span style='color:deeppink'>**TODO:** Overview of the various logs available and then API calls.</span>

# %% [markdown]
# ### Retrieve Training Driver Stdout Log

# %%
# Get Spectrum Conductor logs for training run - shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# load extra config from : /dlishared//conf
# Setting up spark environment on node colonia05.platform
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/dlishared/;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export FABRIC_HOME=/dlishared//fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export DLI_EXECID=Admin-3144597009192530-115196495;export PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export DATA_PATH=hymenoptera_data
# 20/02/25 20:50:17 INFO Conda variables: conda_home=/opt/anaconda3, conda_env=dlipy3, python=/opt/anaconda3/envs/dlipy3/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=
# 20/02/25 20:50:17 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/02/25 20:50:17 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/6Ma1Grj0/0	2020-02-25 20:50:17.080661890 +0100
# [D]: >> 0-1: +++ /tmp/6Ma1Grj0/1	2020-02-25 20:50:17.310662902 +0100
# [D]: >> 0-1: @@ -1,13 +1,211 @@
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@"
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@" && __conda_reactivate
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA;
# [D]: >> 0-1: + *)
# [D]: >> 0-1: + :;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PS1="$CONDA_PS1_BACKUP";
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \hash -r;
# [D]: >> 0-1: + \local ask_conda;
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \rehash;
# [D]: >> 0-1: + \unset CONDA_PS1_BACKUP;
# [D]: >> 0-1: + __conda_activate "$cmd" "$@"
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + activate | deactivate)
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix "$cmd" "$@")" || \return $?;
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix reactivate)" || \return $?;
# [D]: >> 0-1: + case "$cmd" in
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + esac;
# [D]: >> 0-1: + eval "export $save_var=$orig_val";
# [D]: >> 0-1: + eval "orig_val=\${${orig_var}-unset}";
# [D]: >> 0-1: + eval "save_val=\${${save_var}-xxx}";
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "$save_val" = xxx ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [ -n "${POSH_VERSION:+x}" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + install | update | upgrade | remove | uninstall)
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + local orig_val;
# [D]: >> 0-1: + local orig_var="$2";
# [D]: >> 0-1: + local save_val;
# [D]: >> 0-1: + local save_var="POWERAI_${package}_${orig_var}";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC___conda_activate()=() {  if [ -n "${CONDA_PS1_BACKUP:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_hashr()=() {  if [ -n "${ZSH_VERSION:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_reactivate()=() {  \local ask_conda;
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_conda()=() {  if [ "$#" -lt 1 ]; then
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_powerai_save_var_initial()=() {  local package="$1";
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1: +CAFFE_BIN=/opt/anaconda3/envs/dlipy3/bin
# [D]: >> 0-1: +COMPONENT=tensorflow
# [D]: >> 0-1: +CONDA_DEFAULT_ENV=dlipy3
# [D]: >> 0-1: +CONDA_EXE=/opt/anaconda3/bin/conda
# [D]: >> 0-1: +CONDA_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +CONDA_PROMPT_MODIFIER=(dlipy3)
# [D]: >> 0-1: +CONDA_SHLVL=1
# [D]: >> 0-1: +CUDA_TOOLKIT_LIB_PATH=/opt/anaconda3/envs/dlipy3/cuda/lib:
# [D]: >> 0-1: +DATA_PATH=hymenoptera_data
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=dlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1:  DLI_CONDA_HOME=/opt/anaconda3
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/dlidata/
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=Admin-3144597009192530-115196495
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/dlishared//fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1:  DLI_IS_DRIVER=true
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/dliresult/
# [D]: >> 0-1: +DLI_SHARED_FS=/dlishared/
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1:  DL_NFS_PATH=/dlishared/
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1:  EGO_CONFDIR=/dlishared/conductor_share_top/kernel/conf
# [D]: >> 0-1: @@ -16,15 +214,35 @@
# [D]: >> 0-1:  EGO_LIBDIR=/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1:  EGO_MASTER_LIST_PEM=colonia05.platform
# [D]: >> 0-1:  EGO_TOP=/opt/ibm/spectrumcomputing
# [D]: >> 0-1: +FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +GREP=/bin/grep
# [D]: >> 0-1:  HADOOP_CONF_DIR=
# [D]: >> 0-1:  HADOOP_HOME=
# [D]: >> 0-1:  HOME=/home/egoadmin
# [D]: >> 0-1: +HOSTNAME_F=colonia05.platform
# [D]: >> 0-1:  JAVA_HOME=/opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1580185149401
# [D]: >> 0-1: -LD_LIBRARY_PATH=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1: +MPI_ROOT=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OMP_NUM_THREADS=16
# [D]: >> 0-1: +OPAL_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +POWERAI_caffe_CAFFE_BIN=unset
# [D]: >> 0-1: +POWERAI_caffe_OMP_NUM_THREADS=16
# [D]: >> 0-1: +POWERAI_pytorch_OMP_NUM_THREADS=16
# [D]: >> 0-1: +PS1=(dlipy3)
# [D]: >> 0-1:  PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1:  PWD=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786
# [D]: >> 0-1: +PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=egoadmin
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -83,6 +301,34 @@
# [D]: >> 0-1:  SPARK_PRINT_LAUNCH_COMMAND=1
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=egoadmin
# [D]: >> 0-1: +SYS_PYTHON_MAJOR=3
# [D]: >> 0-1: +SYS_PYTHON_MINOR=6
# [D]: >> 0-1: +TF_INCLUDE_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/include
# [D]: >> 0-1: +TF_LIBRARY_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1: +TF_PKG_PATH=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1:  USER=egoadmin
# [D]: >> 0-1: +USER_UID=1001
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1: +_CE_CONDA=
# [D]: >> 0-1: +_CE_M=
# [D]: >> 0-1: +_CONDA_ROOT=/opt/anaconda3
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/6Ma1Grj0
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to
# Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data
# Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/
# 20/02/25 20:50:17 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=
# DLI_CONDA_HOME=/opt/anaconda3
# DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# DL_NFS_PATH=/dlishared/
# DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=egoadmin
# USER_UID=1001
# DLI_EXECID=Admin-3144597009192530-115196495
# SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/
# 20/02/25 20:50:17 INFO finish spark environment setup.
# /dlishared//fabric/1.2.3/libs/fabric.zip
# <> DATA_DIR /dlidata//hymenoptera_data
# <> RESULT_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# <> LOG_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# <> SAVED_MODEL_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# Using pytorch backend.
# /dlishared//fabric/1.2.3/libs/fabric.zip/fabric_zmqservice/rep_stream_handler.py:15: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
# libunformatworker.so loaded successfully
# Using spark scheduler.
# > fabric loaded from /dlishared//fabric/1.2.3/libs/fabric.zip
# dataDir is: /dlidata//hymenoptera_data
# model_path: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model/saved_model
# tb_directory: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/tb
# sys.argv:  ['.//pytorch_mnist_EDT.py', '--dataControlSchema', '0', '--weightSyncInterval', '5', '--numWorker', '2', '--usegpuNumPerWorker', '1', '--commIPNetwork', '10.3.64.217/24', '--isTest', 'true', '--globalStep', 'null', '--testIter', '10', '--testInterval', 'None', '--isESE', 'true', '--mode', '1', '--execPathParam', '/dlishared//fabric/1.2.3', '--train_dir', '/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt', '--model_path', '/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt', '--epochs', '50']
# args:  Namespace(batchsize=64, epochs=50, numWorker=2)
# numWorker args: 2
# batch_size args: 64
# epochs args: 50
# /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip/pyspark/context.py:248: RuntimeWarning: Failed to add file [.//fabric.zip] speficied in 'spark.submit.pyFiles' to Python path:
#   /dlishared//fabric/1.2.3/libs/fabric.zip
#   /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-9816d2de-3e1b-4e4a-b92e-de4e8c3d96f2/userFiles-8b7cdccd-cf8a-4c92-b2b3-baf7461a8032
#   /dlishared//fabric/1.2.3/libs/fabric.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786/fabric.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/py4j-0.10.7-src.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/spark-core_2.11-2.3.3.jar
#   /dlishared/tools/dli_utils
#   /dlishared/fabric/1.2.3/libs/fabric.zip
#   /dlishared/fabric/1.2.3/tools
#   /dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786
#   /opt/anaconda3/envs/dlipy3/lib/python36.zip
#   /opt/anaconda3/envs/dlipy3/lib/python3.6
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/lib-dynload
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tflms-2.0.1-py3.6.egg
#   RuntimeWarning)
# start message server 10.3.64.217:43969
# 2020-02-25 20:50:24,247 - root - INFO - client connect to server url: 10.3.64.217:43969
# --------START TRAINING--------
# kelvin: value:  -0.0037579904310405254
# kelvin: value:  -0.003620576928369701
# kelvin: value:  -0.10578026180155575
# kelvin: value:  -0.38918850972102237
# kelvin: value:  -0.6706798323269548
# kelvin: value:  -0.7567619217766656
# kelvin: value:  -1.0099367157357637
# kelvin: value:  -2.1283528254582333
# kelvin: value:  -2.4973164262442755
# kelvin: value:  -2.594121805826823
# kelvin: value:  -2.984923065685835
# kelvin: value:  -5.027789189265325
# kelvin: value:  -5.311933583226697
# kelvin: value:  -309.8224534254808
# kelvin: value:  -280.1987978178879
# kelvin: value:  -272.2597547743056
# kelvin: value:  -269.24266777663934
# kelvin: value:  -318.3483698918269
# kelvin: value:  -287.3615133351293
# kelvin: value:  -278.9698784722222
# kelvin: value:  -275.7340868340164
# kelvin: value:  -324.8596003605769
# kelvin: value:  -291.6790981950431
# kelvin: value:  -284.1213107638889
# kelvin: value:  -281.7262743340164
# kelvin: value:  -337.0202824519231
# kelvin: value:  -303.08031384698273
# kelvin: value:  -292.7358072916667
# kelvin: value:  -288.51078221055326
# kelvin: value:  -342.9116962139423
# --------END TRAINING: completed epoch 50 in time 197.70525574684143 --------

# %% [markdown]
# ### Retrieve Training Driver Stderr Log

# %%
# shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# +++ export SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ '[' -z '' ']'
# +++ export GLOG_logtostderr=true
# +++ GLOG_logtostderr=true
# +++ '[' -z '' -a -n '' -a -f '' ']'
# +++ '[' -n '' -a -f '' ']'
# +++ '[' true = true ']'
# +++ checkGPUMemory
# +++ echo 'Check GPU memory utilization'
# +++ echo 'CUDA_VISIBLE_DEVICES is set to '
# +++ utilization_high=1
# +++ timeout_secs=30
# +++ time_sleep=0
# +++ '[' 0 -lt 30 -a 1 -eq 1 ']'
# +++ utilization_high=0
# ++++ echo
# ++++ tr , ' '
# +++ '[' 0 -eq 1 ']'
# +++ '[' 0 -lt 30 -a 0 -eq 1 ']'
# +++ '[' 0 -eq 1 ']'
# +++ export NCCL_P2P_DISABLE=1
# +++ NCCL_P2P_DISABLE=1
# +++ handle_BYOF_EDT_Job
# +++ '[' true = true -a Admin-3144597009192530-115196495x '!=' x ']'
# +++ '[' /dlidata/ '!=' '' ']'
# +++ export DATA_DIR=/dlidata//hymenoptera_data
# +++ DATA_DIR=/dlidata//hymenoptera_data
# +++ local batch_path=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ export RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ '[' -n /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/ ']'
# ++++ basename /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/
# +++ local log_subdir=driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# +++ export LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# +++ LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# +++ mkdir -p /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform
# +++ export SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# +++ SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# +++ echo 'Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data'
# +++ echo 'Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495'
# +++ echo 'Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform'
# +++ echo 'Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model'
# +++ echo /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/
# +++ grep logs/driver-
# +++ '[' '!' -L /var/tmp/elk_logs/Admin-3144597009192530-115196495 ']'
# +++ ln -s /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495 /var/tmp/elk_logs/Admin-3144597009192530-115196495
# +++ trace_env
# +++ log_info 'Trace envrionment'
# ++++ date '+%y/%m/%d %H:%M:%S'
# +++ echo '20/02/25 20:50:17 INFO Trace envrionment'
# +++ echo CUDA_VISIBLE_DEVICES=
# +++ echo DLI_CONDA_HOME=/opt/anaconda3
# +++ echo DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# +++ echo DL_NFS_PATH=/dlishared/
# +++ echo DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# +++ echo DLI_LOGGER_LEVEL=debug
# +++ echo PYTHON_VERSION=
# +++ echo SPARK_EGO_USER_FIRST_JARS=
# +++ echo 'LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib'
# +++ echo PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# +++ echo PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# +++ echo RDMA_ENABLED=false
# +++ echo RDMA_BUFFER_SIZE=1073741824
# +++ echo RDMA_DEVICE_NAME=
# +++ echo RDMA_DEVICE_PORT=
# +++ echo DLI_IS_ELASTIC=true
# +++ echo USER=egoadmin
# +++ echo USER_UID=1001
# +++ echo DLI_EXECID=Admin-3144597009192530-115196495
# +++ echo SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786.colonia05.platform/
# +++ false
# +++ set +x
# Spark Command: /opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le/bin/java -cp /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/*:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/conf/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/* -Dspark.files=file:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py -Dspark.master=spark://colonia05.platform:7081 -Dspark.submit.deployMode=cluster -Dspark.ego.vemkd.principal=None -Dspark.akka.frameSize=2047 -Dspark.executorEnv.DLI_EXTRA_CONF=... -Dspark.ssl.ego.workload.enabled=false -Dspark.shuffle.reduceLocality.enabled=false -Dspark.ego.dl.app=true -Dspark.ssl.ego.gui.enabled=false -Dspark.local.dir=/tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin -Dspark.ego.driverEnv.DLI_SPARK_APP_NAME=ElasticTrain-PyTorch -Dspark.kryoserializer.buffer.max=500m -Dspark.app.name=ElasticTrain-PyTorch-DLIBatch-Admin-dli-edt-pytorch_mnist_EDT.py -Dspark.ssl.enabled=false -Dspark.ego.executor.container.type=normal -Dspark.rpc.framesize=2047 -Dspark.executorEnv.DLI_SPARK_APP_NAME=ElasticTrain-PyTorch -Dspark.shuffle.service.port=7341 -Dspark.driver.memory=4G -Dspark.executor.memory=4G -Dspark.executorEnv.LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH -Dspark.ego.driver.container.type=normal -Dspark.ego.gpu.executor.slots.max=1 -Dspark.shuffle.service.enabled=true -Dspark.ego.driverEnv.DLI_IS_DRIVER=true -Dspark.executor.extraJavaOptions=-Djava.security.egd=file:/dev/./urandom -Dspark.ego.driverEnv.DLI_EXTRA_CONF=... -Dspark.ego.gpu.app=true -Dspark.ego.presend.tasks=0 -Dspark.ego.driverEnv.PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt -Dspark.driver.extraLibraryPath=/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH -Dspark.driver.supervise=false -Dspark.FABRIC_HOME=/dlishared//fabric/1.2.3 -Dspark.driver.maxResultSize=2g -Dspark.ego.uname=Admin -Dspark.ego.gpu.slots.max=2 -Dspark.master.rest.port=6070 -Dspark.ego.priority=5000 -Xmx4G org.apache.spark.deploy.ego.EGOClusterDriverWrapper {{WORKER_URL}} file:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py org.apache.spark.deploy.PythonRunner --primary-py-file pytorch_mnist_EDT.py --py-files fabric.zip --dataControlSchema 0 --weightSyncInterval 5 --numWorker 2 --usegpuNumPerWorker 1 --commIPNetwork 10.3.64.217/24 --isTest true --globalStep null --testIter 10 --testInterval None --isESE true --mode 1 --execPathParam /dlishared//fabric/1.2.3 --train_dir /dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt --model_path /dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt --epochs 50
# ========================================
# 20/02/25 20:50:19 INFO EGOClusterDriverWrapper: Started daemon with process name: 1985@colonia05.platform
# 20/02/25 20:50:19 INFO SignalUtils: Registered signal handler for TERM
# 20/02/25 20:50:19 INFO SignalUtils: Registered signal handler for HUP
# 20/02/25 20:50:19 INFO SignalUtils: Registered signal handler for INT
# 20/02/25 20:50:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 20/02/25 20:50:19 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:19 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:20 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:20 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:20 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:20 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:20 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:20 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:20 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:20 INFO Utils: Successfully started service 'EGOClusterDriverWrapper-driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786' on port 39654.
# 20/02/25 20:50:20 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7081 after 32 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:20 INFO EGOClusterDriverWrapper: Receive ext  by Master.
# 20/02/25 20:50:20 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:20 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:20 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:20 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:20 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:20 INFO EGOClusterDriverWrapper: Fetching file from file:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py to .//pytorch_mnist_EDT.py
# 20/02/25 20:50:20 INFO Utils: Copying /dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py to /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786/./pytorch_mnist_EDT.py
# 20/02/25 20:50:20 INFO EGOClusterDriverWrapper: Starting the user JAR in a separate Thread
# 20/02/25 20:50:20 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:20 INFO EGOClusterDriverWrapper: Waiting for spark context initialization ... 0
# 20/02/25 20:50:22 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:22 INFO SparkContext: Running Spark version 2.3.3
# 20/02/25 20:50:22 WARN SparkConf: In Spark 1.0 and later spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone and LOCAL_DIRS in YARN).
# 20/02/25 20:50:22 INFO SparkContext: Submitted application: ElasticTrain-PyTorch-DLIBatch-Admin-dli-edt-pytorch_mnist_EDT.py
# 20/02/25 20:50:22 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:22 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:22 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:22 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:22 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:22 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:22 INFO Utils: Successfully started service 'sparkDriver' on port 42336.
# 20/02/25 20:50:22 INFO SparkEnv: Registering MapOutputTracker
# 20/02/25 20:50:22 INFO SparkEnv: Registering BlockManagerMaster
# 20/02/25 20:50:22 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/02/25 20:50:22 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/02/25 20:50:22 INFO MemoryStore: MemoryStore started with capacity 2.2 GB
# 20/02/25 20:50:22 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/02/25 20:50:23 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:23 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:23 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:23 INFO Utils: Successfully started service 'SparkUI' on port 42351.
# 20/02/25 20:50:23 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://colonia05.platform:42351
# 20/02/25 20:50:23 INFO SparkContext: Added file file:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py at spark://colonia05.platform:42336/files/pytorch_mnist_EDT.py with timestamp 1582660223432
# 20/02/25 20:50:23 INFO Utils: Copying /dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt/pytorch_mnist_EDT.py to /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-9816d2de-3e1b-4e4a-b92e-de4e8c3d96f2/userFiles-8b7cdccd-cf8a-4c92-b2b3-baf7461a8032/pytorch_mnist_EDT.py
# 20/02/25 20:50:23 INFO EGOSparkDockerConfig: Executor Container Type is 'normal' from local configuration file.
# 20/02/25 20:50:23 INFO EGOSparkDockerConfig: Driver Container Type is 'normal' from local configuration file.
# 20/02/25 20:50:23 INFO EGOSparkDockerConfig: spark-ego-docker.conf will not be parsed as docker is not defined as any container type.
# 20/02/25 20:50:23 INFO EGOFineGrainedSchedulerBackend: setting reserve=0, priority=5000, limit=2147483647, gpuLimit=2, master=[Ljava.lang.String;@f081924b
# 20/02/25 20:50:23 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:23 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:23 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:23 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:23 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:23 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:23 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:23 INFO Utils: Successfully started service 'driverWrapper' on port 38338.
# 20/02/25 20:50:23 INFO EGOAppClient$ClientEndpoint: Sending the first request to master spark://colonia05.platform:7081...
# 20/02/25 20:50:23 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7081 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:23 INFO EGOAppClient$ClientEndpoint: Successfully obtained the first response from master colonia05.platform:7081
# 20/02/25 20:50:23 INFO EGOAppClient$ClientEndpoint: Connecting to master spark://colonia05.platform:7081...
# 20/02/25 20:50:23 INFO EGOAppClient$ClientEndpoint: Received driver endpoint NettyRpcEndpointRef(spark://DriverWrapper@10.3.64.217:39654), colonia05.platform
# 20/02/25 20:50:23 INFO TransportClientFactory: Successfully created connection to /10.3.64.217:39654 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:23 INFO EGOFineGrainedSchedulerBackend: Connected to Spark cluster with app ID app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4
# 20/02/25 20:50:23 INFO EGOFineGrainedSchedulerBackend: Application registered successfully as app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4, executor Container type is normal
# 20/02/25 20:50:23 INFO DiskBlockManager: Init the driver local dir
# 20/02/25 20:50:23 INFO DiskBlockManager: Created local directory at /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/blockmgr-948152b0-c120-408c-813d-bbc52fb4bbb3
# 20/02/25 20:50:23 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:23 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 42298.
# 20/02/25 20:50:23 INFO NettyBlockTransferService: Server created on colonia05.platform:42298
# 20/02/25 20:50:23 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/25 20:50:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, colonia05.platform, 42298, None)
# 20/02/25 20:50:23 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:42298 with 2.2 GB RAM, BlockManagerId(driver, colonia05.platform, 42298, None)
# 20/02/25 20:50:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, colonia05.platform, 42298, None)
# 20/02/25 20:50:23 INFO BlockManager: external shuffle service port = 7341
# 20/02/25 20:50:23 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, colonia05.platform, 42298, None)
# 20/02/25 20:50:24 INFO EGODeployScheduler: Spark context initialized.
# 20/02/25 20:50:24 INFO server: pyspark script logger initialized
# 20/02/25 20:50:24 INFO server: start logging thread for mao
# 20/02/25 20:50:25 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 672.0 B, free 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece1 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece2 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece3 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece4 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece5 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece6 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece7 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece8 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece9 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece10 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece11 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece12 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece13 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece14 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece15 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece16 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece17 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece18 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece19 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:42298 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_0_piece20 stored as bytes in memory (estimated size 3.0 MB, free 2.1 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:42298 (size: 3.0 MB, free: 2.1 GB)
# 20/02/25 20:50:26 INFO SparkContext: Created broadcast 0 from collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64
# 20/02/25 20:50:26 INFO SparkContext: Starting job: collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64
# 20/02/25 20:50:26 INFO DAGScheduler: Got job 0 (collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64) with 2 output partitions
# 20/02/25 20:50:26 INFO DAGScheduler: Final stage: ResultStage 0 (collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64)
# 20/02/25 20:50:26 INFO DAGScheduler: Parents of final stage: List()
# 20/02/25 20:50:26 INFO DAGScheduler: Missing parents: List()
# 20/02/25 20:50:26 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[1] at collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64), which has no missing parents
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 6.0 KB, free 2.1 GB)
# 20/02/25 20:50:26 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 3.9 KB, free 2.1 GB)
# 20/02/25 20:50:26 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:42298 (size: 3.9 KB, free: 2.1 GB)
# 20/02/25 20:50:26 INFO EGOFineGrainedSchedulerBackend: onStageSubmitted: stageId(0)
# 20/02/25 20:50:26 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1042
# 20/02/25 20:50:26 INFO EGOFineGrainedSchedulerBackend: RDD 1: GPU
# 20/02/25 20:50:26 INFO EGOFineGrainedSchedulerBackend: RDD 0: GPU
# 20/02/25 20:50:26 INFO EGOFineGrainedSchedulerBackend: onStageSubmitted: stageId is 0, rg is GPU
# 20/02/25 20:50:26 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 0 (PythonRDD[1] at collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64) (first 15 tasks are for partitions Vector(0, 1))
# 20/02/25 20:50:26 INFO EGODeployScheduler: Adding task set 0.0 with 2 tasks
# 20/02/25 20:50:27 INFO EGOFineGrainedSchedulerBackend: <EVENT> Spark driver 63027c69-543b-451c-9a03-9c850784725f-dli-edt-sparkms-batch-1 workload coming in
# 20/02/25 20:50:32 INFO EGOFineGrainedSchedulerBackend: Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.3.64.217:33084) with ID 1-72825eba-bb18-4d19-bf58-783c42867e4e
# 20/02/25 20:50:32 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, colonia05.platform, executor 1-72825eba-bb18-4d19-bf58-783c42867e4e, partition 0, PROCESS_LOCAL, 7899 bytes)
# 20/02/25 20:50:32 INFO EGOFineGrainedSchedulerBackend: onTaskStart: TID 0 ( Index 0 ) on 1-72825eba-bb18-4d19-bf58-783c42867e4e
# 20/02/25 20:50:32 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:41550 with 2.2 GB RAM, BlockManagerId(1-72825eba-bb18-4d19-bf58-783c42867e4e, colonia05.platform, 41550, None)
# 20/02/25 20:50:32 INFO EGOFineGrainedSchedulerBackend: Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.3.64.217:33086) with ID 0-28c4b5ed-3f65-40bc-989e-07dc04c49677
# 20/02/25 20:50:32 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, colonia05.platform, executor 0-28c4b5ed-3f65-40bc-989e-07dc04c49677, partition 1, PROCESS_LOCAL, 7899 bytes)
# 20/02/25 20:50:32 INFO EGOFineGrainedSchedulerBackend: onTaskStart: TID 1 ( Index 1 ) on 0-28c4b5ed-3f65-40bc-989e-07dc04c49677
# 20/02/25 20:50:33 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:42433 with 2.2 GB RAM, BlockManagerId(0-28c4b5ed-3f65-40bc-989e-07dc04c49677, colonia05.platform, 42433, None)
# 20/02/25 20:50:33 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:41550 (size: 3.9 KB, free: 2.2 GB)
# 20/02/25 20:50:33 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:42433 (size: 3.9 KB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.disk.diskSpaceUsed_MB, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxMem_MB, value=6832
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxOffHeapMem_MB, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxOnHeapMem_MB, value=6832
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.memUsed_MB, value=107
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.offHeapMemUsed_MB, value=0
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.onHeapMemUsed_MB, value=111
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingMem_MB, value=6721
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingOffHeapMem_MB, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingOnHeapMem_MB, value=6721
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.job.activeJobs, value=1
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.job.allJobs, value=1
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.failedStages, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.runningStages, value=1
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.waitingStages, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.size, value=0
# 20/02/25 20:50:34 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.numEventsPosted, count=42
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/25 20:50:34 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/25 20:50:34 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:34 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:34 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:34 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.messageProcessingTime, count=5, min=0.012038, max=102.09416999999999, mean=20.048462439334003, stddev=39.23434826755844, median=2.3559159999999997, p75=2.762099, p95=102.09416999999999, p98=102.09416999999999, p99=102.09416999999999, p999=102.09416999999999, mean_rate=0.4689040459543814, m1=0.24797335122240602, m5=0.20991712770702953, m15=0.20332409119706196, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=42, min=0.0018709999999999998, max=2.72212, mean=0.16590641533660722, stddev=0.5493700028343236, median=0.003646, p75=0.008950999999999999, p95=0.883157, p98=2.72212, p99=2.72212, p999=2.72212, mean_rate=3.911790929608324, m1=5.064186541443158, m5=5.330580106050794, m15=5.376731361620567, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=42, min=0.001764, max=2.291805, mean=0.08740331157583828, stddev=0.37079337900332876, median=0.003851, p75=0.00791, p95=0.251759, p98=2.291805, p99=2.291805, p999=2.291805, mean_rate=3.9399832590355226, m1=5.096168775591429, m5=5.337191524522147, m15=5.378947422418609, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=42, min=0.013812999999999999, max=42.740367, mean=2.2239432606357137, stddev=7.072875986508216, median=0.065104, p75=0.18558, p95=12.09792, p98=42.740367, p99=42.740367, p999=42.740367, mean_rate=3.665490628064442, m1=4.968239838998346, m5=5.310745850636735, m15=5.370083179226443, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=42, min=0.058244, max=42.884449, mean=2.4209710783915956, stddev=7.144591161743369, median=0.194823, p75=0.439336, p95=12.192069, p98=42.884449, p99=42.884449, p999=42.884449, mean_rate=3.664762150187619, m1=4.968239838998346, m5=5.310745850636735, m15=5.370083179226443, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=42, min=0.025859999999999998, max=3.7509319999999997, mean=0.24030170742254778, stddev=0.6570708754833036, median=0.059650999999999996, p75=0.084342, p95=0.934627, p98=3.7509319999999997, p99=3.7509319999999997, p999=3.7509319999999997, mean_rate=3.9100142159971036, m1=5.064186541443158, m5=5.330580106050794, m15=5.376731361620567, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:41550 (size: 3.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:42433 (size: 3.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.2 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:41550 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:34 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:42433 (size: 4.0 MB, free: 2.1 GB)
# 20/02/25 20:50:36 INFO server: init data batch index with size of 244 in epoch 50 iter 4
# 20/02/25 20:50:36 INFO server: Total iterations: 200
# 20/02/25 20:50:36 INFO server: ignore duplicate setting
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d: action: ADD_NODE, server gs 0, server epoch 0, client tid 0, client epoch 0
# 20/02/25 20:50:39 INFO server: - insert node: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 in pool {'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0'}
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: ACQUIRE_TASK, server gs 0, server epoch 0, client tid 0, client epoch 0
# 20/02/25 20:50:39 INFO server: handleAcquireTask: curr_total_itr=0 acc_count=0 total_itrs=4 gs=0
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: next_sync_step:2 current:0, old topo 0, new topo 0
# 20/02/25 20:50:39 INFO server: - sync boundary 0 begin-
# 20/02/25 20:50:39 INFO server: Push weight worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 -> worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0, already inited list set()
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: send message exit CtrlMsg.PUSH_WEIGHT tid 0
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: send message exit CtrlMsg.PULL_WEIGHT tid 0
# 20/02/25 20:50:39 INFO server: ! insert batch_idx 0 into cache
# 20/02/25 20:50:39 INFO server: ! insert batch_idx 1 into cache
# 20/02/25 20:50:39 INFO server: ! insert batch_idx 2 into cache
# 20/02/25 20:50:39 INFO server: ! insert batch_idx 3 into cache
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: newTask: tid 1 pend list {1}, presend {0, 1, 2, 3}
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: send message exit CtrlMsg.NEW_TASK tid 1
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: read message exit CtrlMsg.PUSH_WEIGHT tid 0
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8: action: ADD_NODE, server gs 1, server epoch 0, client tid 0, client epoch 0
# 20/02/25 20:50:39 INFO server: - insert node: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1 in pool {'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'worker-ecba1632-2d33-4437-b015-9d6b081514a8:1'}
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: read message exit CtrlMsg.PULL_WEIGHT tid 0
# 20/02/25 20:50:39 INFO server: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: read message exit CtrlMsg.NEW_TASK tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: action: ACQUIRE_TASK, server gs 1, server epoch 0, client tid 0, client epoch 0
# 20/02/25 20:50:39 INFO server: handleAcquireTask: curr_total_itr=1 acc_count=0 total_itrs=4 gs=0
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: action: next_sync_step:2 current:1, old topo 0, new topo 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: status: cache empty, tid 1 pend list {1}, presend set(), unhandled batches 0
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1 action: cache emtpy wait, util next sync
# 20/02/25 20:50:39 INFO server: get_next_batch_idx 0
# 20/02/25 20:50:39 INFO server: Pull Index 0, starter 43, size 64, server ep 0, gs 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: get_next_batch_idx 1
# 20/02/25 20:50:39 INFO server: Pull Index 1, starter 189, size 64, server ep 0, gs 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/25 20:50:39 INFO server: worker-ecba1632-2d33-4437-b015-9d6b081514a8:1: read message exit CtrlMsg.EMPTY tid 1
# ...
# 20/02/25 20:53:41 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.numEventsPosted, count=118
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/25 20:53:41 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/25 20:53:41 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:41 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:41 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:41 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.messageProcessingTime, count=7, min=0.012038, max=102.09416999999999, mean=8.739290394233763, stddev=14.626716977141118, median=7.065106, p75=7.126326, p95=7.126326, p98=102.09416999999999, p99=102.09416999999999, p999=102.09416999999999, mean_rate=0.035271093403099175, m1=0.011358745232531359, m5=0.11330079176168176, m15=0.1655454300202656, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=118, min=0.001725, max=2.72212, mean=0.0216542498785759, stddev=0.18335189114902203, median=0.0038989999999999997, p75=0.00484, p95=0.018986, p98=0.036635, p99=0.19128799999999999, p999=2.72212, mean_rate=0.5943503001963991, m1=0.4474004020029315, m5=3.042752005759188, m15=4.451951575985767, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=117, min=0.001764, max=2.291805, mean=0.06863276055371086, stddev=0.19980104681265504, median=0.0034609999999999997, p75=0.004523, p95=0.5829909999999999, p98=0.5829909999999999, p99=0.5829909999999999, p999=2.291805, mean_rate=0.5895426178551273, m1=0.4472730885901725, m5=3.042692033195663, m15=4.451941524171518, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=118, min=0.01162, max=42.740367, mean=1.4472611086157663, stddev=2.8778621898763834, median=1.1088559999999998, p75=1.437516, p95=6.6418029999999995, p98=6.6418029999999995, p99=12.09792, p999=42.740367, mean_rate=0.5922018229326655, m1=0.4477823422412084, m5=3.042931923449764, m15=4.451981731428525, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=117, min=0.058244, max=42.884449, mean=1.6592073641604046, stddev=3.0022106444643524, median=1.183181, p75=1.5039829999999998, p95=7.292649, p98=7.292649, p99=12.192069, p999=42.884449, mean_rate=0.5871792335790539, m1=0.4477823422412084, m5=3.042931923449764, m15=4.451981731428525, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:41 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=118, min=0.024779, max=3.7509319999999997, mean=0.07053070486295544, stddev=0.22038601045551043, median=0.047189999999999996, p75=0.05645, p95=0.122719, p98=0.178059, p99=0.282595, p999=3.7509319999999997, mean_rate=0.5943434922856874, m1=0.4474004020029315, m5=3.042752005759188, m15=4.451951575985767, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:42 INFO EGOFineGrainedSchedulerBackend: Spark driver enters idle mode
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.disk.diskSpaceUsed_MB, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxMem_MB, value=6832
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxOffHeapMem_MB, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.maxOnHeapMem_MB, value=6832
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.memUsed_MB, value=249
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.offHeapMemUsed_MB, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.onHeapMemUsed_MB, value=249
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingMem_MB, value=6583
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingOffHeapMem_MB, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.BlockManager.memory.remainingOnHeapMem_MB, value=6583
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.job.activeJobs, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.job.allJobs, value=1
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.failedStages, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.runningStages, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.stage.waitingStages, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.size, value=0
# 20/02/25 20:53:44 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.numEventsPosted, count=118
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/25 20:53:44 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/25 20:53:44 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:44 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:44 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:44 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.DAGScheduler.messageProcessingTime, count=7, min=0.012038, max=102.09416999999999, mean=8.739290394233763, stddev=14.626716977141118, median=7.065106, p75=7.126326, p95=7.126326, p98=102.09416999999999, p99=102.09416999999999, p999=102.09416999999999, mean_rate=0.03489150374542273, m1=0.04243278425665861, m5=0.11803951286435452, m15=0.16684434397389988, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=118, min=0.001725, max=2.72212, mean=0.0216542498785759, stddev=0.18335189114902203, median=0.0038989999999999997, p75=0.00484, p95=0.018986, p98=0.036635, p99=0.19128799999999999, p999=2.72212, mean_rate=0.5879558710941707, m1=0.5235660604846585, m5=3.0155997033723665, m15=4.435043300373111, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=118, min=0.001764, max=518.8239689999999, mean=23.31455397949984, stddev=107.32479190008776, median=0.0034609999999999997, p75=0.00917, p95=0.5829909999999999, p98=518.8239689999999, p99=518.8239689999999, p999=518.8239689999999, mean_rate=0.5881819575167814, m1=0.5234489264903421, m5=3.015540722068127, m15=4.43503330424744, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=118, min=0.01162, max=42.740367, mean=1.4472611086157663, stddev=2.8778621898763834, median=1.1088559999999998, p75=1.437516, p95=6.6418029999999995, p98=6.6418029999999995, p99=12.09792, p999=42.740367, mean_rate=0.5858528764746637, m1=0.5239174624676073, m5=3.0157766472850858, m15=4.435073288750131, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=118, min=0.058244, max=518.944692, mean=24.839263131333723, stddev=107.06073403272578, median=1.190486, p75=1.5840589999999999, p95=21.675431, p98=518.944692, p99=518.944692, p999=518.944692, mean_rate=0.5858487984453928, m1=0.5239174624676073, m5=3.0157766472850858, m15=4.435073288750131, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:44 INFO metrics: type=TIMER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=118, min=0.024779, max=3.7509319999999997, mean=0.07053070486295544, stddev=0.22038601045551043, median=0.047189999999999996, p75=0.05645, p95=0.122719, p98=0.178059, p99=0.282595, p999=3.7509319999999997, mean_rate=0.5879483718624512, m1=0.5235660604846585, m5=3.0155997033723665, m15=4.435043300373111, rate_unit=events/second, duration_unit=milliseconds
# 20/02/25 20:53:52 INFO EGODeployScheduler: Spark context stopped.
# 20/02/25 20:53:52 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/02/25 20:53:52 INFO MemoryStore: MemoryStore cleared
# 20/02/25 20:53:52 INFO BlockManager: BlockManager stopped
# 20/02/25 20:53:52 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/02/25 20:53:52 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/02/25 20:53:52 INFO SparkContext: Successfully stopped SparkContext
# 20/02/25 20:53:53 INFO EGOClusterDriverWrapper: Final app status: 0, exitCode: 0
# 20/02/25 20:53:53 INFO EGOClusterDriverWrapper: Sending driver program state to master
# 20/02/25 20:53:53 INFO ShutdownHookManager: Shutdown hook called
# 20/02/25 20:53:53 INFO ShutdownHookManager: Deleting directory /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-9816d2de-3e1b-4e4a-b92e-de4e8c3d96f2/pyspark-d87415bf-6ee2-44cb-9e68-d80a30d5708d
# 20/02/25 20:53:53 INFO ShutdownHookManager: Deleting directory /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-9816d2de-3e1b-4e4a-b92e-de4e8c3d96f2
# 20/02/25 20:53:53 INFO EGOClusterDriverWrapper: staging dir is None
# 20/02/25 20:53:53 INFO EGOClusterDriverWrapper: Deleting local temp file .//pytorch_mnist_EDT.py: true
# 20/02/25 20:53:53 INFO EGOClusterDriverWrapper: Deleting local temp file /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200225205016-0003-d67b5eec-c51d-4226-aca5-9ac667456786/.: false

# %% [markdown]
# ### Retrieve Training Executor Log
# #### Retrieve Executor ID
# - The deep learning training log per GPU is written in executor log
# - Execute following code to retrieve list of executor ID

# %%
for key in executors:    
    print ('executors: ' + key['id'])
# Out:
# executors: 1-72825eba-bb18-4d19-bf58-783c42867e4e
# executors: 0-28c4b5ed-3f65-40bc-989e-07dc04c49677

# %% [markdown]
# ### Retrieve Executor Stdout log
# - set the parameter executor_id

# %%
executor_id = '1-72825eba-bb18-4d19-bf58-783c42867e4e'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# load extra config from : /dlishared//conf
# Setting up spark environment on node colonia05.platform
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/dlishared/;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export FABRIC_HOME=/dlishared//fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export DLI_EXECID=Admin-3144597009192530-115196495;export PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt;export DATA_PATH=hymenoptera_data
# 20/02/25 20:50:28 INFO Conda variables: conda_home=/opt/anaconda3, conda_env=dlipy3, python=/opt/anaconda3/envs/dlipy3/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=
# 20/02/25 20:50:28 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/02/25 20:50:28 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/BFzyWFvN/0	2020-02-25 20:50:28.740713194 +0100
# [D]: >> 0-1: +++ /tmp/BFzyWFvN/1	2020-02-25 20:50:28.990714294 +0100
# [D]: >> 0-1: @@ -1,13 +1,211 @@
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@"
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@" && __conda_reactivate
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA;
# [D]: >> 0-1: + *)
# [D]: >> 0-1: + :;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PS1="$CONDA_PS1_BACKUP";
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \hash -r;
# [D]: >> 0-1: + \local ask_conda;
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \rehash;
# [D]: >> 0-1: + \unset CONDA_PS1_BACKUP;
# [D]: >> 0-1: + __conda_activate "$cmd" "$@"
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + activate | deactivate)
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix "$cmd" "$@")" || \return $?;
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix reactivate)" || \return $?;
# [D]: >> 0-1: + case "$cmd" in
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + esac;
# [D]: >> 0-1: + eval "export $save_var=$orig_val";
# [D]: >> 0-1: + eval "orig_val=\${${orig_var}-unset}";
# [D]: >> 0-1: + eval "save_val=\${${save_var}-xxx}";
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "$save_val" = xxx ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [ -n "${POSH_VERSION:+x}" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + install | update | upgrade | remove | uninstall)
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + local orig_val;
# [D]: >> 0-1: + local orig_var="$2";
# [D]: >> 0-1: + local save_val;
# [D]: >> 0-1: + local save_var="POWERAI_${package}_${orig_var}";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC___conda_activate()=() {  if [ -n "${CONDA_PS1_BACKUP:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_hashr()=() {  if [ -n "${ZSH_VERSION:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_reactivate()=() {  \local ask_conda;
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_conda()=() {  if [ "$#" -lt 1 ]; then
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_powerai_save_var_initial()=() {  local package="$1";
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1: +CAFFE_BIN=/opt/anaconda3/envs/dlipy3/bin
# [D]: >> 0-1: +COMPONENT=tensorflow
# [D]: >> 0-1: +CONDA_DEFAULT_ENV=dlipy3
# [D]: >> 0-1: +CONDA_EXE=/opt/anaconda3/bin/conda
# [D]: >> 0-1: +CONDA_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +CONDA_PROMPT_MODIFIER=(dlipy3)
# [D]: >> 0-1: +CONDA_SHLVL=1
# [D]: >> 0-1: +CUDA_TOOLKIT_LIB_PATH=/opt/anaconda3/envs/dlipy3/cuda/lib:
# [D]: >> 0-1:  CUDA_VISIBLE_DEVICES=2
# [D]: >> 0-1: +DATA_PATH=hymenoptera_data
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=dlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1:  DLI_CONDA_HOME=/opt/anaconda3
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/dlidata/
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=Admin-3144597009192530-115196495
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/dlishared//fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/dliresult/
# [D]: >> 0-1: +DLI_SHARED_FS=/dlishared/
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1:  DL_NFS_PATH=/dlishared/
# [D]: >> 0-1:  DRIVER_EXECUTOR_SHAREDKEY=7a0ef47c-41f8-474e-9ee5-28e770fdf4ac
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1: @@ -18,12 +216,33 @@
# [D]: >> 0-1:  EGO_MASTER_LIST_PEM=colonia05.platform
# [D]: >> 0-1:  EGO_TOP=/opt/ibm/spectrumcomputing
# [D]: >> 0-1:  FABRIC_BACKEND=pytorch
# [D]: >> 0-1: +FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +GREP=/bin/grep
# [D]: >> 0-1:  HOME=/home/egoadmin
# [D]: >> 0-1: +HOSTNAME_F=colonia05.platform
# [D]: >> 0-1:  JAVA_HOME=/opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1580185149401
# [D]: >> 0-1: -LD_LIBRARY_PATH=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/1985:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/1985:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1: +MPI_ROOT=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OMP_NUM_THREADS=16
# [D]: >> 0-1: +OPAL_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +POWERAI_caffe_CAFFE_BIN=unset
# [D]: >> 0-1: +POWERAI_caffe_OMP_NUM_THREADS=16
# [D]: >> 0-1: +POWERAI_pytorch_OMP_NUM_THREADS=16
# [D]: >> 0-1: +PS1=(dlipy3)
# [D]: >> 0-1: +PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt
# [D]: >> 0-1:  PWD=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/executor-1-72825eba-bb18-4d19-bf58-783c42867e4e
# [D]: >> 0-1: +PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=egoadmin
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -91,6 +310,34 @@
# [D]: >> 0-1:  SPARK_PRINT_LAUNCH_COMMAND=1
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=egoadmin
# [D]: >> 0-1: +SYS_PYTHON_MAJOR=3
# [D]: >> 0-1: +SYS_PYTHON_MINOR=6
# [D]: >> 0-1: +TF_INCLUDE_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/include
# [D]: >> 0-1: +TF_LIBRARY_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1: +TF_PKG_PATH=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1:  USER=egoadmin
# [D]: >> 0-1: +USER_UID=1001
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1: +_CE_CONDA=
# [D]: >> 0-1: +_CE_M=
# [D]: >> 0-1: +_CONDA_ROOT=/opt/anaconda3
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/BFzyWFvN
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: final: >> CUDA_VISIBLE_DEVICES=2
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to 2
# Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data
# Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# 20/02/25 20:50:29 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=2
# DLI_CONDA_HOME=/opt/anaconda3
# DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# DL_NFS_PATH=/dlishared/
# DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/1985:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=egoadmin
# USER_UID=1001
# DLI_EXECID=Admin-3144597009192530-115196495
# SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/
# 20/02/25 20:50:29 INFO finish spark environment setup.

# %% [markdown]
# ### Retrieve Executor Stderr log
# - set the parameter executor_id

# %%
executor_id = '1-72825eba-bb18-4d19-bf58-783c42867e4e'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# +++ export SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ '[' -z '' ']'
# +++ export GLOG_logtostderr=true
# +++ GLOG_logtostderr=true
# +++ '[' -z '' -a -n '' -a -f '' ']'
# +++ '[' -n '' -a -f '' ']'
# +++ '[' true = true ']'
# +++ checkGPUMemory
# +++ echo 'Check GPU memory utilization'
# +++ echo 'CUDA_VISIBLE_DEVICES is set to 2'
# +++ utilization_high=1
# +++ timeout_secs=30
# +++ time_sleep=0
# +++ '[' 0 -lt 30 -a 1 -eq 1 ']'
# +++ utilization_high=0
# ++++ echo 2
# ++++ tr , ' '
# +++ for gpuid in '$(echo $CUDA_VISIBLE_DEVICES | tr '\'','\'' '\'' '\'')'
# ++++ nvidia-smi -i 2 --query-gpu=utilization.memory --format=csv,nounits,noheader
# +++ utilization=0
# +++ '[' 0 -gt 90 ']'
# +++ '[' 0 -eq 1 ']'
# +++ '[' 0 -lt 30 -a 0 -eq 1 ']'
# +++ '[' 0 -eq 1 ']'
# +++ export NCCL_P2P_DISABLE=1
# +++ NCCL_P2P_DISABLE=1
# +++ handle_BYOF_EDT_Job
# +++ '[' true = true -a Admin-3144597009192530-115196495x '!=' x ']'
# +++ '[' /dlidata/ '!=' '' ']'
# +++ export DATA_DIR=/dlidata//hymenoptera_data
# +++ DATA_DIR=/dlidata//hymenoptera_data
# +++ local batch_path=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ export RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# +++ '[' -n /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/ ']'
# ++++ basename /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/
# +++ local log_subdir=1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# +++ export LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# +++ LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# +++ mkdir -p /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# +++ export SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# +++ SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# +++ echo 'Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data'
# +++ echo 'Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495'
# +++ echo 'Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform'
# +++ echo 'Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model'
# +++ echo /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/
# +++ grep logs/driver-
# +++ trace_env
# +++ log_info 'Trace envrionment'
# ++++ date '+%y/%m/%d %H:%M:%S'
# +++ echo '20/02/25 20:50:29 INFO Trace envrionment'
# +++ echo CUDA_VISIBLE_DEVICES=2
# +++ echo DLI_CONDA_HOME=/opt/anaconda3
# +++ echo DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# +++ echo DL_NFS_PATH=/dlishared/
# +++ echo DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# +++ echo DLI_LOGGER_LEVEL=debug
# +++ echo PYTHON_VERSION=
# +++ echo SPARK_EGO_USER_FIRST_JARS=
# +++ echo 'LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/1985:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib'
# +++ echo PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-3144597009192530-115196495/_submitted_code/pytorch_edt:
# +++ echo PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# +++ echo RDMA_ENABLED=false
# +++ echo RDMA_BUFFER_SIZE=1073741824
# +++ echo RDMA_DEVICE_NAME=
# +++ echo RDMA_DEVICE_PORT=
# +++ echo DLI_IS_ELASTIC=true
# +++ echo USER=egoadmin
# +++ echo USER_UID=1001
# +++ echo DLI_EXECID=Admin-3144597009192530-115196495
# +++ echo SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/
# +++ false
# +++ set +x
# Spark Command: /opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le/bin/java -cp /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/*:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/1985:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/44665:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/conf/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/* -Dspark.ssl.ego.workload.enabled=false -Dspark.ssl.ego.gui.enabled=false -Dspark.ssl.enabled=false -Dspark.rpc.framesize=2047 -Dspark.shuffle.service.port=7341 -Dspark.driver.port=42336 -Dspark.ui.port=0 -Dspark.master.rest.port=6070 -Djava.security.egd=file:/dev/./urandom -Xmx4096m org.apache.spark.executor.EGOExecutorBackend --driver-url spark://EGODRIVERScheduler@colonia05.platform:42336 --executor-id 1-72825eba-bb18-4d19-bf58-783c42867e4e --hostname colonia05.platform --cores 1 --app-id app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4 --resourceType GPU
# ========================================
# 20/02/25 20:50:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 20/02/25 20:50:31 INFO EGOExecutorBackend:  The args is : [Ljava.lang.String;@ed820621
# 20/02/25 20:50:31 INFO EGOExecutorBackend: Started daemon with process name: 3407@colonia05.platform
# 20/02/25 20:50:31 INFO SignalUtils: Registered signal handler for TERM
# 20/02/25 20:50:31 INFO SignalUtils: Registered signal handler for HUP
# 20/02/25 20:50:31 INFO SignalUtils: Registered signal handler for INT
# 20/02/25 20:50:31 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:31 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:31 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:31 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:31 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:32 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:42336 after 78 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:32 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/25 20:50:32 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/25 20:50:32 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/25 20:50:32 INFO SecurityManager: Changing view acls groups to:
# 20/02/25 20:50:32 INFO SecurityManager: Changing modify acls groups to:
# 20/02/25 20:50:32 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/25 20:50:32 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:42336 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:32 INFO DiskBlockManager: Created local directory at /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/blockmgr-a3dbdb4f-1812-452a-87b0-3f0a1b724120
# 20/02/25 20:50:32 INFO MemoryStore: MemoryStore started with capacity 2.2 GB
# 20/02/25 20:50:32 INFO EGOExecutorBackend: Connecting to driver: spark://EGODRIVERScheduler@colonia05.platform:42336
# 20/02/25 20:50:32 INFO EGOExecutorBackend: getLogPath /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform/
# 20/02/25 20:50:32 INFO EGOExecutorBackend: Successfully registered with driver
# 20/02/25 20:50:32 INFO Executor: Starting executor ID 1-72825eba-bb18-4d19-bf58-783c42867e4e on host colonia05.platform
# 20/02/25 20:50:32 INFO Utils: Incrementing port number property = true.
# 20/02/25 20:50:32 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 41550.
# 20/02/25 20:50:32 INFO NettyBlockTransferService: Server created on colonia05.platform:41550
# 20/02/25 20:50:32 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/25 20:50:32 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(1-72825eba-bb18-4d19-bf58-783c42867e4e, colonia05.platform, 41550, None)
# 20/02/25 20:50:32 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(1-72825eba-bb18-4d19-bf58-783c42867e4e, colonia05.platform, 41550, None)
# 20/02/25 20:50:32 INFO BlockManager: external shuffle service port = 7341
# 20/02/25 20:50:32 INFO BlockManager: Registering executor with local external shuffle service.
# 20/02/25 20:50:32 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7341 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:33 INFO BlockManager: Initialized BlockManager: BlockManagerId(1-72825eba-bb18-4d19-bf58-783c42867e4e, colonia05.platform, 41550, None)
# 20/02/25 20:50:33 INFO EGOExecutorBackend: Got assigned task 0 with concurrent number(1)
# 20/02/25 20:50:33 INFO Executor: Task 0 took 1 ms in queue
# 20/02/25 20:50:33 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 20/02/25 20:50:33 INFO Executor: [task] [startingDeserialization] taskName:task 0.0 in stage 0.0 taskId:0 deserializeStartTime:1582660233056
# 20/02/25 20:50:33 INFO Executor: Fetching spark://colonia05.platform:42336/files/pytorch_mnist_EDT.py with timestamp 1582660223432
# 20/02/25 20:50:33 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:42336 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:33 INFO Utils: Fetching spark://colonia05.platform:42336/files/pytorch_mnist_EDT.py to /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/fetchFileTemp852078887256985056.tmp
# 20/02/25 20:50:33 INFO Utils: Copying /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/-7044369171582660223432_cache to /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4/executor-1-72825eba-bb18-4d19-bf58-783c42867e4e/./pytorch_mnist_EDT.py
# 20/02/25 20:50:33 INFO Executor: [task] [started] taskName:task 0.0 in stage 0.0 taskId:0 startTime:1582660233272
# 20/02/25 20:50:33 INFO TorrentBroadcast: Started reading broadcast variable 1
# 20/02/25 20:50:33 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:42298 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:33 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 3.9 KB, free 2.2 GB)
# 20/02/25 20:50:33 INFO TorrentBroadcast: Reading broadcast variable 1 took 115 ms
# 20/02/25 20:50:33 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 6.0 KB, free 2.2 GB)
# 20/02/25 20:50:34 INFO TorrentBroadcast: Started reading broadcast variable 0
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece13 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece17 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece16 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece8 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece20 stored as bytes in memory (estimated size 3.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece6 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece14 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece7 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece5 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece1 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece15 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece19 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece10 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece2 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece11 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece12 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece9 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:42433 after 1 ms (0 ms spent in bootstraps)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece4 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece3 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/25 20:50:34 INFO MemoryStore: Block broadcast_0_piece18 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/25 20:50:34 INFO TorrentBroadcast: Reading broadcast variable 0 took 666 ms
# 20/02/25 20:50:35 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 400.0 B, free 2.1 GB)
# <> DATA_DIR /dlidata//hymenoptera_data
# <> RESULT_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495
# <> LOG_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/log/1-72825eba-bb18-4d19-bf58-783c42867e4e.colonia05.platform
# Using pytorch backend.
# <> SAVED_MODEL_DIR /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model
# /dlishared/fabric/1.2.3/libs/fabric.zip/fabric_zmqservice/rep_stream_handler.py:15: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
# libunformatworker.so loaded successfully
# Using spark scheduler.
# 2020-02-25 20:50:36,618 - root - INFO - spark
# 2020-02-25 20:50:36,618 - root - INFO - create dataset
# 2020-02-25 20:50:36,621 - root - INFO - create dataloader
# 2020-02-25 20:50:36,621 - root - INFO - pytorch_backend init_dataloader
# 2020-02-25 20:50:36,621 - root - INFO - ! dataset size 244, batch size 64
# 2020-02-25 20:50:36,622 - root - INFO - worker-c831590d-9b8b-4ba2-9d17-21dfddc1bcda: action: send batch setting
# 2020-02-25 20:50:36,622 - root - INFO - zmq connected, url: tcp://10.3.64.217:43969
# 2020-02-25 20:50:36,774 - root - INFO - setup model
# 2020-02-25 20:50:36,774 - root - INFO - _worker_loop - worker 0 start pid: 6604
# 2020-02-25 20:50:36,774 - root - INFO - resume weight from None
# 2020-02-25 20:50:38,851 - root - INFO - CUDA Device set to: 0
# 2020-02-25 20:50:38,853 - root - INFO - init_ese_worker, grad size 1026
# UnformatedEseWorker created.
# work ptr is: 0x1002d040560
# 2020-02-25 20:50:39,104 - root - INFO -  ese engine created!
# 2020-02-25 20:50:39,105 - root - INFO - setup optimizer
# 2020-02-25 20:50:39,105 - root - INFO - client registration
# 2020-02-25 20:50:39,105 - root - INFO - worker-c831590d-9b8b-4ba2-9d17-21dfddc1bcda register sync variable !
# 2020-02-25 20:50:39,105 - root - INFO - start heart beat
# 2020-02-25 20:50:39,105 - root - INFO - !ADD_NODE: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d
# 2020-02-25 20:50:39,107 - root - INFO - !ADD_NODE: worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0
# 2020-02-25 20:50:39,107 - root - INFO - add node id worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0
# 2020-02-25 20:50:39,107 - root - INFO - epoch start, total epoch 50
# 2020-02-25 20:50:39,107 - root - INFO - --------START TRAINING--------
# 2020-02-25 20:50:39,107 - root - INFO - <=== Epoch 0 Begin ==>
# 2020-02-25 20:50:39,107 - root - INFO - kick off the trainer
# 2020-02-25 20:50:39,113 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: PUSH_WEIGHT, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 0
# 2020-02-25 20:50:39,113 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: HandleControlMsg: Receive PUSH_WEIGHT message.
# 2020-02-25 20:50:39,113 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: HandleControlMsg PUSH_WEIGHT: First worker in the topo, myself worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0
# 2020-02-25 20:50:39,115 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: PULL_WEIGHT, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 0
# 2020-02-25 20:50:39,116 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 1
# 2020-02-25 20:50:39,116 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 0
# 2020-02-25 20:50:39,119 - root - INFO - idx presend batch 0 pending {0, 1, 2, 3}
# 2020-02-25 20:50:39,119 - root - INFO - FabricDistributedSampler.next - tid: 0, batch_idx:[43, 118, 5, 192, 180, 169, 207, 120, 53, 35, 55, 80, 45, 30, 206, 26, 76, 205, 144, 6, 233, 50, 195, 129, 191, 194, 165, 95, 59, 94, 133, 49, 23, 241, 159, 91, 147, 9, 232, 105, 140, 184, 78, 115, 114, 163, 29, 178, 223, 2, 121, 61, 92, 84, 4, 77, 175, 25, 137, 224, 54, 113, 230, 10]
# 2020-02-25 20:50:39,119 - root - INFO - _process_next_indices - put to index queue: tid=0
# 2020-02-25 20:50:39,119 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending
- root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 2
# 2020-02-25 20:50:40,618 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-25 20:50:40,618 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[214, 40, 116, 111, 0, 213, 16, 185, 31, 21, 220, 83, 88, 46, 12, 234, 98, 93, 58, 24, 41, 134, 89, 164, 63, 100, 130, 210, 125, 177, 197, 70, 27, 172, 56, 101, 17, 109, 132, 174, 126, 48, 42, 242, 3, 90, 218, 200, 173, 67, 141, 22, 122, 18, 156, 82, 166, 143, 186, 157, 69, 28, 238, 128]
# 2020-02-25 20:50:40,618 - root - INFO - _process_next_indices - put to index queue: tid=2
# 2020-02-25 20:50:40,618 - root - INFO - loader.next - read idx:1, batches_outstanding:0
# 2020-02-25 20:50:40,618 - root - INFO - loader.next - randomly handle batch 1
# 2020-02-25 20:50:40,618 - root - INFO - Start training batch 1
# 2020-02-25 20:50:40,618 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 2, batch_indices [214, 40, 116, 111, 0, 213, 16, 185, 31, 21, 220, 83, 88, 46, 12, 234, 98, 93, 58, 24, 41, 134, 89, 164, 63, 100, 130, 210, 125, 177, 197, 70, 27, 172, 56, 101, 17, 109, 132, 174, 126, 48, 42, 242, 3, 90, 218, 200, 173, 67, 141, 22, 122, 18, 156, 82, 166, 143, 186, 157, 69, 28, 238, 128]
# 2020-02-25 20:50:40,626 - root - INFO - sync local
# 2020-02-25 20:50:40,638 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_UP, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 2
# 2020-02-25 20:50:40,638 - root - INFO - HandleControlMsg: new communicate id is CgDAJwAAAAD+gAAAAAAAACaKBwMAp5ggCAAAAP4/AADol7vE/j8AAOC7FQkAAQAAyDXgyP4/AADAFvDI/j8AAHBMAbT+PwAAWnZNb0mVpnklCgAA/j8AALDx/6/+PwAAQJi7xP4/AAD//wMAAAAAABB0HMn+PwAAAH/SIQEAAAA=
# 2020-02-25 20:50:40,638 - root - INFO - ese-worker reset engine, local grads buffer
# 2020-02-25 20:50:40,638 - root - INFO - ------cluster begin-------
# 2020-02-25 20:50:40,638 - root - INFO - ['worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0']
# 2020-02-25 20:50:40,638 - root - INFO - ------cluster end-------
# 2020-02-25 20:50:40,638 - root - INFO - Initializing DDL with options:-ddl_worker_count 1 -ddl_worker_index 0 -ddl_device_index 0 -ddl_group_id CgDAJwAAAAD+gAAAAAAAACaKBwMAp5ggCAAAAP4/AADol7vE/j8AAOC7FQkAAQAAyDXgyP4/AADAFvDI/j8AAHBMAbT+PwAAWnZNb0mVpnklCgAA/j8AALDx/6/+PwAAQJi7xP4/AAD//wMAAAAAABB0HMn+PwAAAH/SIQEAAAA=
# colonia05:4675:4675 [0] NCCL INFO NET/Socket : Using [0]ib0:fe80::268a:703:a7:9820%ib0<0>
# colonia05:4675:4675 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# colonia05:4675:4675 [0] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# NCCL version 2.4.7nvb1+cuda10.1
# colonia05:4675:4675 [0] NCCL INFO NCCL_P2P_DISABLE set by environment to 1.
# colonia05:4675:4675 [0] NCCL INFO Using 256 threads, Min Comp Cap 6, Trees enabled up to size -2
# colonia05:4675:4675 [0] NCCL INFO comm 0x3eff62166860 rank 0 nranks 1 cudaDev 0 nvmlDev 2 - Init COMPLETE
# 2020-02-25 20:50:40,706 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 Receive SYNC_UP round 1 group{'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0'}} changed? True
# 2020-02-25 20:50:40,707 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x1002d040560
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-25 20:50:40,707 - root - INFO - optmizer step local 3
# 2020-02-25 20:50:40,710 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_DONE, sender worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0, global step 2
# 2020-02-25 20:50:40,714 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 3
# 2020-02-25 20:50:40,714 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:50:40,715 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 3, 'correction': tensor(40), 'count': 64, 'loss': -0.2229224592447281}
# Timestamp 1582660240717, Iteration 2
# batches :2 -0.2229224592447281
# Iteration 3: tag train_accuracy, simple_value 0.61719
# Iteration 3: tag train_loss, simple_value -0.22292
# 2020-02-25 20:50:40,717 - root - INFO - Batch 1 training finished
# 2020-02-25 20:50:40,717 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-25 20:50:40,717 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-25 20:50:40,717 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[214, 40, 116, 111, 0, 213, 16, 185, 31, 21, 220, 83, 88, 46, 12, 234, 98, 93, 58, 24, 41, 134, 89, 164, 63, 100, 130, 210, 125, 177, 197, 70, 27, 172, 56, 101, 17, 109, 132, 174, 126, 48, 42, 242, 3, 90, 218, 200, 173, 67, 141, 22, 122, 18, 156, 82, 166, 143, 186, 157, 69, 28, 238, 128]
# 2020-02-25 20:50:40,717 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 3
# 2020-02-25 20:50:40,718 - root - INFO - idx presend batch 3 pending {3}
# 2020-02-25 20:50:40,718 - root - INFO - FabricDistributedSampler.next - tid: 3, batch_idx:[171, 8, 240, 131, 198, 146, 20, 217, 201, 182, 119, 152, 211, 44, 219, 231, 160, 51, 60, 71, 62, 138, 135, 168, 33, 57, 193, 162, 167, 239, 36, 190, 139, 52, 215, 104, 11, 64, 38, 153, 149, 79, 1, 68, 228, 212, 74, 227, 14, 66, 87, 196]
# 2020-02-25 20:50:40,718 - root - INFO -
#  final batch 52
# 2020-02-25 20:50:40,718 - root - INFO - _process_next_indices - put to index queue: tid=3
# 2020-02-25 20:50:41,105 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: heartbeat
# 2020-02-25 20:50:41,126 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 3, batch_indices [171, 8, 240, 131, 198, 146, 20, 217, 201, 182, 119, 152, 211, 44, 219, 231, 160, 51, 60, 71, 62, 138, 135, 168, 33, 57, 193, 162, 167, 239, 36, 190, 139, 52, 215, 104, 11, 64, 38, 153, 149, 79, 1, 68, 228, 212, 74, 227, 14, 66, 87, 196]
# 2020-02-25 20:50:41,131 - root - INFO - loader.next - read idx:2, batches_outstanding:0
# 2020-02-25 20:50:41,131 - root - INFO - loader.next - randomly handle batch 2
# 2020-02-25 20:50:41,131 - root - INFO - Start training batch 2
# 2020-02-25 20:50:41,139 - root - INFO - sync local
# 2020-02-25 20:50:41,144 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 4
# 2020-02-25 20:50:41,164 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:50:41,164 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 4, 'correction': tensor(35), 'count': 64, 'loss': -19.846376419067383}
# Timestamp 1582660241167, Iteration 3
# batches :3 -19.846376419067383
# Iteration 4: tag train_accuracy, simple_value 0.59375
# Iteration 4: tag train_loss, simple_value -19.84638
# 2020-02-25 20:50:41,166 - root - INFO - Batch 2 training finished
# 2020-02-25 20:50:41,166 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-25 20:50:41,166 - root - INFO - _process_next_indices - all data index cached
# 2020-02-25 20:50:41,552 - root - INFO - loader.next - read idx:3, batches_outstanding:-1
# 2020-02-25 20:50:41,552 - root - INFO - loader.next - randomly handle batch 3
# 2020-02-25 20:50:41,552 - root - INFO - Start training batch 3
# 2020-02-25 20:50:41,560 - root - INFO - sync local
# 2020-02-25 20:50:41,563 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_UP, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 4
# 2020-02-25 20:50:41,563 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 Receive SYNC_UP round 2 group{'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0'}} changed? False
# 2020-02-25 20:50:41,564 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x1002d040560
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-25 20:50:41,581 - root - INFO - optmizer step local 6
# 2020-02-25 20:50:41,583 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_DONE, sender worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0, global step 4
# 2020-02-25 20:50:41,586 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: END_EPOCH, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 0
# 2020-02-25 20:50:41,586 - root - INFO - sync: end of the epoch
# 2020-02-25 20:50:41,587 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:50:41,587 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 0, 'correction': tensor(37), 'count': 52, 'loss': -20.237802505493164}
# Timestamp 1582660241589, Iteration 4
# batches :4 -20.237802505493164
# Iteration 4: tag train_accuracy, simple_value 0.71154
# Iteration 4: tag train_loss, simple_value -20.2378
# 2020-02-25 20:50:41,589 - root - INFO - Batch 3 training finished
# 2020-02-25 20:50:41,589 - root - INFO - loader reset, batch_sample.is_final:True
# 2020-02-25 20:50:41,589 - root - INFO - <=== Epoch 0 End ==>
# 2020-02-25 20:50:41,589 - root - INFO - save model under: /dliresult//egoadmin/batchworkdir/Admin-3144597009192530-115196495/model/train
# 2020-02-25 20:50:41,590 - root - INFO - save models for epoch 0
# Iteration 0: tag test_accuracy, simple_value 0.17188
# Iteration 0: tag test_loss, simple_value -52.50385
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.ExternalShuffle.shuffle-client.usedDirectMemory, value=-1
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.ExternalShuffle.shuffle-client.usedHeapMemory, value=16777216
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.largeRead_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.read_bytes, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.read_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.write_bytes, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.write_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.largeRead_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.read_bytes, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.read_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.write_bytes, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.write_ops, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.activeGpuTasks, value=1
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.completeGpuTasks, value=0
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.currentPool_size, value=1
# 20/02/25 20:50:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.maxPool_size, value=2147483647
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.bytesRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.bytesWritten, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.cpuTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.deserializeCpuTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.deserializeTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.diskBytesSpilled, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.jvmGCTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.memoryBytesSpilled, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.recordsRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.recordsWritten, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.resultSerializationTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.resultSize, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.runTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleBytesWritten, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleFetchWaitTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleLocalBlocksFetched, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleLocalBytesRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRecordsRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRecordsWritten, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBlocksFetched, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBytesRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBytesReadToDisk, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleTotalBytesRead, count=0
# 20/02/25 20:50:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleWriteTime, count=0
# 20/02/25 20:50:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:50:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# Iteration 1: tag test_accuracy, simple_value 0.55469
# Iteration 1: tag test_loss, simple_value -64.15259
# 2020-02-25 20:50:43,107 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: heartbeat
# Iteration 2: tag test_accuracy, simple_value 0.62745
# Iteration 2: tag test_loss, simple_value -64.80698
# 2020-02-25 20:50:43,298 - root - INFO - epoch=0 validation_accuracy: 0.6275
# 2020-02-25 20:50:43,298 - root - INFO - <=== Epoch 1 Begin ==>
# 2020-02-25 20:50:43,298 - root - INFO - kick off the trainer
# 2020-02-25 20:50:43,303 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 1
# 2020-02-25 20:50:43,304 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 0
# 2020-02-25 20:50:43,305 - root - INFO - idx presend batch 0 pending {0, 1, 2, 3}
# 2020-02-25 20:50:43,305 - root - INFO - FabricDistributedSampler.next - tid: 0, batch_idx:[239, 81, 72, 70, 193, 141, 52, 78, 49, 145, 174, 4, 132, 84, 86, 67, 134, 41, 57, 94, 190, 231, 143, 243, 198, 158, 32, 195, 207, 77, 0, 55, 216, 168, 139, 176, 97, 107, 92, 42, 26, 23, 137, 71, 19, 56, 230, 138, 192, 101, 122, 38, 213, 199, 221, 241, 206, 46, 108, 180, 152, 51, 147, 31]
# 2020-02-25 20:50:43,305 - root - INFO - _process_next_indices - put to index queue: tid=0
# 2020-02-25 20:50:43,305 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 1
# 2020-02-25 20:50:43,305 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 0, batch_indices [239, 81, 72, 70, 193, 141, 52, 78, 49, 145, 174, 4, 132, 84, 86, 67, 134, 41, 57, 94, 190, 231, 143, 243, 198, 158, 32, 195, 207, 77, 0, 55, 216, 168, 139, 176, 97, 107, 92, 42, 26, 23, 137, 71, 19, 56, 230, 138, 192, 101, 122, 38, 213, 199, 221, 241, 206, 46, 108, 180, 152, 51, 147, 31]
# 2020-02-25 20:50:43,306 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-25 20:50:43,306 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[93, 161, 197, 164, 146, 177, 83, 66, 80, 149, 63, 129, 204, 62, 125, 95, 238, 116, 148, 186, 150, 60, 237, 126, 183, 153, 22, 16, 220, 151, 240, 200, 75, 25, 157, 9, 178, 232, 219, 191, 2, 124, 76, 90, 54, 140, 128, 43, 142, 102, 24, 175, 113, 185, 214, 36, 215, 210, 47, 117, 30, 155, 196, 21]
# 2020-02-25 20:50:43,306 - root - INFO - _process_next_indices - put to index queue: tid=1
# 2020-02-25 20:50:43,796 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 1, batch_indices [93, 161, 197, 164, 146, 177, 83, 66, 80, 149, 63, 129, 204, 62, 125, 95, 238, 116, 148, 186, 150, 60, 237, 126, 183, 153, 22, 16, 220, 151, 240, 200, 75, 25, 157, 9, 178, 232, 219, 191, 2, 124, 76, 90, 54, 140, 128, 43, 142, 102, 24, 175, 113, 185, 214, 36, 215, 210, 47, 117, 30, 155, 196, 21]
# 2020-02-25 20:50:43,801 - root - INFO - loader.next - read idx:0, batches_outstanding:0
# 2020-02-25 20:50:43,801 - root - INFO - loader.next - randomly handle batch 0
# 2020-02-25 20:50:43,801 - root - INFO - Start training batch 0
# 2020-02-25 20:50:43,809 - root - INFO - sync local
# 2020-02-25 20:50:43,813 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 2
# 2020-02-25 20:50:43,833 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:50:43,834 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 2, 'correction': tensor(35), 'count': 64, 'loss': -57.561058044433594}
# Timestamp 1582660243836, Iteration 5
# batches :5 -57.561058044433594
# Iteration 6: tag train_accuracy, simple_value 0.62069
# Iteration 6: tag train_loss, simple_value -57.56106
# 2020-02-25 20:50:43,836 - root - INFO - Batch 0 training finished
# 2020-02-25 20:50:43,836 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-25 20:50:43,836 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-25 20:50:43,836 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[93, 161, 197, 164, 146, 177, 83, 66, 80, 149, 63, 129, 204, 62, 125, 95, 238, 116, 148, 186, 150, 60, 237, 126, 183, 153, 22, 16, 220, 151, 240, 200, 75, 25, 157, 9, 178, 232, 219, 191, 2, 124, 76, 90, 54, 140, 128, 43, 142, 102, 24, 175, 113, 185, 214, 36, 215, 210, 47, 117, 30, 155, 196, 21]
# 2020-02-25 20:50:43,836 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 2
# 2020-02-25 20:50:43,837 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-25 20:50:43,837 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[127, 89, 223, 6, 205, 112, 34, 44, 218, 131, 15, 37, 105, 123, 187, 154, 74, 3, 82, 109, 88, 106, 8, 182, 7, 5, 211, 209, 226, 10, 79, 120, 224, 144, 184, 212, 179, 91, 53, 69, 35, 188, 27, 233, 28, 119, 73, 104, 12, 61, 114, 166, 18, 65, 194, 100, 202, 156, 229, 33, 217, 169, 111, 133]
# 2020-02-25 20:50:43,837 - root - INFO - _process_next_indices - put to index queue: tid=2
# 2020-02-25 20:50:44,349 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 2, batch_indices [127, 89, 223, 6, 205, 112, 34, 44, 218, 131, 15, 37, 105, 123, 187, 154, 74, 3, 82, 109, 88, 106, 8, 182, 7, 5, 211, 209, 226, 10, 79, 120, 224, 144, 184, 212, 179, 91, 53, 69, 35, 188, 27, 233, 28, 119, 73, 104, 12, 61, 114, 166, 18, 65, 194, 100, 202, 156, 229, 33, 217, 169, 111, 133]
# 2020-02-25 20:50:44,354 - root - INFO - loader.next - read idx:1, batches_outstanding:0
# 2020-02-25 20:50:44,355 - root - INFO - loader.next - randomly handle batch 1
# 2020-02-25 20:50:44,355 - root - INFO - Start training batch 1
# 2020-02-25 20:50:44,363 - root - INFO - sync local
# ...
# 2020-02-25 20:53:39,323 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 action: GET BATCH INDEX pending 3
# 2020-02-25 20:53:39,324 - root - INFO - idx presend batch 3 pending {3}
# 2020-02-25 20:53:39,324 - root - INFO - FabricDistributedSampler.next - tid: 3, batch_idx:[95, 168, 10, 18, 56, 221, 30, 100, 177, 188, 164, 106, 226, 194, 26, 8, 228, 27, 191, 210, 196, 190, 65, 123, 112, 90, 93, 102, 57, 21, 239, 216, 230, 209, 163, 162, 76, 81, 84, 67, 189, 29, 231, 180, 38, 142, 214, 193, 186, 128, 135, 92]
# 2020-02-25 20:53:39,324 - root - INFO -
#  final batch 52
# 2020-02-25 20:53:39,324 - root - INFO - _process_next_indices - put to index queue: tid=3
# 2020-02-25 20:53:39,821 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 3, batch_indices [95, 168, 10, 18, 56, 221, 30, 100, 177, 188, 164, 106, 226, 194, 26, 8, 228, 27, 191, 210, 196, 190, 65, 123, 112, 90, 93, 102, 57, 21, 239, 216, 230, 209, 163, 162, 76, 81, 84, 67, 189, 29, 231, 180, 38, 142, 214, 193, 186, 128, 135, 92]
# 2020-02-25 20:53:39,828 - root - INFO - loader.next - read idx:2, batches_outstanding:0
# 2020-02-25 20:53:39,828 - root - INFO - loader.next - randomly handle batch 2
# 2020-02-25 20:53:39,828 - root - INFO - Start training batch 2
# 2020-02-25 20:53:39,836 - root - INFO - sync local
# 2020-02-25 20:53:39,838 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: NEW_TASK, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 4
# 2020-02-25 20:53:39,860 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:53:39,861 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 4, 'correction': tensor(35), 'count': 64, 'loss': -17704.185546875}
# Timestamp 1582660419863, Iteration 199
# batches :199 -17704.185546875
# Iteration 200: tag train_accuracy, simple_value 0.65164
# Iteration 200: tag train_loss, simple_value -17704.18555
# 2020-02-25 20:53:39,862 - root - INFO - Batch 2 training finished
# 2020-02-25 20:53:39,862 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-25 20:53:39,862 - root - INFO - _process_next_indices - all data index cached
# 2020-02-25 20:53:40,232 - root - INFO - loader.next - read idx:3, batches_outstanding:-1
# 2020-02-25 20:53:40,232 - root - INFO - loader.next - randomly handle batch 3
# 2020-02-25 20:53:40,232 - root - INFO - Start training batch 3
# 2020-02-25 20:53:40,239 - root - INFO - sync local
# 2020-02-25 20:53:40,241 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_UP, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 4
# 2020-02-25 20:53:40,241 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 Receive SYNC_UP round 100 group{'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0'}} changed? False
# 2020-02-25 20:53:40,242 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x1002d040560
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-25 20:53:40,261 - root - INFO - optmizer step local 300
# 2020-02-25 20:53:40,262 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: SYNC_DONE, sender worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0, global step 4
# 2020-02-25 20:53:40,264 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: STOP_WORKER, sender server-4da53b6c-a8d9-4657-a135-8932e74cc989, global step 0
# 2020-02-25 20:53:40,265 - root - INFO - stop heart beat
# 2020-02-25 20:53:40,265 - root - INFO - sync: stop worker!
# 2020-02-25 20:53:40,265 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0 end heart beat
# 2020-02-25 20:53:40,265 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy
# 2020-02-25 20:53:40,266 - root - INFO - worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0: action: update accuracy {'sender': 'worker-f48f1916-06fb-4f77-bb63-48b9ccce504d:0', 'global_step': 4, 'correction': tensor(35), 'count': 52, 'loss': -17831.408203125}
# Timestamp 1582660420267, Iteration 200
# batches :200 -17831.408203125
# Iteration 200: tag train_accuracy, simple_value 0.67308
# Iteration 200: tag train_loss, simple_value -17831.4082
# 2020-02-25 20:53:40,267 - root - INFO - Batch 3 training finished
# 2020-02-25 20:53:40,267 - root - INFO - loader reset, batch_sample.is_final:True
# 2020-02-25 20:53:40,267 - root - INFO - <=== Epoch 49 End ==>
# 2020-02-25 20:53:40,267 - root - INFO - save models for epoch 49
# Iteration 0: tag test_accuracy, simple_value 0.1875
# Iteration 0: tag test_loss, simple_value -16497.11914
# Iteration 1: tag test_accuracy, simple_value 0.5625
# Iteration 1: tag test_loss, simple_value -20011.43555
# Iteration 2: tag test_accuracy, simple_value 0.63399
# Iteration 2: tag test_loss, simple_value -19918.70703
# 2020-02-25 20:53:41,905 - root - INFO - epoch=49 validation_accuracy: 0.6340
# 2020-02-25 20:53:41,905 - root - INFO - --------END TRAINING: completed iteration 200 --------
# 2020-02-25 20:53:41,905 - root - INFO - disconnect zmq
# 2020-02-25 20:53:41,906 - root - INFO - zmq closed
# 20/02/25 20:53:41 INFO PythonRunner: Times: total = 188349, boot = 461, init = 2600, finish = 185288
# 20/02/25 20:53:41 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1460 bytes result sent to driver
# 20/02/25 20:53:41 INFO Executor: [task] [finished] taskName:task 0.0 in stage 0.0 taskId:0 finishTime:1582660421918 duration:188420 state:TaskState.FINISHED resourceType:GPU
# 20/02/25 20:53:42 INFO EGOExecutorBackend: Driver commanded a shutdown
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.ExternalShuffle.shuffle-client.usedDirectMemory, value=-1
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.ExternalShuffle.shuffle-client.usedHeapMemory, value=16777216
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.largeRead_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.read_bytes, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.read_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.write_bytes, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.file.write_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.largeRead_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.read_bytes, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.read_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.write_bytes, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.filesystem.hdfs.write_ops, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.activeGpuTasks, value=0
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.completeGpuTasks, value=1
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.currentPool_size, value=1
# 20/02/25 20:53:42 INFO metrics: type=GAUGE, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.threadpool.maxPool_size, value=2147483647
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.bytesRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.bytesWritten, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.cpuTime, count=95285588
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.deserializeCpuTime, count=302160356
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.deserializeTime, count=442
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.diskBytesSpilled, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.jvmGCTime, count=163
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.memoryBytesSpilled, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.recordsRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.recordsWritten, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.resultSerializationTime, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.resultSize, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.runTime, count=188420
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleBytesWritten, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleFetchWaitTime, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleLocalBlocksFetched, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleLocalBytesRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRecordsRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRecordsWritten, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBlocksFetched, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBytesRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleRemoteBytesReadToDisk, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleTotalBytesRead, count=0
# 20/02/25 20:53:42 INFO metrics: type=COUNTER, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.executor.shuffleWriteTime, count=0
# 20/02/25 20:53:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:42 INFO metrics: type=HISTOGRAM, name=app-20200225205023-0000-31b1d751-29bd-4419-b546-e998e550cad4.1-72825eba-bb18-4d19-bf58-783c42867e4e.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/25 20:53:42 INFO MemoryStore: MemoryStore cleared
# 20/02/25 20:53:42 INFO BlockManager: BlockManager stopped
# 20/02/25 20:53:42 INFO ShutdownHookManager: Shutdown hook called

# %% [markdown]
# ## Further information and useful links
# [Back to top](#Contents)
