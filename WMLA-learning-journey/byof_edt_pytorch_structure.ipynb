# %% [markdown]
# # Using WMLA Elastic Distributed Training via API - a sample notebook

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Contents
#
# - [The big picture](#The-big-picture)
# - [Changes to your code](#Changes-to-your-code)
# - [Making dataset available](#Making-dataset-available)
# - [Set up API end point and log on](#Set-up-API-end-point-and-log-on)
# - [Submit job via API](#Submit-job-via-API)
# - [Monitor running job](#Monitor-running-job)
# - [Retrieve output and saved models](#Retrieve-output-and-saved-models)
#   - [Output](#Output)
#   - [Saved Models](#Saved-models)
# - [Debugging any issues](#Debugging-any-issues)
# - [Further information and useful links](#Further-information-and-useful-links)
#
# </div>

# %% [markdown]
# ## The big picture
# [Back to top](#Contents)
#
# This notebook details the process of taking your existing model training code and making the changes required to run the code using [IBM Watson Machine Learning](https://developer.ibm.com/linuxonpower/deep-learning-powerai/powerai-enterprise/) (WMLA) using Elastic Distributed Training.
#
# <span style='color:deeppink'>**TODO:** Link to blog with more details</span>
#
# The image below shows the various elements required to use EDT. In this notebook we will step through each of these elements in more detail. Through this process you will offload your code to a WMLA cluster, monitor the running job, retrieve the output and debug any issues seen. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/5_running_job.png) is also available.
#
# ![overall](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/5_running_job.gif)

# %% [markdown]
# ## Changes to your code
# [Back to top](#Contents)
#
# In this section we will take existing sample code and make the relevant changes required for use with EDT. An overview of these changes can be seen in the diagram below. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/2_code_adaptations.png) is also available.
#
# ![code](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/2_code_adaptations.gif)
#
# <span style='color:deeppink'>**TODO:** Add Kelvin's existing code here re changes to be made.</span>
#
# <span style='color:deeppink'>**TODO:** Add links to original code and updated code package which can be downloaded for testing / inspection.</span>

# %% [markdown]
# ## original RestNet18 model: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
# %load '/Users/Kelvin/Documents/WorkInProgress/WellsFargo/CSSC_EDT/pytorch_edt_cssc2/pytorch_mnist_EDT.py'
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.optim import lr_scheduler
from pathlib import Path

import sys
import os
from os import environ
import json


#  Importing libraries and setting up enviroment variables 
path=os.path.join(os.getenv("FABRIC_HOME"), "libs", "fabric.zip")
print(path)
sys.path.insert(0,path)
from fabric_model import FabricModel
from edtcallback import EDTLoggerCallback

dataDir = environ.get("DATA_DIR")
if dataDir is not None:
    print("dataDir is: %s"%dataDir)
else:
    print("Warning: not found DATA_DIR from os env!")


model_path = os.environ["RESULT_DIR"]+"/model/saved_model"
tb_directory = os.environ["LOG_DIR"]+"/tb"
print ("model_path: %s" %model_path)
print ("tb_directory: %s" %tb_directory)

# Data Loading function for EDT

def getDatasets():
    data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    }

    return (datasets.ImageFolder(os.path.join(dataDir, 'train'), data_transforms['train']),
            datasets.ImageFolder(os.path.join(dataDir, 'val'), data_transforms['val']))


def main():

  
    # Extract parameters for training
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batchsize', type=int, default=64, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--numWorker', type=int, default=100, metavar='N',
                        help='maxWorker')

    parser.add_argument('--epochs', type=int, default=5, metavar='N',
                        help='input epochs for training (default: 64)')

    args, unknow = parser.parse_known_args()
 
    print('args: ', args)

    #Define Model
    model_conv = torchvision.models.resnet18(pretrained=True)
    for param in model_conv.parameters():
        param.requires_grad = False

    num_ftrs = model_conv.fc.in_features
    model_conv.fc = nn.Linear(num_ftrs, 2)
    criterion = nn.CrossEntropyLoss()
    
    #inject learning_rate from HPO API and do the search
    optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.1, momentum=0.9)
    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

  
    # Replace the training and testing loops with EDT equivalents
    edt_m = FabricModel(model_conv, getDatasets, F.nll_loss, optimizer_conv, driver_logger=EDTLoggerCallback())
    edt_m.train(args.epochs, args.batchsize, args.numWorker)

if __name__ == '__main__':
    print('sys.argv: ', sys.argv)
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f74c16067160> in <module>
#       2 from __future__ import print_function
#       3 import argparse
# ----> 4 import torch
#       5 import torch.nn as nn
#       6 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Making dataset available
# [Back to top](#Contents)
#
# Next we will make our dataset available to the WMLA cluster as seen in the diagram below.
#
# ![data](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/3_dataset.png)
#
# <span style='color:deeppink'>**TODO:** Add details of where this should go and with what permissions. Details of ssh commands needed here?</span>

# %% [markdown]
# 1. Log on to DLI_DATA_FS directory
#
# 2. Download dataset
#
# ```
# wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
#
# Resolving download.pytorch.org... 99.86.230.63, 99.86.230.94, 99.86.230.13, ...
# Connecting to download.pytorch.org|99.86.230.63|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: 'hymenoptera_data.zip'
#
# hymenoptera_data.zip          100%[================================================>]  45.10M  11.0MB/s    in 4.5s
#
# 2020-02-19 17:01:52 (10.1 MB/s) - 'hymenoptera_data.zip' saved [47286322/47286322]
#
# ```
#
# 3. Unzip the zip file and modify file owner/group, that is equivalent to Instance Group Execution User
# ```
# [root@colonia04 dlidata]# chown -R egoadmin:egoadmin hymenopteradata/
# [root@colonia04 hymenopteradata]# pwd
# /dlidata/hymenopteradata
# [root@colonia04 hymenopteradata]# ls -lt
# total 0
# drwxr-x--- 4 egoadmin egoadmin 34 Jan  7 23:54 MNIST
# drwxr-xr-x 4 egoadmin egoadmin 30 Jan  7 23:08 val
# drwxr-xr-x 4 egoadmin egoadmin 30 Jan  7 23:08 train
# ```

# %% [markdown]
# ## Set up API end point and log on
# [Back to top](#Contents)
#
# In this section we set up the API endpoint which will be used in this notebook.
#
# <span style='color:deeppink'>**TODO:** Add existing details as to how to find this, what it should look it and where to find documentation.</span>

# %% [markdown]
# 1. Source the environment
#
# ```
# . $EGO_TOP/profile.platform
#
# ```
# 2. Login
#
# ```
# egosh user logon -u Admin -x Admin
# Logged on successfully
#
# ```
#
# 3. Retrieve Conductor Rest API Port
#
# ```
# egosh client view |grep -A 3 ASCD_REST_BASE_URL_1
# CLIENT NAME: ASCD_REST_BASE_URL_1
# DESCRIPTION: http://colonia04.platform:8280/platform/rest/
#
# ```
#
# 4.  Retrieve DLI (Deep Learning Impact) Rest API Port
#
# ```
# egosh client view |grep -A 3 DLPD_REST_BASE_URL_1
# CLIENT NAME: DLPD_REST_BASE_URL_1
# DESCRIPTION: http://colonia04.platform:9280/platform/rest/
#
# ```

# %% [markdown]
# ## Submit job via API
# [Back to top](#Contents)
#
# Now we need to structure our API job submission. There are various elements to this process as seen in the diagram below. Note that **this** jupyter notebook is the one referred to below. A [static version](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/4_api_setup.png) is also available.
#
# ![code](https://github.com/mandieq/shared_images/raw/master/wmla_api_pieces/4_api_setup.gif)
#
# <span style='color:deeppink'>**TODO:** Add existing code here re changes to be made. Include the first step as packaging the code we created in the last section.</span>
#
# <span style='color:deeppink'>**TODO:** Add existing code here to actually get the workload running! Should we add anything about watching GPU usage via various means? Or leave that to the blog?</span>

# %%
import requests, json
import pandas as pd
import datetime
# from IPython.display import display

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
# plt.rcParams['figure.figsize'] = [24, 8.0]
import seaborn as sns

pd.set_option('display.max_columns', 999)
pd.set_option('max_colwidth', 300)

import tarfile
import tempfile
import os

# %%
#Construct API call

master_host = 'colonia05.platform'
dli_rest_port = '9280'  #Deep Learning Impact Rest API Port
sc_rest_port = '8280' #Conductor Rest API Port

sc_rest_url = 'http://'+master_host+':'+sc_rest_port+'/platform/rest/conductor/v1'
dl_rest_url = 'http://'+master_host+':'+dli_rest_port+'/platform/rest/deeplearning/v1'

# User login details
#wmla_user = '**** ADD HERE ****'
#wmla_pwd = '**** ADD HERE ****'
wmla_user = 'Admin'
wmla_pwd = 'Admin'

myauth = (wmla_user, wmla_pwd)

# Instance Group to be used
#sig_name =  '***ADD Here***'
sig_name = 'dli-edt'

# REST call variables
headers = {'Accept': 'application/json'}
print (sc_rest_url)
print (dl_rest_url)

# Model Path
model_path = '/Users/Kelvin/Documents/WorkInProgress/WellsFargo/CSSC_EDT/pytorch_edt_cssc2'
# Out:
# http://colonia05.platform:8280/platform/rest/conductor/v1
# http://colonia05.platform:9280/platform/rest/deeplearning/v1

# %% [markdown]
# ## Package model files for training
# Package the updated model files into a tar file ending with `.modelDir.tar`

# %%
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))


MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
#make_tarfile(tempFile, '/path/to/your/file/')
#make_tarfile(tempFile, '/Users/Kelvin/Github/dli-1.2.3-wmla-1.2.1-samples/dli-1.2.3-wmla-1.2.1-samples/pytorch_edt/')
make_tarfile(tempFile, '/Users/Kelvin/Documents/WorkInProgress/WellsFargo/CSSC_EDT/pytorch_edt_cssc2')
print(" tempFile: " + tempFile)
files = {'file': open(tempFile, 'rb')}
# Out:
#  tempFile: /var/folders/l8/5dhpt4mn5zs6rjblzhlxp5300000gp/T/tmp1xgvo6vx.modelDir.tar

# %% [markdown]
# ## Log on
#
#
# Obtain login session tokens to be used for session authentication within the RESTful API. Tokens are valid for 8 hours.

# %%
r = requests.get(sc_rest_url+'/auth/logon', verify=False, auth=myauth, headers=headers) 

if r.ok:
    print ('\nLogon succeeded')
    
else: 
    print('\nLogon failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Logon succeeded

# %% [markdown]
# ## Check DL Frameworks details
#
# Check what framework plugins are available and see example execution commands.  In this demonstration we will use **edtPyTorch**

# %%
r = requests.get(dl_rest_url+'/execs/frameworks', auth=myauth, headers=headers, verify=False).json()
# Using the raw json, easier to see the examples given
print(json.dumps(r, indent=4))
# Out:
# [
#     {
#         "name": "edtKeras",
#         "description": "",
#         "desc": [
#             "Keras - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtKeras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "edtPyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch - IBM Elastic Distributed Training (EDT)",
#             "Examples:",
#             "$ python dlicmd.py --exec-start edtPyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "tensorflow1100",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow. Tested for Tensorflow 1.10.0.",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow1100 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PyTorch",
#         "description": "",
#         "desc": [
#             "PyTorch",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "PowerAICaffeIBM",
#         "description": "",
#         "desc": [
#             "IBM PowerAI IBM Caffe",
#             "NOTES:",
#             "-You must specify --model-dir flag to point to a directory containing both solver",
#             " and network files, and in the solver file, the path for the network file must not be ",
#             " a full path.",
#             "-Other paths such as snapshot, data source, in solver and network files must be",
#             " on a shared file system.",
#             "-Caffe's --gpu option will be overriden with 'all' since DLI allocates ",
#             " and manages GPUs. Use --gpuPerWorker option as shown below to request for number of GPUs.",
#             " Currently max gpuPerWorker is set to 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-dir <model-dir> --model-main lenet_solver.prototxt train",
#             "$ python dlicmd.py --exec-start PowerAICaffeIBM <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --gpuPerWorker 2 --model-dir <model-dir> --model-main lenet_solver.prototxt train"
#         ]
#     },
#     {
#         "name": "ddlTensorFlow",
#         "description": "",
#         "desc": [
#             "Tensorflow - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start  ddlTensorFlow --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 2 python --model-main ddl_mnist.py",
#             "  --ddl_opts=_QUOTE_-mode r:2_QUOTE_ "
#         ]
#     },
#     {
#         "name": "tensorflow",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow",
#             "NOTES:",
#             "- Since DLI manages GPU allocation, if you explicitly assign devices using",
#             "  calls such as `tf.device`, you should use Tensorflow configuration flag",
#             "  `allow_soft_placement=True`",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "ddlCaffe",
#         "description": "",
#         "desc": [
#             "Caffe - IBM PowerAI Distributed Deep Learning (DDL)",
#             "Notes:",
#             "  - Always use --exclusive option, in which case also make",
#             "    sure resource plans are configured appropriately",
#             "  - Need to specify --numWorker to number of GPUs to be allocated",
#             "  - Need to specify --accelerators to number of learners on each host",
#             "  - Use --model-dir to specify folder containing the model files",
#             "  - Use --model-main to specify the solver file",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "  - Do not pass host options such as -rf, --rankfile, -host, -machinefile, etc ...",
#             "    since rankfiles are automatically generated",
#             "Examples:",
#             "$ python dlicmd.py --exec-start ddlCaffe --exclusive --master-host <masterHost> --ig <ig> --cs-datastore-meta type=fs,data_path=datapath ",
#             "  --numWorker 4 --mpiarg --allow-run-as-root --accelerators 4 caffe train",
#             "  --model-main lenet_solver.prototxt --model-dir <modelDir>",
#             "  -ddl_update"
#         ]
#     },
#     {
#         "name": "PyTorch041",
#         "description": "",
#         "desc": [
#             "PyTorch041. Tested for torch version 0.4.1.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start PyTorch041 <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "keras",
#         "description": "",
#         "desc": [
#             "Keras",
#             "Examples:",
#             "$ python dlicmd.py --exec-start keras <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main keras_mnist_cnn.py"
#         ]
#     },
#     {
#         "name": "disttensorflow",
#         "description": "",
#         "desc": [
#             "Distributed TensorFlow",
#             "Instead of passing parameters such as ps_hosts, worker_hosts, specify --numPs",
#             "as in example below. Parameter servers (ps) and worker hosts will be allocated",
#             "dynamically.",
#             "Use --gpuPerWorker flag to specify number of GPUs per worker.",
#             "The maximum number of worker is 2.",
#             "The maximum number of GPUs per worker is 2.",
#             "Examples:",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 1 --gpuPerWorker 1",
#             "$ python dlicmd.py --exec-start disttensorflow <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py --numPs 1 --numWorker 2 --gpuPerWorker 1"
#         ]
#     },
#     {
#         "name": "tensorflow200_alpha",
#         "description": "",
#         "desc": [
#             "Single-node TensorFlow 2.0 preview",
#             "Examples:",
#             "$ python dlicmd.py --exec-start tensorflow20_preview <connection-options> --ig <ig> --cs-datastore-meta type=fs,data_path=mnist --model-main mnist.py"
#         ]
#     },
#     {
#         "name": "daskDistribution",
#         "description": "",
#         "desc": [
#             "daskDistribution - IBM PowerAI 1.6.2",
#             "Notes:",
#             "  - Need to specify --numWorker for number of GPUs to be allocated",
#             "  - Use --model-main to specify the solver file",
#             "  - Use --dask-scheduler-args optionally to specify extra arguments",
#             "      to be passed to dask-scheduler command",
#             "  - Use --dask-cuda-worker-args optionally to specify extra arguments",
#             "      to be passed to dask-cuda-worker command",
#             "  - Use --keep-dask-logs optionally to skip cleaning up of dask cluster daemons logs",
#             "  - Use --skip-checks optionally to skip performing validations of",
#             "      the environment before launching dask cuda cluster daemons",
#             "  - Use _QUOTE_ to pass strings with spaces as parameters",
#             "Example:",
#             "python dlicmd.py --exec-start daskDistribution --master-host <masterHost> --ig <ig>",
#             "  --numWorker <n> --cs-datastore-meta type=fs --dask-scheduler-args",
#             "  \"<args of dask-scheduler command>\" --dask-cuda-worker-args",
#             "  \"<args of dask-cuda-worker command>\" --skip-checks --keep-dask-logs",
#             "  python --model-main <dask python application>"
#         ]
#     }
# ]

# %% [markdown]
# ## Arguments for API call
# ### Equivalent of flags used if running command directly on WMLA CLI, including:

# %%
framework_name = 'edtPyTorch' # DL Framework to use, from list given above
dataset_location = 'hymenoptera_data' # relative path of your data set 
local_dir_containing_your_code = 'pytorch_edt_cssc2'
number_of_GPU = '2' # number of GPUs for elastic distribution
name_of_your_code_file = 'pytorch_mnist_EDT.py' # Main model file as opened locally above


args = '--exec-start {} \
        --cs-datastore-meta type=fs,data_path={} \
        --model-dir {} \
        --edt-options maxWorkers={} \
        --model-main {} \
        --epochs 50  \
        '.format(framework_name, dataset_location, local_dir_containing_your_code, number_of_GPU, name_of_your_code_file)

print ("args: " + args)
# Out:
# args: --exec-start edtPyTorch         --cs-datastore-meta type=fs,data_path=hymenoptera_data         --model-dir pytorch_edt_cssc2         --edt-options maxWorkers=2         --model-main pytorch_mnist_EDT.py         --epochs 50

# %% [markdown]
# ## Submit Job via API call

# %%
r = requests.post(dl_rest_url+'/execs?sigName='+sig_name+'&args='+args, files=files,
                  auth=myauth, headers=headers, verify=False)

if r.ok:
    exec_id = r.json()['id']
    sig_id = r.json()['sigId']
    driver_id = r.json()['submissionId']
    print ('\nModel submitted successfully \Driver ID: {}'.format(driver_id))
    print ('Exec ID: {}'.format(exec_id))
    print ('SIG ID: {}'.format(sig_id))
else: 
    print('\nModel submission failed with code={}, {}'. format(r.status_code, r.content))
# Out:
# Model submitted successfully \Driver ID: driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055
# Exec ID: Admin-2809611603258194-1703562770
# SIG ID: 63027c69-543b-451c-9a03-9c850784725f

# %% [markdown]
# ## Monitor running job
# [Back to top](#Contents)
#
# Once the job is submitted successfully we can monitor the running job.
#
# <span style='color:deeppink'>**TODO:** Add existing code here re how to do this.</span>

# %%
# Check status of all RUNNING jobs in SIG (rerun cell to refresh)

monitor = []
monitor_output = []

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications?state=RUNNING', 
                auth=myauth, headers=headers, verify=False).json()


       
if (len(r) == 0):
    print ('No jobs running')
    
else:
    
    # Filter out the relevant information
    monitor.append([(
        job['driver']['id'],
        job['driver']['state'],
        job['apprunduration'],
        job['gpuslots'],
        job['gpumemused']['total'],
        job['gpudevutil']['total'],
    ) for job in r])

    monitor_output = pd.DataFrame([item for monitor in monitor for item in monitor])
    monitor_output.columns = [
        'Driver ID', 
        'State', 
        'Run duration (mins)',
        'GPU slots',
        'Total GPU memory used',
        'Total GPU utilsation (%) ',
    ]
    
    for job in r:
        executors = job['executors']
        

monitor_output
# Out:
#                                                          Driver ID    State  \
# 0  driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055  RUNNING
#
#    Run duration (mins)  GPU slots Total GPU memory used  \
# 0             0.143417          2                     0
#
#   Total GPU utilsation (%)
# 0                       0.0

# %%
# Check status of job submitted 

r = requests.get(dl_rest_url+'/execs/'+exec_id, auth=myauth, headers=headers, verify=False).json()
pd.read_json(json.dumps(r), orient='index')
# Out:
#                                                                                                                                                                                                                                                          0
# appId                                                                                                                                                                                         app-20200221160530-0043-c1d7e3c6-1fd9-4294-b17c-47a5c3e46323
# args               --exec-start edtPyTorch         --cs-datastore-meta type=fs,data_path=hymenoptera_data         --model-dir pytorch_edt_cssc2         --edt-options maxWorkers=2         --model-main pytorch_mnist_EDT.py         --epochs 50
# executionUserName                                                                                                                                                                                                                                 egoadmin
# id                                                                                                                                                                                                                        Admin-2781904014777372-695105367
# masterURL                                                                                                                                                                                                                  spark://colonia05.platform:6072
# sigId                                                                                                                                                                                                                 63027c69-543b-451c-9a03-9c850784725f
# sigName                                                                                                                                                                                                                                            dli-edt
# state                                                                                                                                                                                                                                              RUNNING
# submissionId                                                                                                                                                                               driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4
# userName                                                                                                                                                                                                                                             Admin

# %% [markdown]
# ## Retrieve output and saved models
# [Back to top](#Contents)
#
# After the job completes then we can retrieve the output, logs and saved models.
#
# ### Output
#
# <span style='color:deeppink'>**TODO:** Add existing code.</span>
#
# ### Saved models
#
# <span style='color:deeppink'>**TODO:** Add existing code regarding changes to get a model saved. And then how to get the saved version back.</span>

# %% [markdown]
# ## Save Model

# %%
# Get model from training job - downloads zip file (with progress bar) of saved model to directory local to this notebook
# (note that you need to save model in your code using the environment variable for location)

import requests, zipfile, io
from tqdm.notebook import tqdm

r = requests.get(dl_rest_url+'/execs/'+exec_id+'/result', auth=myauth, stream=True)

total_size = int(r.headers.get('Content-Disposition').split('size=')[1])
block_size = 1024 #1 Kibibyte
t=tqdm(total=total_size, unit='iB', unit_scale=True)

with open('model.zip', 'wb') as f:
    for data in r.iter_content(block_size):
        t.update(len(data))
        f.write(data)
t.close()

# %% [markdown]
# ## Retrieve Training Metric
#
# <span style='color:deeppink'>**TODO:** Plot the graph of metric of Loss and Accuracy.</span>

# %%
# Check status of job submitted 


r = requests.get(dl_rest_url+'/execs/'+exec_id+'/log', auth=myauth, headers=headers, verify=False).json()
print(r)
# Out:
# [2020-02-21 16:05:46] Train,	Timestamp: 1582297546490,	Global steps: 1,	Iteration: 2,	Loss: 0.00124,	Accuracy: 0.00469
# [2020-02-21 16:05:46] Train,	Timestamp: 1582297546592,	Global steps: 2,	Iteration: 3,	Loss: 0.00105,	Accuracy: 0.00508
# [2020-02-21 16:05:47] Train,	Timestamp: 1582297547028,	Global steps: 3,	Iteration: 4,	Loss: -0.10088,	Accuracy: 0.00542
# [2020-02-21 16:05:47] Train,	Timestamp: 1582297547486,	Global steps: 4,	Iteration: 0,	Loss: -0.37705,	Accuracy: 0.00577
# [2020-02-21 16:05:49] Train,	Timestamp: 1582297549693,	Global steps: 5,	Iteration: 2,	Loss: -0.65836,	Accuracy: 0.0075
# [2020-02-21 16:05:50] Train,	Timestamp: 1582297550209,	Global steps: 6,	Iteration: 3,	Loss: -0.74346,	Accuracy: 0.00811
# [2020-02-21 16:05:50] Train,	Timestamp: 1582297550785,	Global steps: 7,	Iteration: 4,	Loss: -1.00607,	Accuracy: 0.00803
# [2020-02-21 16:05:51] Train,	Timestamp: 1582297551185,	Global steps: 8,	Iteration: 0,	Loss: -2.13375,	Accuracy: 0.00654
# [2020-02-21 16:05:53] Train,	Timestamp: 1582297553370,	Global steps: 9,	Iteration: 2,	Loss: -2.49759,	Accuracy: 0.00698
# [2020-02-21 16:05:53] Train,	Timestamp: 1582297553947,	Global steps: 10,	Iteration: 3,	Loss: -2.61185,	Accuracy: 0.00722
# [2020-02-21 16:05:54] Train,	Timestamp: 1582297554416,	Global steps: 11,	Iteration: 4,	Loss: -2.99057,	Accuracy: 0.00701
# [2020-02-21 16:05:54] Train,	Timestamp: 1582297554833,	Global steps: 12,	Iteration: 0,	Loss: -5.02715,	Accuracy: 0.00846
# [2020-02-21 16:05:56] Train,	Timestamp: 1582297556979,	Global steps: 13,	Iteration: 2,	Loss: -5.31192,	Accuracy: 0.00793
# [2020-02-21 16:05:57] Train,	Timestamp: 1582297557462,	Global steps: 14,	Iteration: 3,	Loss: -5.38593,	Accuracy: 0.00733
# [2020-02-21 16:05:57] Train,	Timestamp: 1582297557923,	Global steps: 15,	Iteration: 4,	Loss: -5.84849,	Accuracy: 0.00734
# [2020-02-21 16:05:58] Train,	Timestamp: 1582297558397,	Global steps: 16,	Iteration: 0,	Loss: -8.8169,	Accuracy: 0.0075
# [2020-02-21 16:06:00] Train,	Timestamp: 1582297560558,	Global steps: 17,	Iteration: 2,	Loss: -8.84591,	Accuracy: 0.00647
# [2020-02-21 16:06:01] Train,	Timestamp: 1582297561045,	Global steps: 18,	Iteration: 3,	Loss: -8.86673,	Accuracy: 0.00644
# [2020-02-21 16:06:01] Train,	Timestamp: 1582297561592,	Global steps: 19,	Iteration: 4,	Loss: -9.40059,	Accuracy: 0.00676
# [2020-02-21 16:06:01] Train,	Timestamp: 1582297561967,	Global steps: 20,	Iteration: 0,	Loss: -13.15553,	Accuracy: 0.00673
# [2020-02-21 16:06:04] Train,	Timestamp: 1582297564151,	Global steps: 21,	Iteration: 2,	Loss: -12.92896,	Accuracy: 0.00664
# [2020-02-21 16:06:04] Train,	Timestamp: 1582297564651,	Global steps: 22,	Iteration: 3,	Loss: -12.86903,	Accuracy: 0.00639
# [2020-02-21 16:06:05] Train,	Timestamp: 1582297565183,	Global steps: 23,	Iteration: 4,	Loss: -13.40984,	Accuracy: 0.00639
# [2020-02-21 16:06:05] Train,	Timestamp: 1582297565575,	Global steps: 24,	Iteration: 0,	Loss: -18.45876,	Accuracy: 0.00692
# [2020-02-21 16:06:07] Train,	Timestamp: 1582297567922,	Global steps: 25,	Iteration: 2,	Loss: -17.76532,	Accuracy: 0.00681
# [2020-02-21 16:06:08] Train,	Timestamp: 1582297568425,	Global steps: 26,	Iteration: 3,	Loss: -17.56091,	Accuracy: 0.00661
# [2020-02-21 16:06:08] Train,	Timestamp: 1582297568907,	Global steps: 27,	Iteration: 4,	Loss: -18.07857,	Accuracy: 0.00672
# [2020-02-21 16:06:09] Train,	Timestamp: 1582297569306,	Global steps: 28,	Iteration: 0,	Loss: -23.84007,	Accuracy: 0.00596
# [2020-02-21 16:06:11] Train,	Timestamp: 1582297571513,	Global steps: 29,	Iteration: 2,	Loss: -22.70701,	Accuracy: 0.00603
# [2020-02-21 16:06:11] Train,	Timestamp: 1582297572008,	Global steps: 30,	Iteration: 3,	Loss: -22.44917,	Accuracy: 0.00656
# [2020-02-21 16:06:12] Train,	Timestamp: 1582297572479,	Global steps: 31,	Iteration: 4,	Loss: -22.98368,	Accuracy: 0.00656
# [2020-02-21 16:06:12] Train,	Timestamp: 1582297572931,	Global steps: 32,	Iteration: 0,	Loss: -29.56323,	Accuracy: 0.00558
# [2020-02-21 16:06:15] Train,	Timestamp: 1582297575123,	Global steps: 33,	Iteration: 2,	Loss: -28.0907,	Accuracy: 0.00638
# [2020-02-21 16:06:15] Train,	Timestamp: 1582297575680,	Global steps: 34,	Iteration: 3,	Loss: -27.59657,	Accuracy: 0.00617
# [2020-02-21 16:06:16] Train,	Timestamp: 1582297576133,	Global steps: 35,	Iteration: 4,	Loss: -28.06056,	Accuracy: 0.00631
# [2020-02-21 16:06:16] Train,	Timestamp: 1582297576514,	Global steps: 36,	Iteration: 0,	Loss: -36.25848,	Accuracy: 0.00558
# [2020-02-21 16:06:18] Train,	Timestamp: 1582297578721,	Global steps: 37,	Iteration: 2,	Loss: -33.96388,	Accuracy: 0.00603
# [2020-02-21 16:06:19] Train,	Timestamp: 1582297579248,	Global steps: 38,	Iteration: 3,	Loss: -33.29865,	Accuracy: 0.00644
# [2020-02-21 16:06:19] Train,	Timestamp: 1582297579786,	Global steps: 39,	Iteration: 4,	Loss: -33.68295,	Accuracy: 0.00648
# [2020-02-21 16:06:20] Train,	Timestamp: 1582297580207,	Global steps: 40,	Iteration: 0,	Loss: -42.71287,	Accuracy: 0.00538
# [2020-02-21 16:06:22] Train,	Timestamp: 1582297582454,	Global steps: 41,	Iteration: 2,	Loss: -39.83377,	Accuracy: 0.00603
# [2020-02-21 16:06:23] Train,	Timestamp: 1582297583012,	Global steps: 42,	Iteration: 3,	Loss: -38.95979,	Accuracy: 0.00628
# [2020-02-21 16:06:23] Train,	Timestamp: 1582297583511,	Global steps: 43,	Iteration: 4,	Loss: -39.34339,	Accuracy: 0.00623
# [2020-02-21 16:06:23] Train,	Timestamp: 1582297583908,	Global steps: 44,	Iteration: 0,	Loss: -49.45741,	Accuracy: 0.00615
# [2020-02-21 16:06:26] Train,	Timestamp: 1582297586126,	Global steps: 45,	Iteration: 2,	Loss: -46.03596,	Accuracy: 0.0069
# [2020-02-21 16:06:26] Train,	Timestamp: 1582297586623,	Global steps: 46,	Iteration: 3,	Loss: -44.94634,	Accuracy: 0.00667
# [2020-02-21 16:06:27] Train,	Timestamp: 1582297587184,	Global steps: 47,	Iteration: 4,	Loss: -45.13218,	Accuracy: 0.00668
# [2020-02-21 16:06:27] Train,	Timestamp: 1582297587578,	Global steps: 48,	Iteration: 0,	Loss: -56.17783,	Accuracy: 0.00519
# [2020-02-21 16:06:29] Train,	Timestamp: 1582297589806,	Global steps: 49,	Iteration: 2,	Loss: -51.96634,	Accuracy: 0.00586
# [2020-02-21 16:06:30] Train,	Timestamp: 1582297590316,	Global steps: 50,	Iteration: 3,	Loss: -50.84908,	Accuracy: 0.00606
# [2020-02-21 16:06:30] Train,	Timestamp: 1582297590794,	Global steps: 51,	Iteration: 4,	Loss: -50.97132,	Accuracy: 0.00598
# [2020-02-21 16:06:31] Train,	Timestamp: 1582297591188,	Global steps: 52,	Iteration: 0,	Loss: -63.75987,	Accuracy: 0.00673
# [2020-02-21 16:06:33] Train,	Timestamp: 1582297593483,	Global steps: 53,	Iteration: 2,	Loss: -58.39161,	Accuracy: 0.00603
# [2020-02-21 16:06:33] Train,	Timestamp: 1582297593951,	Global steps: 54,	Iteration: 3,	Loss: -57.20545,	Accuracy: 0.00667
# [2020-02-21 16:06:34] Train,	Timestamp: 1582297594436,	Global steps: 55,	Iteration: 4,	Loss: -57.27326,	Accuracy: 0.00648
# [2020-02-21 16:06:34] Train,	Timestamp: 1582297594830,	Global steps: 56,	Iteration: 0,	Loss: -69.92994,	Accuracy: 0.00654
# [2020-02-21 16:06:37] Train,	Timestamp: 1582297597012,	Global steps: 57,	Iteration: 2,	Loss: -64.7948,	Accuracy: 0.00698
# [2020-02-21 16:06:37] Train,	Timestamp: 1582297597592,	Global steps: 58,	Iteration: 3,	Loss: -62.93318,	Accuracy: 0.00639
# [2020-02-21 16:06:38] Train,	Timestamp: 1582297598067,	Global steps: 59,	Iteration: 4,	Loss: -63.11339,	Accuracy: 0.00664
# [2020-02-21 16:06:38] Train,	Timestamp: 1582297598465,	Global steps: 60,	Iteration: 0,	Loss: -77.77984,	Accuracy: 0.00673
# [2020-02-21 16:06:40] Train,	Timestamp: 1582297600749,	Global steps: 61,	Iteration: 2,	Loss: -71.54942,	Accuracy: 0.00681
# [2020-02-21 16:06:41] Train,	Timestamp: 1582297601230,	Global steps: 62,	Iteration: 3,	Loss: -69.44358,	Accuracy: 0.00656
# [2020-02-21 16:06:41] Train,	Timestamp: 1582297601741,	Global steps: 63,	Iteration: 4,	Loss: -69.42465,	Accuracy: 0.00676
# [2020-02-21 16:06:42] Train,	Timestamp: 1582297602198,	Global steps: 64,	Iteration: 0,	Loss: -84.39798,	Accuracy: 0.00519
# [2020-02-21 16:06:44] Train,	Timestamp: 1582297604504,	Global steps: 65,	Iteration: 2,	Loss: -77.44354,	Accuracy: 0.00552
# [2020-02-21 16:06:44] Train,	Timestamp: 1582297604998,	Global steps: 66,	Iteration: 3,	Loss: -75.50691,	Accuracy: 0.00572
# [2020-02-21 16:06:45] Train,	Timestamp: 1582297605505,	Global steps: 67,	Iteration: 4,	Loss: -75.45248,	Accuracy: 0.00594
# [2020-02-21 16:06:45] Train,	Timestamp: 1582297605876,	Global steps: 68,	Iteration: 0,	Loss: -93.4699,	Accuracy: 0.0075
# [2020-02-21 16:06:48] Train,	Timestamp: 1582297608143,	Global steps: 69,	Iteration: 2,	Loss: -84.98588,	Accuracy: 0.00741
# [2020-02-21 16:06:48] Train,	Timestamp: 1582297608645,	Global steps: 70,	Iteration: 3,	Loss: -82.71674,	Accuracy: 0.00722
# [2020-02-21 16:06:49] Train,	Timestamp: 1582297609140,	Global steps: 71,	Iteration: 4,	Loss: -82.15813,	Accuracy: 0.00676
# [2020-02-21 16:06:49] Train,	Timestamp: 1582297609550,	Global steps: 72,	Iteration: 0,	Loss: -99.67454,	Accuracy: 0.00712
# [2020-02-21 16:06:51] Train,	Timestamp: 1582297611742,	Global steps: 73,	Iteration: 2,	Loss: -91.20806,	Accuracy: 0.00707
# [2020-02-21 16:06:52] Train,	Timestamp: 1582297612240,	Global steps: 74,	Iteration: 3,	Loss: -88.95941,	Accuracy: 0.00711
# [2020-02-21 16:06:52] Train,	Timestamp: 1582297612802,	Global steps: 75,	Iteration: 4,	Loss: -88.46529,	Accuracy: 0.00693
# [2020-02-21 16:06:53] Train,	Timestamp: 1582297613210,	Global steps: 76,	Iteration: 0,	Loss: -106.74546,	Accuracy: 0.00481
# [2020-02-21 16:06:55] Train,	Timestamp: 1582297615493,	Global steps: 77,	Iteration: 2,	Loss: -97.56782,	Accuracy: 0.00552
# [2020-02-21 16:06:55] Train,	Timestamp: 1582297616002,	Global steps: 78,	Iteration: 3,	Loss: -94.9278,	Accuracy: 0.00594
# [2020-02-21 16:06:56] Train,	Timestamp: 1582297616478,	Global steps: 79,	Iteration: 4,	Loss: -94.38238,	Accuracy: 0.0059
# [2020-02-21 16:06:56] Train,	Timestamp: 1582297616870,	Global steps: 80,	Iteration: 0,	Loss: -115.33083,	Accuracy: 0.00692
# [2020-02-21 16:06:59] Train,	Timestamp: 1582297619090,	Global steps: 81,	Iteration: 2,	Loss: -104.41295,	Accuracy: 0.00621
# [2020-02-21 16:06:59] Train,	Timestamp: 1582297619605,	Global steps: 82,	Iteration: 3,	Loss: -101.29523,	Accuracy: 0.00583
# [2020-02-21 16:07:00] Train,	Timestamp: 1582297620156,	Global steps: 83,	Iteration: 4,	Loss: -100.88048,	Accuracy: 0.00623
# [2020-02-21 16:07:00] Train,	Timestamp: 1582297620549,	Global steps: 84,	Iteration: 0,	Loss: -123.17783,	Accuracy: 0.00654
# [2020-02-21 16:07:02] Train,	Timestamp: 1582297622729,	Global steps: 85,	Iteration: 2,	Loss: -112.31442,	Accuracy: 0.00724
# [2020-02-21 16:07:03] Train,	Timestamp: 1582297623259,	Global steps: 86,	Iteration: 3,	Loss: -108.58607,	Accuracy: 0.00678
# [2020-02-21 16:07:03] Train,	Timestamp: 1582297623764,	Global steps: 87,	Iteration: 4,	Loss: -107.94392,	Accuracy: 0.00689
# [2020-02-21 16:07:04] Train,	Timestamp: 1582297624139,	Global steps: 88,	Iteration: 0,	Loss: -129.77532,	Accuracy: 0.00538
# [2020-02-21 16:07:06] Train,	Timestamp: 1582297626393,	Global steps: 89,	Iteration: 2,	Loss: -117.8627,	Accuracy: 0.00569
# [2020-02-21 16:07:06] Train,	Timestamp: 1582297626913,	Global steps: 90,	Iteration: 3,	Loss: -114.77511,	Accuracy: 0.00617
# [2020-02-21 16:07:07] Train,	Timestamp: 1582297627417,	Global steps: 91,	Iteration: 4,	Loss: -113.95709,	Accuracy: 0.00631
# [2020-02-21 16:07:07] Train,	Timestamp: 1582297627799,	Global steps: 92,	Iteration: 0,	Loss: -137.69512,	Accuracy: 0.00635
# [2020-02-21 16:07:09] Train,	Timestamp: 1582297629994,	Global steps: 93,	Iteration: 2,	Loss: -124.77581,	Accuracy: 0.00629
# [2020-02-21 16:07:10] Train,	Timestamp: 1582297630555,	Global steps: 94,	Iteration: 3,	Loss: -120.64739,	Accuracy: 0.00617
# [2020-02-21 16:07:11] Train,	Timestamp: 1582297631038,	Global steps: 95,	Iteration: 4,	Loss: -120.03729,	Accuracy: 0.00639
# [2020-02-21 16:07:11] Train,	Timestamp: 1582297631455,	Global steps: 96,	Iteration: 0,	Loss: -146.30665,	Accuracy: 0.00731
# [2020-02-21 16:07:13] Train,	Timestamp: 1582297633823,	Global steps: 97,	Iteration: 2,	Loss: -131.35581,	Accuracy: 0.00681
# [2020-02-21 16:07:14] Train,	Timestamp: 1582297634381,	Global steps: 98,	Iteration: 3,	Loss: -127.84305,	Accuracy: 0.00694
# [2020-02-21 16:07:14] Train,	Timestamp: 1582297634848,	Global steps: 99,	Iteration: 4,	Loss: -126.77149,	Accuracy: 0.0066
# [2020-02-21 16:07:15] Train,	Timestamp: 1582297635246,	Global steps: 100,	Iteration: 0,	Loss: -151.85111,	Accuracy: 0.00596
# [2020-02-21 16:07:17] Train,	Timestamp: 1582297637425,	Global steps: 101,	Iteration: 2,	Loss: -138.58982,	Accuracy: 0.00629
# [2020-02-21 16:07:17] Train,	Timestamp: 1582297637927,	Global steps: 102,	Iteration: 3,	Loss: -134.71369,	Accuracy: 0.00639
# [2020-02-21 16:07:18] Train,	Timestamp: 1582297638475,	Global steps: 103,	Iteration: 4,	Loss: -133.4517,	Accuracy: 0.00635
# [2020-02-21 16:07:18] Train,	Timestamp: 1582297638868,	Global steps: 104,	Iteration: 0,	Loss: -159.26219,	Accuracy: 0.00635
# [2020-02-21 16:07:21] Train,	Timestamp: 1582297641052,	Global steps: 105,	Iteration: 2,	Loss: -144.86849,	Accuracy: 0.00629
# [2020-02-21 16:07:21] Train,	Timestamp: 1582297641601,	Global steps: 106,	Iteration: 3,	Loss: -140.47161,	Accuracy: 0.00639
# [2020-02-21 16:07:22] Train,	Timestamp: 1582297642103,	Global steps: 107,	Iteration: 4,	Loss: -139.3369,	Accuracy: 0.00656
# [2020-02-21 16:07:22] Train,	Timestamp: 1582297642499,	Global steps: 108,	Iteration: 0,	Loss: -167.90732,	Accuracy: 0.00577
# [2020-02-21 16:07:24] Train,	Timestamp: 1582297644653,	Global steps: 109,	Iteration: 2,	Loss: -152.48056,	Accuracy: 0.00621
# [2020-02-21 16:07:25] Train,	Timestamp: 1582297645203,	Global steps: 110,	Iteration: 3,	Loss: -148.15378,	Accuracy: 0.00661
# [2020-02-21 16:07:25] Train,	Timestamp: 1582297645695,	Global steps: 111,	Iteration: 4,	Loss: -146.49127,	Accuracy: 0.00635
# [2020-02-21 16:07:26] Train,	Timestamp: 1582297646100,	Global steps: 112,	Iteration: 0,	Loss: -174.39524,	Accuracy: 0.00615
# [2020-02-21 16:07:28] Train,	Timestamp: 1582297648332,	Global steps: 113,	Iteration: 2,	Loss: -158.32848,	Accuracy: 0.00621
# [2020-02-21 16:07:28] Train,	Timestamp: 1582297648825,	Global steps: 114,	Iteration: 3,	Loss: -153.78665,	Accuracy: 0.00644
# [2020-02-21 16:07:29] Train,	Timestamp: 1582297649335,	Global steps: 115,	Iteration: 4,	Loss: -152.47832,	Accuracy: 0.00648
# [2020-02-21 16:07:29] Train,	Timestamp: 1582297649740,	Global steps: 116,	Iteration: 0,	Loss: -182.38899,	Accuracy: 0.00538
# [2020-02-21 16:07:31] Train,	Timestamp: 1582297651955,	Global steps: 117,	Iteration: 2,	Loss: -165.57766,	Accuracy: 0.00595
# [2020-02-21 16:07:32] Train,	Timestamp: 1582297652439,	Global steps: 118,	Iteration: 3,	Loss: -160.78984,	Accuracy: 0.00606

# %% [markdown]
# ## Debugging any issues
# [Back to top](#Contents)
#
# In the case where you have issues during the process detailed above, there are a number of detailed logs that you can view to understand what is happening on the WMLA cluster.
#
# <span style='color:deeppink'>**TODO:** Overview of the various logs available and then API calls.</span>

# %% [markdown]
# ## Retrieve Training Driver Stdout Log

# %%
# Get Spectrum Conductor logs for training run - shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# load extra config from : /dlishared//conf
# Setting up spark environment on node colonia05.platform
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/dlishared/;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2;export LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2;export FABRIC_HOME=/dlishared//fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2;export DLI_EXECID=Admin-2781904014777372-695105367;export PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2;export DATA_PATH=hymenoptera_data
# 20/02/21 16:05:24 INFO Conda variables: conda_home=/opt/anaconda3, conda_env=dlipy3, python=/opt/anaconda3/envs/dlipy3/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=
# 20/02/21 16:05:24 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/02/21 16:05:24 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/leIwNrlJ/0	2020-02-21 16:05:24.104396085 +0100
# [D]: >> 0-1: +++ /tmp/leIwNrlJ/1	2020-02-21 16:05:24.344396949 +0100
# [D]: >> 0-1: @@ -1,13 +1,211 @@
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@"
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@" && __conda_reactivate
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA;
# [D]: >> 0-1: + *)
# [D]: >> 0-1: + :;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PS1="$CONDA_PS1_BACKUP";
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \hash -r;
# [D]: >> 0-1: + \local ask_conda;
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \rehash;
# [D]: >> 0-1: + \unset CONDA_PS1_BACKUP;
# [D]: >> 0-1: + __conda_activate "$cmd" "$@"
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + activate | deactivate)
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix "$cmd" "$@")" || \return $?;
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix reactivate)" || \return $?;
# [D]: >> 0-1: + case "$cmd" in
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + esac;
# [D]: >> 0-1: + eval "export $save_var=$orig_val";
# [D]: >> 0-1: + eval "orig_val=\${${orig_var}-unset}";
# [D]: >> 0-1: + eval "save_val=\${${save_var}-xxx}";
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "$save_val" = xxx ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [ -n "${POSH_VERSION:+x}" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + install | update | upgrade | remove | uninstall)
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + local orig_val;
# [D]: >> 0-1: + local orig_var="$2";
# [D]: >> 0-1: + local save_val;
# [D]: >> 0-1: + local save_var="POWERAI_${package}_${orig_var}";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC___conda_activate()=() {  if [ -n "${CONDA_PS1_BACKUP:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_hashr()=() {  if [ -n "${ZSH_VERSION:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_reactivate()=() {  \local ask_conda;
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_conda()=() {  if [ "$#" -lt 1 ]; then
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_powerai_save_var_initial()=() {  local package="$1";
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1: +CAFFE_BIN=/opt/anaconda3/envs/dlipy3/bin
# [D]: >> 0-1: +COMPONENT=tensorflow
# [D]: >> 0-1: +CONDA_DEFAULT_ENV=dlipy3
# [D]: >> 0-1: +CONDA_EXE=/opt/anaconda3/bin/conda
# [D]: >> 0-1: +CONDA_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +CONDA_PROMPT_MODIFIER=(dlipy3)
# [D]: >> 0-1: +CONDA_SHLVL=1
# [D]: >> 0-1: +CUDA_TOOLKIT_LIB_PATH=/opt/anaconda3/envs/dlipy3/cuda/lib:
# [D]: >> 0-1: +DATA_PATH=hymenoptera_data
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=dlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1:  DLI_CONDA_HOME=/opt/anaconda3
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/dlidata/
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=Admin-2781904014777372-695105367
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/dlishared//fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1:  DLI_IS_DRIVER=true
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/dliresult/
# [D]: >> 0-1: +DLI_SHARED_FS=/dlishared/
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1:  DL_NFS_PATH=/dlishared/
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1:  EGO_CONFDIR=/dlishared/conductor_share_top/kernel/conf
# [D]: >> 0-1: @@ -16,15 +214,35 @@
# [D]: >> 0-1:  EGO_LIBDIR=/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1:  EGO_MASTER_LIST_PEM=colonia05.platform
# [D]: >> 0-1:  EGO_TOP=/opt/ibm/spectrumcomputing
# [D]: >> 0-1: +FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +GREP=/bin/grep
# [D]: >> 0-1:  HADOOP_CONF_DIR=
# [D]: >> 0-1:  HADOOP_HOME=
# [D]: >> 0-1:  HOME=/home/egoadmin
# [D]: >> 0-1: +HOSTNAME_F=colonia05.platform
# [D]: >> 0-1:  JAVA_HOME=/opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1580185149401
# [D]: >> 0-1: -LD_LIBRARY_PATH=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1: +MPI_ROOT=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OMP_NUM_THREADS=16
# [D]: >> 0-1: +OPAL_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +POWERAI_caffe_CAFFE_BIN=unset
# [D]: >> 0-1: +POWERAI_caffe_OMP_NUM_THREADS=16
# [D]: >> 0-1: +POWERAI_pytorch_OMP_NUM_THREADS=16
# [D]: >> 0-1: +PS1=(dlipy3)
# [D]: >> 0-1:  PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1:  PWD=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4
# [D]: >> 0-1: +PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=egoadmin
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -83,6 +301,34 @@
# [D]: >> 0-1:  SPARK_PRINT_LAUNCH_COMMAND=1
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=egoadmin
# [D]: >> 0-1: +SYS_PYTHON_MAJOR=3
# [D]: >> 0-1: +SYS_PYTHON_MINOR=6
# [D]: >> 0-1: +TF_INCLUDE_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/include
# [D]: >> 0-1: +TF_LIBRARY_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1: +TF_PKG_PATH=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1:  USER=egoadmin
# [D]: >> 0-1: +USER_UID=1001
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1: +_CE_CONDA=
# [D]: >> 0-1: +_CE_M=
# [D]: >> 0-1: +_CONDA_ROOT=/opt/anaconda3
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/leIwNrlJ
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to
# Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data
# Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367
# Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/log/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4.colonia05.platform
# Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/model
# /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4.colonia05.platform/
# 20/02/21 16:05:24 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=
# DLI_CONDA_HOME=/opt/anaconda3
# DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# DL_NFS_PATH=/dlishared/
# DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2:
# PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=egoadmin
# USER_UID=1001
# DLI_EXECID=Admin-2781904014777372-695105367
# SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4.colonia05.platform/
# 20/02/21 16:05:24 INFO finish spark environment setup.
# /dlishared//fabric/1.2.3/libs/fabric.zip
# <> DATA_DIR /dlidata//hymenoptera_data
# <> RESULT_DIR /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367
# <> LOG_DIR /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/log/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4.colonia05.platform
# <> SAVED_MODEL_DIR /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/model
# Using pytorch backend.
# /dlishared//fabric/1.2.3/libs/fabric.zip/fabric_zmqservice/rep_stream_handler.py:15: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
# libunformatworker.so loaded successfully
# Using spark scheduler.
# > fabric loaded from /dlishared//fabric/1.2.3/libs/fabric.zip
# dataDir is: /dlidata//hymenoptera_data
# model_path: /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/model/saved_model
# tb_directory: /dliresult//egoadmin/batchworkdir/Admin-2781904014777372-695105367/log/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4.colonia05.platform/tb
# sys.argv:  ['.//pytorch_mnist_EDT.py', '--dataControlSchema', '0', '--weightSyncInterval', '5', '--numWorker', '2', '--usegpuNumPerWorker', '1', '--commIPNetwork', '10.3.64.217/24', '--isTest', 'true', '--globalStep', 'null', '--testIter', '10', '--testInterval', 'None', '--isESE', 'true', '--mode', '1', '--execPathParam', '/dlishared//fabric/1.2.3', '--train_dir', '/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2', '--model_path', '/dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2', '--epochs', '50']
# args:  Namespace(batchsize=64, epochs=50, numWorker=2)
# numWorker args: 2
# batch_size args: 64
# epochs args: 50
# /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip/pyspark/context.py:248: RuntimeWarning: Failed to add file [.//fabric.zip] speficied in 'spark.submit.pyFiles' to Python path:
#   /dlishared//fabric/1.2.3/libs/fabric.zip
#   /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-413be2a3-cc9e-4e98-a0a6-cdfe74d7274d/userFiles-195eea3d-5f38-4b18-86ec-e4f2767c1b44
#   /dlishared//fabric/1.2.3/libs/fabric.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4/fabric.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/pyspark.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/python/lib/py4j-0.10.7-src.zip
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/spark-core_2.11-2.3.3.jar
#   /dlishared/tools/dli_utils
#   /dlishared/fabric/1.2.3/libs/fabric.zip
#   /dlishared/fabric/1.2.3/tools
#   /dliresult/egoadmin/batchworkdir/Admin-2781904014777372-695105367/_submitted_code/pytorch_edt_cssc2
#   /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221160523-0083-913ec8b0-3b74-4779-8b20-bd6f9ee021f4
#   /opt/anaconda3/envs/dlipy3/lib/python36.zip
#   /opt/anaconda3/envs/dlipy3/lib/python3.6
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/lib-dynload
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages
#   /opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tflms-2.0.1-py3.6.egg
#   RuntimeWarning)
# start message server 10.3.64.217:45076
# 2020-02-21 16:05:31,102 - root - INFO - client connect to server url: 10.3.64.217:45076
# --------START TRAINING--------
# kelvin: value:  0.0012409474002197385
# kelvin: value:  0.0010481706995051354
# kelvin: value:  -0.1008810346829705
# kelvin: value:  -0.3770527472862831
# kelvin: value:  -0.6583570940741177
# kelvin: value:  -0.7434571372138129
# kelvin: value:  -1.0060746083494092
# kelvin: value:  -2.1337466606727014
# kelvin: value:  -2.4975893086400527
# kelvin: value:  -2.611852052476671
# kelvin: value:  -2.9905721007800494
# kelvin: value:  -5.027149493877705
# kelvin: value:  -5.311924375336746
# kelvin: value:  -5.385928683810764
# kelvin: value:  -5.8484901053006535
# kelvin: value:  -8.816899813138521
# kelvin: value:  -8.845914380303745
# kelvin: value:  -8.866732279459635
# kelvin: value:  -9.400594117211513
# kelvin: value:  -13.155530489408052
# kelvin: value:  -12.928957708950701
# kelvin: value:  -12.86902601453993
# kelvin: value:  -13.409838817158683
# kelvin: value:  -18.45875666691707
# kelvin: value:  -17.76532298120959
# kelvin: value:  -17.560906982421876
# kelvin: value:  -18.078567755026896
# kelvin: value:  -23.84007145808293
# kelvin: value:  -22.707014412715516
# kelvin: value:  -22.449167887369793
# kelvin: value:  -22.983678598872952
# kelvin: value:  -29.56323476938101
# kelvin: value:  -28.09069508519666
# kelvin: value:  -27.596567789713543
# kelvin: value:  -28.060563884797645
# kelvin: value:  -36.25848388671875
# kelvin: value:  -33.963884024784484
# kelvin: value:  -33.29865180121528
# kelvin: value:  -33.682945376536885
# kelvin: value:  -42.71287184495192
# kelvin: value:  -39.83376969962284
# kelvin: value:  -38.95979410807292
# kelvin: value:  -39.34338879194416
# kelvin: value:  -49.45741154597356
# kelvin: value:  -46.035962334994615
# kelvin: value:  -44.94634331597222
# kelvin: value:  -45.13218413806352
# kelvin: value:  -56.17782827524039
# kelvin: value:  -51.96633595433728
# kelvin: value:  -50.84908311631944
# kelvin: value:  -50.9713164782915
# kelvin: value:  -63.75987361027644
# kelvin: value:  -58.391612085802805
# kelvin: value:  -57.205448404947916
# kelvin: value:  -57.273262399141906
# kelvin: value:  -69.92993633563702
# kelvin: value:  -64.79479559536638
# kelvin: value:  -62.9331787109375
# kelvin: value:  -63.11338831166752
# kelvin: value:  -77.77984149639423
# kelvin: value:  -71.54942163927802
# kelvin: value:  -69.4435791015625
# kelvin: value:  -69.42465259989754
# kelvin: value:  -84.39797738882211
# kelvin: value:  -77.44354037580818
# kelvin: value:  -75.5069091796875
# kelvin: value:  -75.45248463114754
# kelvin: value:  -93.4698955829327
# kelvin: value:  -84.9858819369612
# kelvin: value:  -82.71674262152777
# kelvin: value:  -82.1581250800461
# kelvin: value:  -99.67454176682692
# kelvin: value:  -91.20806253367456
# kelvin: value:  -88.95940755208333
# kelvin: value:  -88.4652880058914
# kelvin: value:  -106.74545522836539
# kelvin: value:  -97.56781637257544
# kelvin: value:  -94.92779676649306
# kelvin: value:  -94.38238425332992
# kelvin: value:  -115.33082932692308
# kelvin: value:  -104.41295123922414
# kelvin: value:  -101.29522569444444
# kelvin: value:  -100.88048315829919
# kelvin: value:  -123.17782827524039
# kelvin: value:  -112.31441945043103
# kelvin: value:  -108.58606770833333
# kelvin: value:  -107.94391569544058
# kelvin: value:  -129.77532489483173
# kelvin: value:  -117.86270036368535
# kelvin: value:  -114.77511121961805
# kelvin: value:  -113.95709128457992
# kelvin: value:  -137.69512469951923
# kelvin: value:  -124.77580734779094
# kelvin: value:  -120.6473876953125
# kelvin: value:  -120.03728547643442
# kelvin: value:  -146.30665001502405
# kelvin: value:  -131.3558139143319
# kelvin: value:  -127.84304741753472
# kelvin: value:  -126.77148637615267
# kelvin: value:  -151.85111177884616
# kelvin: value:  -138.58981849407328
# kelvin: value:  -134.71369086371527
# kelvin: value:  -133.45169817815062
# kelvin: value:  -159.26218825120193
# kelvin: value:  -144.8684923895474
# kelvin: value:  -140.4716091579861
# kelvin: value:  -139.3368980532787
# kelvin: value:  -167.9073204627404
# kelvin: value:  -152.48056135506465
# kelvin: value:  -148.15377604166667
# kelvin: value:  -146.49127497438525
# kelvin: value:  -174.39524489182693
# kelvin: value:  -158.32847858297413
# kelvin: value:  -153.78664822048611
# kelvin: value:  -152.47832351434425
# kelvin: value:  -182.38899113581732
# kelvin: value:  -165.57766197467672
# kelvin: value:  -160.78983832465278
# kelvin: value:  -159.38165183145492
# kelvin: value:  -189.57003079927884
# kelvin: value:  -172.30413186961206
# kelvin: value:  -167.187060546875
# kelvin: value:  -165.68885678150616
# kelvin: value:  -198.28057391826923
# kelvin: value:  -179.11183324353448
# kelvin: value:  -173.69236653645834
# kelvin: value:  -172.15336834016392
# kelvin: value:  -205.10428560697116
# kelvin: value:  -184.79206795528017
# kelvin: value:  -180.15295681423612
# kelvin: value:  -178.22261222464138
# kelvin: value:  -213.81043419471155
# kelvin: value:  -193.28042497306035
# kelvin: value:  -187.75762803819444
# kelvin: value:  -185.33681000256146
# kelvin: value:  -220.35103665865384
# kelvin: value:  -199.12893992456895
# kelvin: value:  -193.11776258680555
# kelvin: value:  -191.1731237192623
# kelvin: value:  -228.95556640625
# kelvin: value:  -207.2352084455819
# kelvin: value:  -199.81727973090278
# kelvin: value:  -197.56050284964138
# kelvin: value:  -238.42311448317307
# kelvin: value:  -213.7166537580819
# kelvin: value:  -208.0205295138889
# kelvin: value:  -205.31430103739754
# kelvin: value:  -242.11016376201923
# kelvin: value:  -219.12106849407328
# kelvin: value:  -213.24228515625
# kelvin: value:  -210.71544409579917
# kelvin: value:  -250.46991436298077
# kelvin: value:  -227.41429822198276
# kelvin: value:  -219.68938802083332
# kelvin: value:  -217.1325283363217
# kelvin: value:  -259.19153771033655
# kelvin: value:  -234.58142510775863
# kelvin: value:  -225.92120225694444
# kelvin: value:  -223.455798539959
# kelvin: value:  -268.65371469350964
# kelvin: value:  -241.66570413523706
# kelvin: value:  -233.39644097222222
# kelvin: value:  -230.60738585425204
# kelvin: value:  -275.0888108473558
# kelvin: value:  -247.79309502963363
# kelvin: value:  -240.01826171875
# kelvin: value:  -237.10738985655738
# kelvin: value:  -282.3585674579327
# kelvin: value:  -255.17406384698276
# kelvin: value:  -246.2958984375
# kelvin: value:  -243.48381867955942
# kelvin: value:  -288.064208984375
# kelvin: value:  -260.0022141029095
# kelvin: value:  -252.58944769965277
# kelvin: value:  -249.09824859118854
# kelvin: value:  -298.91939603365387
# kelvin: value:  -268.0583917025862
# kelvin: value:  -260.02302517361113
# kelvin: value:  -256.65418881275616
# kelvin: value:  -305.2355769230769
# kelvin: value:  -273.5623737203664
# kelvin: value:  -265.27725694444445
# kelvin: value:  -262.62315893954917
# kelvin: value:  -309.5857121394231
# kelvin: value:  -279.17482994342674
# kelvin: value:  -271.34613172743053
# kelvin: value:  -269.01768618724384
# kelvin: value:  -316.8614032451923
# kelvin: value:  -286.1623956088362
# kelvin: value:  -278.2021050347222
# kelvin: value:  -275.5730340676229
# kelvin: value:  -325.8374774639423
# kelvin: value:  -294.9401434536638
# kelvin: value:  -285.9080295138889
# kelvin: value:  -282.498767289959
# kelvin: value:  -331.21007361778845
# kelvin: value:  -300.0869308997845
# kelvin: value:  -291.68219401041665
# kelvin: value:  -288.1533203125
# kelvin: value:  -338.97513521634613
# --------END TRAINING: completed epoch 50 in time 197.46612977981567 --------

# %% [markdown]
# ## Retrieve Training Driver Stderr Log

# %%
# shows various information including environment variables

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# +++ export SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ '[' -z '' ']'
# +++ export GLOG_logtostderr=true
# +++ GLOG_logtostderr=true
# +++ '[' -z '' -a -n '' -a -f '' ']'
# +++ '[' -n '' -a -f '' ']'
# +++ '[' true = true ']'
# +++ checkGPUMemory
# +++ echo 'Check GPU memory utilization'
# +++ echo 'CUDA_VISIBLE_DEVICES is set to '
# +++ utilization_high=1
# +++ timeout_secs=30
# +++ time_sleep=0
# +++ '[' 0 -lt 30 -a 1 -eq 1 ']'
# +++ utilization_high=0
# ++++ echo
# ++++ tr , ' '
# +++ '[' 0 -eq 1 ']'
# +++ '[' 0 -lt 30 -a 0 -eq 1 ']'
# +++ '[' 0 -eq 1 ']'
# +++ export NCCL_P2P_DISABLE=1
# +++ NCCL_P2P_DISABLE=1
# +++ handle_BYOF_EDT_Job
# +++ '[' true = true -a Admin-2809611603258194-1703562770x '!=' x ']'
# +++ '[' /dlidata/ '!=' '' ']'
# +++ export DATA_DIR=/dlidata//hymenoptera_data
# +++ DATA_DIR=/dlidata//hymenoptera_data
# +++ local batch_path=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ export RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ '[' -n /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform/ ']'
# ++++ basename /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform/
# +++ local log_subdir=driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform
# +++ export LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform
# +++ LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform
# +++ mkdir -p /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform
# +++ export SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# +++ SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# +++ echo 'Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data'
# +++ echo 'Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770'
# +++ echo 'Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform'
# +++ echo 'Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model'
# +++ echo /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform/
# +++ grep logs/driver-
# +++ '[' '!' -L /var/tmp/elk_logs/Admin-2809611603258194-1703562770 ']'
# +++ ln -s /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770 /var/tmp/elk_logs/Admin-2809611603258194-1703562770
# +++ trace_env
# +++ log_info 'Trace envrionment'
# ++++ date '+%y/%m/%d %H:%M:%S'
# +++ echo '20/02/21 23:47:12 INFO Trace envrionment'
# +++ echo CUDA_VISIBLE_DEVICES=
# +++ echo DLI_CONDA_HOME=/opt/anaconda3
# +++ echo DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# +++ echo DL_NFS_PATH=/dlishared/
# +++ echo DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# +++ echo DLI_LOGGER_LEVEL=debug
# +++ echo PYTHON_VERSION=
# +++ echo SPARK_EGO_USER_FIRST_JARS=
# +++ echo 'LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib'
# +++ echo PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2:
# +++ echo PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# +++ echo RDMA_ENABLED=false
# +++ echo RDMA_BUFFER_SIZE=1073741824
# +++ echo RDMA_DEVICE_NAME=
# +++ echo RDMA_DEVICE_PORT=
# +++ echo DLI_IS_ELASTIC=true
# +++ echo USER=egoadmin
# +++ echo USER_UID=1001
# +++ echo DLI_EXECID=Admin-2809611603258194-1703562770
# +++ echo SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055.colonia05.platform/
# +++ false
# +++ set +x
# Spark Command: /opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le/bin/java -cp /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/*:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/conf/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/* -Dspark.submit.deployMode=cluster -Dspark.ego.vemkd.principal=None -Dspark.master=spark://colonia05.platform:7083 -Dspark.akka.frameSize=2047 -Dspark.ssl.ego.workload.enabled=false -Dspark.shuffle.reduceLocality.enabled=false -Dspark.ego.dl.app=true -Dspark.ssl.ego.gui.enabled=false -Dspark.local.dir=/tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin -Dspark.ego.driverEnv.DLI_SPARK_APP_NAME=ElasticTrain-PyTorch -Dspark.kryoserializer.buffer.max=500m -Dspark.app.name=ElasticTrain-PyTorch-DLIBatch-Admin-dli-edt-pytorch_mnist_EDT.py -Dspark.ssl.enabled=false -Dspark.ego.executor.container.type=normal -Dspark.rpc.framesize=2047 -Dspark.executorEnv.DLI_SPARK_APP_NAME=ElasticTrain-PyTorch -Dspark.shuffle.service.port=7341 -Dspark.driver.memory=4G -Dspark.executor.memory=4G -Dspark.executorEnv.LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH -Dspark.ego.driver.container.type=normal -Dspark.ego.gpu.executor.slots.max=1 -Dspark.files=file:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py -Dspark.executorEnv.DLI_EXTRA_CONF=... -Dspark.shuffle.service.enabled=true -Dspark.ego.driverEnv.DLI_IS_DRIVER=true -Dspark.executor.extraJavaOptions=-Djava.security.egd=file:/dev/./urandom -Dspark.ego.driverEnv.DLI_EXTRA_CONF=... -Dspark.ego.gpu.app=true -Dspark.ego.presend.tasks=0 -Dspark.driver.extraLibraryPath=/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH -Dspark.driver.supervise=false -Dspark.FABRIC_HOME=/dlishared//fabric/1.2.3 -Dspark.driver.maxResultSize=2g -Dspark.ego.uname=Admin -Dspark.ego.gpu.slots.max=2 -Dspark.ego.driverEnv.PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2 -Dspark.master.rest.port=6070 -Dspark.ego.priority=5000 -Xmx4G org.apache.spark.deploy.ego.EGOClusterDriverWrapper {{WORKER_URL}} file:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py org.apache.spark.deploy.PythonRunner --primary-py-file pytorch_mnist_EDT.py --py-files fabric.zip --dataControlSchema 0 --weightSyncInterval 5 --numWorker 2 --usegpuNumPerWorker 1 --commIPNetwork 10.3.64.217/24 --isTest true --globalStep null --testIter 10 --testInterval None --isESE true --mode 1 --execPathParam /dlishared//fabric/1.2.3 --train_dir /dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2 --model_path /dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2 --epochs 50
# ========================================
# 20/02/21 23:47:13 INFO EGOClusterDriverWrapper: Started daemon with process name: 8300@colonia05.platform
# 20/02/21 23:47:13 INFO SignalUtils: Registered signal handler for TERM
# 20/02/21 23:47:13 INFO SignalUtils: Registered signal handler for HUP
# 20/02/21 23:47:13 INFO SignalUtils: Registered signal handler for INT
# 20/02/21 23:47:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 20/02/21 23:47:14 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:14 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:14 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:14 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:14 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:14 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:14 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:14 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:14 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:14 INFO Utils: Successfully started service 'EGOClusterDriverWrapper-driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055' on port 34155.
# 20/02/21 23:47:14 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7083 after 34 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:15 INFO EGOClusterDriverWrapper: Receive ext  by Master.
# 20/02/21 23:47:15 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:15 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:15 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:15 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:15 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:15 INFO EGOClusterDriverWrapper: Fetching file from file:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py to .//pytorch_mnist_EDT.py
# 20/02/21 23:47:15 INFO Utils: Copying /dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py to /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055/./pytorch_mnist_EDT.py
# 20/02/21 23:47:15 INFO EGOClusterDriverWrapper: Starting the user JAR in a separate Thread
# 20/02/21 23:47:15 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:15 INFO EGOClusterDriverWrapper: Waiting for spark context initialization ... 0
# 20/02/21 23:47:17 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:17 INFO SparkContext: Running Spark version 2.3.3
# 20/02/21 23:47:17 WARN SparkConf: In Spark 1.0 and later spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone and LOCAL_DIRS in YARN).
# 20/02/21 23:47:17 INFO SparkContext: Submitted application: ElasticTrain-PyTorch-DLIBatch-Admin-dli-edt-pytorch_mnist_EDT.py
# 20/02/21 23:47:17 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:17 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:17 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:17 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:17 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:17 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:17 INFO Utils: Successfully started service 'sparkDriver' on port 35089.
# 20/02/21 23:47:17 INFO SparkEnv: Registering MapOutputTracker
# 20/02/21 23:47:17 INFO SparkEnv: Registering BlockManagerMaster
# 20/02/21 23:47:17 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/02/21 23:47:17 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/02/21 23:47:17 INFO MemoryStore: MemoryStore started with capacity 2.2 GB
# 20/02/21 23:47:17 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/02/21 23:47:17 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:17 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:17 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:17 INFO Utils: Successfully started service 'SparkUI' on port 40372.
# 20/02/21 23:47:17 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://colonia05.platform:40372
# 20/02/21 23:47:17 INFO SparkContext: Added file file:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py at spark://colonia05.platform:35089/files/pytorch_mnist_EDT.py with timestamp 1582325237946
# 20/02/21 23:47:17 INFO Utils: Copying /dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2/pytorch_mnist_EDT.py to /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-e28fe4b1-65d8-4a7f-9540-c37e23a2354f/userFiles-4ee19935-fae7-43e4-a67c-21ae3b58f64b/pytorch_mnist_EDT.py
# 20/02/21 23:47:18 INFO EGOSparkDockerConfig: Executor Container Type is 'normal' from local configuration file.
# 20/02/21 23:47:18 INFO EGOSparkDockerConfig: Driver Container Type is 'normal' from local configuration file.
# 20/02/21 23:47:18 INFO EGOSparkDockerConfig: spark-ego-docker.conf will not be parsed as docker is not defined as any container type.
# 20/02/21 23:47:18 INFO EGOFineGrainedSchedulerBackend: setting reserve=0, priority=5000, limit=2147483647, gpuLimit=2, master=[Ljava.lang.String;@13654989
# 20/02/21 23:47:18 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:18 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:18 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:18 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:18 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:18 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:18 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:18 INFO Utils: Successfully started service 'driverWrapper' on port 42414.
# 20/02/21 23:47:18 INFO EGOAppClient$ClientEndpoint: Sending the first request to master spark://colonia05.platform:7083...
# 20/02/21 23:47:18 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7083 after 1 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:18 INFO EGOAppClient$ClientEndpoint: Successfully obtained the first response from master colonia05.platform:7083
# 20/02/21 23:47:18 INFO EGOAppClient$ClientEndpoint: Connecting to master spark://colonia05.platform:7083...
# 20/02/21 23:47:18 INFO EGOAppClient$ClientEndpoint: Received driver endpoint NettyRpcEndpointRef(spark://DriverWrapper@10.3.64.217:34155), colonia05.platform
# 20/02/21 23:47:18 INFO TransportClientFactory: Successfully created connection to /10.3.64.217:34155 after 1 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:18 INFO EGOFineGrainedSchedulerBackend: Connected to Spark cluster with app ID app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322
# 20/02/21 23:47:18 INFO EGOFineGrainedSchedulerBackend: Application registered successfully as app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322, executor Container type is normal
# 20/02/21 23:47:18 INFO DiskBlockManager: Init the driver local dir
# 20/02/21 23:47:18 INFO DiskBlockManager: Created local directory at /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/blockmgr-66b5aed6-2140-464d-8835-cd1924cc101e
# 20/02/21 23:47:18 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:18 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 33350.
# 20/02/21 23:47:18 INFO NettyBlockTransferService: Server created on colonia05.platform:33350
# 20/02/21 23:47:18 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/21 23:47:18 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, colonia05.platform, 33350, None)
# 20/02/21 23:47:18 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:33350 with 2.2 GB RAM, BlockManagerId(driver, colonia05.platform, 33350, None)
# 20/02/21 23:47:18 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, colonia05.platform, 33350, None)
# 20/02/21 23:47:18 INFO BlockManager: external shuffle service port = 7341
# 20/02/21 23:47:18 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, colonia05.platform, 33350, None)
# 20/02/21 23:47:18 INFO EGODeployScheduler: Spark context initialized.
# 20/02/21 23:47:18 INFO server: pyspark script logger initialized
# 20/02/21 23:47:18 INFO server: start logging thread for mao
# 20/02/21 23:47:19 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 672.0 B, free 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece1 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece2 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece3 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece4 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece5 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece6 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece7 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece8 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece9 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece10 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece11 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece12 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece13 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece14 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece15 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece16 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece17 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece18 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece19 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:33350 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_0_piece20 stored as bytes in memory (estimated size 3.0 MB, free 2.1 GB)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:33350 (size: 3.0 MB, free: 2.1 GB)
# 20/02/21 23:47:20 INFO SparkContext: Created broadcast 0 from collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64
# 20/02/21 23:47:20 INFO SparkContext: Starting job: collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64
# 20/02/21 23:47:20 INFO DAGScheduler: Got job 0 (collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64) with 2 output partitions
# 20/02/21 23:47:20 INFO DAGScheduler: Final stage: ResultStage 0 (collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64)
# 20/02/21 23:47:20 INFO DAGScheduler: Parents of final stage: List()
# 20/02/21 23:47:20 INFO DAGScheduler: Missing parents: List()
# 20/02/21 23:47:20 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[1] at collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64), which has no missing parents
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 6.1 KB, free 2.1 GB)
# 20/02/21 23:47:20 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 3.8 KB, free 2.1 GB)
# 20/02/21 23:47:20 INFO EGOFineGrainedSchedulerBackend: onStageSubmitted: stageId(0)
# 20/02/21 23:47:20 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:33350 (size: 3.8 KB, free: 2.1 GB)
# 20/02/21 23:47:20 INFO EGOFineGrainedSchedulerBackend: RDD 1: GPU
# 20/02/21 23:47:20 INFO EGOFineGrainedSchedulerBackend: RDD 0: GPU
# 20/02/21 23:47:20 INFO EGOFineGrainedSchedulerBackend: onStageSubmitted: stageId is 0, rg is GPU
# 20/02/21 23:47:20 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1042
# 20/02/21 23:47:20 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 0 (PythonRDD[1] at collect at /dlishared//fabric/1.2.3/libs/fabric.zip/scheduler/spark/sc.py:64) (first 15 tasks are for partitions Vector(0, 1))
# 20/02/21 23:47:20 INFO EGODeployScheduler: Adding task set 0.0 with 2 tasks
# 20/02/21 23:47:21 INFO EGOFineGrainedSchedulerBackend: <EVENT> Spark driver 63027c69-543b-451c-9a03-9c850784725f-dli-edt-sparkms-batch-1 workload coming in
# 20/02/21 23:47:26 INFO EGOFineGrainedSchedulerBackend: Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.3.64.217:35336) with ID 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542
# 20/02/21 23:47:26 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, colonia05.platform, executor 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542, partition 0, PROCESS_LOCAL, 7899 bytes)
# 20/02/21 23:47:26 INFO EGOFineGrainedSchedulerBackend: Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.3.64.217:35334) with ID 1-6ce73046-91f8-4df0-ad30-339969f0e1c9
# 20/02/21 23:47:26 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, colonia05.platform, executor 1-6ce73046-91f8-4df0-ad30-339969f0e1c9, partition 1, PROCESS_LOCAL, 7899 bytes)
# 20/02/21 23:47:26 INFO EGOFineGrainedSchedulerBackend: onTaskStart: TID 0 ( Index 0 ) on 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542
# 20/02/21 23:47:26 INFO EGOFineGrainedSchedulerBackend: onTaskStart: TID 1 ( Index 1 ) on 1-6ce73046-91f8-4df0-ad30-339969f0e1c9
# 20/02/21 23:47:26 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:45870 with 2.2 GB RAM, BlockManagerId(0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542, colonia05.platform, 45870, None)
# 20/02/21 23:47:26 INFO BlockManagerMasterEndpoint: Registering block manager colonia05.platform:33916 with 2.2 GB RAM, BlockManagerId(1-6ce73046-91f8-4df0-ad30-339969f0e1c9, colonia05.platform, 33916, None)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:33916 (size: 3.8 KB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on colonia05.platform:45870 (size: 3.8 KB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:27 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece8 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece1 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:33916 (size: 3.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece11 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece9 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece3 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece4 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece5 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece7 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece17 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece13 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece12 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece14 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece19 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece20 in memory on colonia05.platform:45870 (size: 3.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece10 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece2 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece6 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.2 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece16 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece15 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.disk.diskSpaceUsed_MB, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxMem_MB, value=6832
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece18 in memory on colonia05.platform:33916 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxOffHeapMem_MB, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxOnHeapMem_MB, value=6832
# 20/02/21 23:47:28 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on colonia05.platform:45870 (size: 4.0 MB, free: 2.1 GB)
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.memUsed_MB, value=245
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.offHeapMemUsed_MB, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.onHeapMemUsed_MB, value=249
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingMem_MB, value=6583
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingOffHeapMem_MB, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingOnHeapMem_MB, value=6583
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.job.activeJobs, value=1
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.job.allJobs, value=1
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.failedStages, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.runningStages, value=1
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.waitingStages, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.size, value=0
# 20/02/21 23:47:28 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.numEventsPosted, count=77
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/21 23:47:28 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/21 23:47:28 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:28 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:28 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:28 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.messageProcessingTime, count=5, min=0.007756, max=105.666401, mean=20.51702930058637, stddev=40.7122556284068, median=1.8103159999999998, p75=2.369656, p95=105.666401, p98=105.666401, p99=105.666401, p999=105.666401, mean_rate=0.47211149942564157, m1=0.24797335122240602, m5=0.20991712770702953, m15=0.20332409119706196, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=77, min=0.002121, max=8.372074999999999, mean=0.16486723765615116, stddev=0.9581193796242782, median=0.006182, p75=0.010084, p95=0.30199, p98=3.0133829999999997, p99=8.372074999999999, p999=8.372074999999999, mean_rate=7.217717624811665, m1=5.128151009739699, m5=5.3438029429934994, m15=5.38116348321665, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=77, min=0.001691, max=2.245765, mean=0.04832290637137828, stddev=0.264963555940951, median=0.004731, p75=0.011183, p95=0.017606, p98=0.923609, p99=2.245765, p999=2.245765, mean_rate=7.272176619735872, m1=5.224097712184512, m5=5.363637198407559, m15=5.387811665610773, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=77, min=0.018749, max=36.967262999999996, mean=1.2086323271385737, stddev=4.943858003853046, median=0.048524, p75=0.11007199999999999, p95=5.512544999999999, p98=18.233735, p99=36.967262999999996, p999=36.967262999999996, mean_rate=6.743291412105183, m1=5.064186541443158, m5=5.330580106050794, m15=5.376731361620567, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=77, min=0.096061, max=37.075418, mean=1.3861380416430331, stddev=5.029344231555899, median=0.201517, p75=0.279866, p95=5.555555, p98=18.296929, p99=37.075418, p999=37.075418, mean_rate=6.741591961516751, m1=5.064186541443158, m5=5.330580106050794, m15=5.376731361620567, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:28 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=77, min=0.032018, max=9.603610999999999, mean=0.24730853241834985, stddev=1.0750339467398002, median=0.07789299999999999, p75=0.094607, p95=0.45903299999999997, p98=3.0604299999999998, p99=9.603610999999999, p999=9.603610999999999, mean_rate=7.2123227444463, m1=5.128151009739699, m5=5.3438029429934994, m15=5.38116348321665, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:47:30 INFO server: init data batch index with size of 244 in epoch 50 iter 4
# 20/02/21 23:47:30 INFO server: Total iterations: 200
# 20/02/21 23:47:30 INFO server: ignore duplicate setting
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8: action: ADD_NODE, server gs 0, server epoch 0, client tid 0, client epoch 0
# 20/02/21 23:47:32 INFO server: - insert node: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 in pool {'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: ACQUIRE_TASK, server gs 0, server epoch 0, client tid 0, client epoch 0
# 20/02/21 23:47:32 INFO server: handleAcquireTask: curr_total_itr=0 acc_count=0 total_itrs=4 gs=0
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: next_sync_step:2 current:0, old topo 0, new topo 0
# 20/02/21 23:47:32 INFO server: - sync boundary 0 begin-
# 20/02/21 23:47:32 INFO server: Push weight worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 -> worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0, already inited list set()
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: send message exit CtrlMsg.PUSH_WEIGHT tid 0
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: send message exit CtrlMsg.PULL_WEIGHT tid 0
# 20/02/21 23:47:32 INFO server: ! insert batch_idx 0 into cache
# 20/02/21 23:47:32 INFO server: ! insert batch_idx 1 into cache
# 20/02/21 23:47:32 INFO server: ! insert batch_idx 2 into cache
# 20/02/21 23:47:32 INFO server: ! insert batch_idx 3 into cache
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: newTask: tid 1 pend list {1}, presend {0, 1, 2, 3}
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: send message exit CtrlMsg.NEW_TASK tid 1
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305: action: ADD_NODE, server gs 1, server epoch 0, client tid 0, client epoch 0
# 20/02/21 23:47:32 INFO server: - insert node: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1 in pool {'worker-ed84af7c-e2b7-447a-881e-387aa65da305:1', 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: read message exit CtrlMsg.PUSH_WEIGHT tid 0
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: action: ACQUIRE_TASK, server gs 1, server epoch 0, client tid 0, client epoch 0
# 20/02/21 23:47:32 INFO server: handleAcquireTask: curr_total_itr=1 acc_count=0 total_itrs=4 gs=0
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: action: next_sync_step:2 current:1, old topo 0, new topo 1
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: status: cache empty, tid 1 pend list {1}, presend set(), unhandled batches 0
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1 action: cache emtpy wait, util next sync
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: read message exit CtrlMsg.PULL_WEIGHT tid 0
# 20/02/21 23:47:32 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:32 INFO server: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: read message exit CtrlMsg.NEW_TASK tid 1
# 20/02/21 23:47:32 INFO server: get_next_batch_idx 0
# 20/02/21 23:47:32 INFO server: Pull Index 0, starter 7, size 64, server ep 0, gs 1
# 20/02/21 23:47:32 INFO server: get_next_batch_idx 1
# 20/02/21 23:47:32 INFO server: Pull Index 1, starter 194, size 64, server ep 0, gs 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.EMPTY tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: send message exit CtrlMsg.SYNC_WAIT tid 1
# 20/02/21 23:47:33 INFO server: worker-ed84af7c-e2b7-447a-881e-387aa65da305:1: read message exit CtrlMsg.SYNC_WAIT tid 1
# ...
# 20/02/21 23:50:34 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.numEventsPosted, count=118
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/21 23:50:34 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/21 23:50:34 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:34 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:34 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:34 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.messageProcessingTime, count=7, min=0.007756, max=105.666401, mean=8.51593749385181, stddev=15.310381745605321, median=6.522784, p75=6.964302999999999, p95=6.964302999999999, p98=105.666401, p99=105.666401, p999=105.666401, mean_rate=0.03559064067517675, m1=0.011358745232531359, m5=0.11330079176168176, m15=0.1655454300202656, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=118, min=0.001606, max=8.372074999999999, mean=0.03665571262058155, stddev=0.43504382144905357, median=0.004469, p75=0.005375, p95=0.010084, p98=0.024432, p99=0.30199, p999=8.372074999999999, mean_rate=0.5997239689256822, m1=0.45592497659415865, m5=3.0452287257673745, m15=4.452944409704986, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=117, min=0.001691, max=2.245765, mean=0.06346712688353758, stddev=0.19307072702343278, median=0.003084, p75=0.005176, p95=0.6054919999999999, p98=0.6054919999999999, p99=0.6054919999999999, p999=2.245765, mean_rate=0.5948866887736681, m1=0.4555430363558817, m5=3.0450488080767966, m15=4.452914254262233, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=118, min=0.013463, max=36.967262999999996, mean=1.4442277747967036, stddev=2.605817466283508, median=1.128646, p75=1.527969, p95=6.8844579999999995, p98=6.8844579999999995, p99=9.498766999999999, p999=36.967262999999996, mean_rate=0.5974520764144597, m1=0.4561796034196765, m5=3.045348670894425, m15=4.452964513333491, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=117, min=0.096061, max=37.075418, mean=1.663563521614631, stddev=2.744707932913837, median=1.211603, p75=1.6181679999999998, p95=7.570264, p98=7.570264, p99=12.563326, p999=37.075418, mean_rate=0.592383822788787, m1=0.4561796034196765, m5=3.045348670894425, m15=4.452964513333491, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=118, min=0.032018, max=9.603610999999999, mean=0.10080924254425853, stddev=0.48863580359321424, median=0.06409, p75=0.078152, p95=0.10520099999999999, p98=0.120059, p99=0.45903299999999997, p999=9.603610999999999, mean_rate=0.5997137450773615, m1=0.45592497659415865, m5=3.0452287257673745, m15=4.452944409704986, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:34 INFO EGOFineGrainedSchedulerBackend: Spark driver enters idle mode
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.disk.diskSpaceUsed_MB, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxMem_MB, value=6832
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxOffHeapMem_MB, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.maxOnHeapMem_MB, value=6832
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.memUsed_MB, value=249
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.offHeapMemUsed_MB, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.onHeapMemUsed_MB, value=249
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingMem_MB, value=6583
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingOffHeapMem_MB, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.BlockManager.memory.remainingOnHeapMem_MB, value=6583
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.job.activeJobs, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.job.allJobs, value=1
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.failedStages, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.runningStages, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.stage.waitingStages, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.size, value=0
# 20/02/21 23:50:38 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.size, value=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.numEventsPosted, count=118
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.numDroppedEvents, count=0
# 20/02/21 23:50:38 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.numDroppedEvents, count=0
# 20/02/21 23:50:38 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:38 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:38 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:38 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.DAGScheduler.messageProcessingTime, count=7, min=0.007756, max=105.666401, mean=8.51593749385181, stddev=15.310381745605321, median=6.522784, p75=6.964302999999999, p95=6.964302999999999, p98=105.666401, p99=105.666401, p999=105.666401, mean_rate=0.03490690190611425, m1=0.04243278425665861, m5=0.11803951286435452, m15=0.16684434397389988, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.HeartbeatReceiver, count=118, min=0.001606, max=8.372074999999999, mean=0.03665571262058155, stddev=0.43504382144905357, median=0.004469, p75=0.005375, p95=0.010084, p98=0.024432, p99=0.30199, p999=8.372074999999999, mean_rate=0.5882068953362638, m1=0.5154179306502726, m5=3.01472977756385, m15=4.434922603243598, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.scheduler.cluster.ego.EGOFineGrainedSchedulerBackend$ExecutorAllocationListener, count=118, min=0.001691, max=522.148018, mean=23.69194686083508, stddev=108.52554890178209, median=0.0032069999999999998, p75=0.009467, p95=0.923609, p98=522.148018, p99=522.148018, p999=522.148018, mean_rate=0.5884447067309837, m1=0.5150665286673237, m5=3.01455283365113, m15=4.434892614866583, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.listenerProcessingTime.org.apache.spark.status.AppStatusListener, count=118, min=0.013463, max=36.967262999999996, mean=1.4442277747967036, stddev=2.605817466283508, median=1.128646, p75=1.527969, p95=6.8844579999999995, p98=6.8844579999999995, p99=9.498766999999999, p999=36.967262999999996, mean_rate=0.5860212203314626, m1=0.5156521986389052, m5=3.0148477401723297, m15=4.434942595494946, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.appStatus.listenerProcessingTime, count=118, min=0.096061, max=522.300841, mean=25.226542619663974, stddev=108.25776543640622, median=1.228661, p75=1.64903, p95=18.296929, p98=522.300841, p99=522.300841, p999=522.300841, mean_rate=0.5860162946640336, m1=0.5156521986389052, m5=3.0148477401723297, m15=4.434942595494946, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:38 INFO metrics: type=TIMER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.driver.LiveListenerBus.queue.executorManagement.listenerProcessingTime, count=118, min=0.032018, max=9.603610999999999, mean=0.10080924254425853, stddev=0.48863580359321424, median=0.06409, p75=0.078152, p95=0.10520099999999999, p98=0.120059, p99=0.45903299999999997, p999=9.603610999999999, mean_rate=0.5881970427549782, m1=0.5154179306502726, m5=3.01472977756385, m15=4.434922603243598, rate_unit=events/second, duration_unit=milliseconds
# 20/02/21 23:50:45 INFO EGODeployScheduler: Spark context stopped.
# 20/02/21 23:50:45 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/02/21 23:50:45 INFO MemoryStore: MemoryStore cleared
# 20/02/21 23:50:45 INFO BlockManager: BlockManager stopped
# 20/02/21 23:50:45 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/02/21 23:50:45 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/02/21 23:50:45 INFO SparkContext: Successfully stopped SparkContext
# 20/02/21 23:50:45 INFO EGOClusterDriverWrapper: Final app status: 0, exitCode: 0
# 20/02/21 23:50:45 INFO EGOClusterDriverWrapper: Sending driver program state to master
# 20/02/21 23:50:45 INFO ShutdownHookManager: Shutdown hook called
# 20/02/21 23:50:45 INFO ShutdownHookManager: Deleting directory /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-e28fe4b1-65d8-4a7f-9540-c37e23a2354f/pyspark-6acfde83-caf4-488c-b191-84fcb4970795
# 20/02/21 23:50:45 INFO ShutdownHookManager: Deleting directory /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/spark-e28fe4b1-65d8-4a7f-9540-c37e23a2354f
# 20/02/21 23:50:45 INFO EGOClusterDriverWrapper: staging dir is None
# 20/02/21 23:50:45 INFO EGOClusterDriverWrapper: Deleting local temp file .//pytorch_mnist_EDT.py: true
# 20/02/21 23:50:45 INFO EGOClusterDriverWrapper: Deleting local temp file /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/driver-20200221234711-0084-e43f7b87-017a-4024-a890-8a6a8a7ba055/.: false

# %% [markdown]
# ## Retrieve Training Executor Log

# %% [markdown]
# ## Retrieve Executor ID
#
# #### The deep learning training log per GPU is written in executor log
# #### Execute following code to retrieve list of executor ID

# %%
for key in executors:    
    print ('executors: ' + key['id'])
# Out:
# executors: 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542
# executors: 1-6ce73046-91f8-4df0-ad30-339969f0e1c9

# %% [markdown]
# ## Retrieve Executor Stdout log
# #### set the parameter executor_id

# %%
executor_id = '0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stdout/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# load extra config from : /dlishared//conf
# Setting up spark environment on node colonia05.platform
# DLI_EXTRA_CONF=export DLI_LOGGER_LEVEL=debug;export DLI_SHARED_FS=/dlishared/;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2;export LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH;export PYTHONPATH=/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2:$PYTHONPATH;export DLI_IS_ELASTIC=true;export MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2;export FABRIC_HOME=/dlishared//fabric/1.2.3;export RESUME_WEIGHT_PATH=null;export DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2;export DLI_EXECID=Admin-2809611603258194-1703562770;export PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2;export DATA_PATH=hymenoptera_data
# 20/02/21 23:47:22 INFO Conda variables: conda_home=/opt/anaconda3, conda_env=dlipy3, python=/opt/anaconda3/envs/dlipy3/bin/python, DLI_BYOF_FRAMEWORK_PYTHON_VERSION=, PYTHON_VERSION=, DLI_BYOF_CONDA_ENV=
# 20/02/21 23:47:22 INFO BUILD_OS_ID=rhel, BUILD_OS_VERSION_ID=7.6, BUILD_OS_ARCH=ppc64le
# 20/02/21 23:47:22 INFO OS_ID=rhel, OS_ID=rhel, ARCH=ppc64le
# [D]: >> 0-1: --- /tmp/PpcaOaUV/0	2020-02-21 23:47:22.753369535 +0100
# [D]: >> 0-1: +++ /tmp/PpcaOaUV/1	2020-02-21 23:47:22.993370495 +0100
# [D]: >> 0-1: @@ -1,13 +1,211 @@
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@"
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA "$cmd" "$@" && __conda_reactivate
# [D]: >> 0-1: + "$CONDA_EXE" $_CE_M $_CE_CONDA;
# [D]: >> 0-1: + *)
# [D]: >> 0-1: + :;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + ;;
# [D]: >> 0-1: + BUILD_OS_ARCH=$(grep "BUILD_OS_ARCH" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_ID=$(grep "BUILD_OS_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + BUILD_OS_VERSION_ID=$(grep "BUILD_OS_VERSION_ID" $DLI_FABRIC_BUILDFILE | awk -F: '{print $2}' | sed -e 's/ //g');
# [D]: >> 0-1: + DLI_CONDA_HOME=$HPO_PLUGIN_CONDA_HOME;
# [D]: >> 0-1: + DLI_CONDA_HOME=$IG_CONDA_HOME;
# [D]: >> 0-1: + DLI_ELASTIC_PROFILE=$DLI_ELASTIC_CONF_DIR/profile.elastic;
# [D]: >> 0-1: + DLI_FABRIC_BUILDFILE=$DLI_FABRIC_HOME/build.version;
# [D]: >> 0-1: + HOSTNAME_F=`hostname -f`;
# [D]: >> 0-1: + LD_LIBRARY_PATH="";
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/#"$1:"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH/%":$1"/};
# [D]: >> 0-1: + LD_LIBRARY_PATH=${LD_LIBRARY_PATH//":$1:"/":"};
# [D]: >> 0-1: + PATH="";
# [D]: >> 0-1: + PATH=${PATH/#"$1:"/};
# [D]: >> 0-1: + PATH=${PATH/%":$1"/};
# [D]: >> 0-1: + PATH=${PATH//":$1:"/":"};
# [D]: >> 0-1: + PS1="$CONDA_PS1_BACKUP";
# [D]: >> 0-1: + PYTHONPATH="";
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/#"$1:"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH/%":$1"/};
# [D]: >> 0-1: + PYTHONPATH=${PYTHONPATH//":$1:"/":"};
# [D]: >> 0-1: + RDMA_BUFFER_SIZE=`grep RDMA_BUFFER_SIZE $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_NAME=`grep "^RDMA_DEVICE_NAME=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_DEVICE_PORT=`grep "^RDMA_DEVICE_PORT=$HOSTNAME_F:" $DLI_ELASTIC_PROFILE | tr ':' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + RDMA_ENABLED=`grep RDMA_ENABLED $DLI_ELASTIC_PROFILE | tr '=' ' ' |awk '{print $2}'`;
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \eval "$ask_conda";
# [D]: >> 0-1: + \hash -r;
# [D]: >> 0-1: + \local ask_conda;
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \local cmd="$1";
# [D]: >> 0-1: + \rehash;
# [D]: >> 0-1: + \unset CONDA_PS1_BACKUP;
# [D]: >> 0-1: + __conda_activate "$cmd" "$@"
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + __conda_hashr
# [D]: >> 0-1: + activate | deactivate)
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix "$cmd" "$@")" || \return $?;
# [D]: >> 0-1: + ask_conda="$(PS1="$PS1" "$CONDA_EXE" $_CE_M $_CE_CONDA shell.posix reactivate)" || \return $?;
# [D]: >> 0-1: + case "$cmd" in
# [D]: >> 0-1: + dli_conda_env_name=$DLI_BYOF_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=$HPO_PLGIN_CONDA_ENV;
# [D]: >> 0-1: + dli_conda_env_name=dli${dli_conda_env_name_suffix};
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py2";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + echo "CUDA_VISIBLE_DEVICES=${CUDA_VISIBLE_DEVICES}";
# [D]: >> 0-1: + echo "DLI_CONDA_HOME=${DLI_CONDA_HOME}";
# [D]: >> 0-1: + echo "DLI_ELASTIC_CONF_DIR=${DLI_ELASTIC_CONF_DIR}";
# [D]: >> 0-1: + echo "DLI_EXECID=${DLI_EXECID}";
# [D]: >> 0-1: + echo "DLI_FABRIC_HOME=${DLI_FABRIC_HOME}";
# [D]: >> 0-1: + echo "DLI_IS_ELASTIC=${DLI_IS_ELASTIC}";
# [D]: >> 0-1: + echo "DLI_LOGGER_LEVEL=${DLI_LOGGER_LEVEL}";
# [D]: >> 0-1: + echo "DL_NFS_PATH=${DL_NFS_PATH}";
# [D]: >> 0-1: + echo "LD_LIBRARY_PATH=${LD_LIBRARY_PATH}";
# [D]: >> 0-1: + echo "PATH=${PATH}";
# [D]: >> 0-1: + echo "PYTHONPATH=${PYTHONPATH}";
# [D]: >> 0-1: + echo "PYTHON_VERSION=${PYTHON_VERSION}";
# [D]: >> 0-1: + echo "RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME}";
# [D]: >> 0-1: + echo "RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT}";
# [D]: >> 0-1: + echo "RDMA_ENABLED=${RDMA_ENABLED}";
# [D]: >> 0-1: + echo "SPARK_EGO_USER_FIRST_JARS=${SPARK_EGO_USER_FIRST_JARS}";
# [D]: >> 0-1: + echo "SPARK_LOG_STDOUTSTDERR_DIR=${SPARK_LOG_STDOUTSTDERR_DIR}"
# [D]: >> 0-1: + echo "USER=${USER}";
# [D]: >> 0-1: + echo "USER_UID=${USER_UID}";
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + else
# [D]: >> 0-1: + esac;
# [D]: >> 0-1: + eval "export $save_var=$orig_val";
# [D]: >> 0-1: + eval "orig_val=\${${orig_var}-unset}";
# [D]: >> 0-1: + eval "save_val=\${${save_var}-xxx}";
# [D]: >> 0-1: + export DLI_CONDA_ENV_NAME=$dli_conda_env_name;
# [D]: >> 0-1: + export DLI_CONDA_HOME=$DLI_CONDA_HOME;
# [D]: >> 0-1: + export DLI_CONDA_LIBPATH=${DLI_CONDA_HOME}/envs/${dli_conda_env_name}/lib;
# [D]: >> 0-1: + export FABRIC_HOME=$DLI_FABRIC_HOME;
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH
# [D]: >> 0-1: + export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$DLI_CONDA_LIBPATH
# [D]: >> 0-1: + export PATH=$DLI_CONDA_HOME/bin:$PATH;
# [D]: >> 0-1: + export RDMA_BUFFER_SIZE=${RDMA_BUFFER_SIZE};
# [D]: >> 0-1: + export RDMA_DEVICE_NAME=${RDMA_DEVICE_NAME};
# [D]: >> 0-1: + export RDMA_DEVICE_PORT=${RDMA_DEVICE_PORT};
# [D]: >> 0-1: + export RDMA_ENABLED=${RDMA_ENABLED};
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + fi;
# [D]: >> 0-1: + if ! echo $PATH | /bin/grep -q "$DLI_CONDA_HOME/bin"; then
# [D]: >> 0-1: + if [ ! -d ${DLI_CONDA_HOME} ]; then
# [D]: >> 0-1: + if [ "$ARCH" != "$BUILD_OS_ARCH" ]; then
# [D]: >> 0-1: + if [ "$OS_ID" != "$BUILD_OS_ID" ]; then
# [D]: >> 0-1: + if [ "$OS_VER" != "$BUILD_OS_VERSION_ID" ]; then
# [D]: >> 0-1: + if [ "$save_val" = xxx ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x2" ]; then
# [D]: >> 0-1: + if [ "x$DLI_BYOF_FRAMEWORK_PYTHON_VERSION" = "x3" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython2" ]; then
# [D]: >> 0-1: + if [ "x$PYTHON_VERSION" = "xpython3" ]; then
# [D]: >> 0-1: + if [ -f $DLI_ELASTIC_PROFILE ]; then
# [D]: >> 0-1: + if [ -f $DLI_FABRIC_BUILDFILE ]; then
# [D]: >> 0-1: + if [ -n "$DLI_BYOF_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_ENV" ]; then
# [D]: >> 0-1: + if [ -n "$HPO_PLUGIN_CONDA_HOME" ]; then
# [D]: >> 0-1: + if [ -n "${POSH_VERSION:+x}" ]; then
# [D]: >> 0-1: + if [[ $PYTHONPATH == "$1" ]]; then
# [D]: >> 0-1: + install | update | upgrade | remove | uninstall)
# [D]: >> 0-1: + local dli_conda_env_name="";
# [D]: >> 0-1: + local dli_conda_env_name_suffix="py3";
# [D]: >> 0-1: + local orig_val;
# [D]: >> 0-1: + local orig_var="$2";
# [D]: >> 0-1: + local save_val;
# [D]: >> 0-1: + local save_var="POWERAI_${package}_${orig_var}";
# [D]: >> 0-1: + log_error "Conda home path ${DLI_CONDA_HOME} does not exist.";
# [D]: >> 0-1: + log_error "Fabric home path ${DLI_FABRIC_HOME} does not exist.";
# [D]: >> 0-1: + log_info "BUILD_OS_ID=$BUILD_OS_ID, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_info "Conda variables: conda_home=$DLI_CONDA_HOME, conda_env=$dli_conda_env_name, python=$(which python), DLI_BYOF_FRAMEWORK_PYTHON_VERSION=$DLI_BYOF_FRAMEWORK_PYTHON_VERSION, PYTHON_VERSION=$PYTHON_VERSION, DLI_BYOF_CONDA_ENV=$DLI_BYOF_CONDA_ENV";
# [D]: >> 0-1: + log_info "OS_ID=$OS_ID, OS_ID=$OS_ID, ARCH=$ARCH";
# [D]: >> 0-1: + log_warn "Different OS ARCH detected. ARCH=$ARCH, BUILD_OS_ARCH=$BUILD_OS_ARCH";
# [D]: >> 0-1: + log_warn "Different OS ID detected. OS_ID=$OS_ID, BUILD_OS_ID=$BUILD_OS_ID";
# [D]: >> 0-1: + log_warn "Different OS VERSION ID detected. OS_VER=$OS_VER, BUILD_OS_VERSION_ID=$BUILD_OS_VERSION_ID";
# [D]: >> 0-1: + log_warn "Unable to find fabric build file $DLI_FABRIC_BUILDFILE";
# [D]: >> 0-1: + log_warn "Unable to find fabric profile $DLI_ELASTIC_PROFILE";
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + shift;
# [D]: >> 0-1: + source activate $dli_conda_env_name;
# [D]: >> 0-1: +ARCH2=ppc64el
# [D]: >> 0-1: +ARCH=ppc64le
# [D]: >> 0-1: +BASH_FUNC___conda_activate()=() {  if [ -n "${CONDA_PS1_BACKUP:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_hashr()=() {  if [ -n "${ZSH_VERSION:+x}" ]; then
# [D]: >> 0-1: +BASH_FUNC___conda_reactivate()=() {  \local ask_conda;
# [D]: >> 0-1: +BASH_FUNC_activate_conda()=() {  if [ -n "$IG_CONDA_HOME" ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_fabric()=() {  if [ ! -d ${DLI_FABRIC_HOME} ]; then
# [D]: >> 0-1: +BASH_FUNC_activate_framework_in_conda()=() {  export PYTHONPATH=$DL_NFS_PATH/tools/dli_utils/:$PYTHONPATH;
# [D]: >> 0-1: +BASH_FUNC_conda()=() {  if [ "$#" -lt 1 ]; then
# [D]: >> 0-1: +BASH_FUNC_is_empty_dir()=() {  return `ls -A $1|wc -w`
# [D]: >> 0-1: +BASH_FUNC_ldlibrarypath_remove()=() {  if [[ $LD_LIBRARY_PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_log_error()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` ERROR $1"
# [D]: >> 0-1: +BASH_FUNC_log_info()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` INFO $1"
# [D]: >> 0-1: +BASH_FUNC_log_warn()=() {  echo "`date +%y/%m/%d\ %H:%M:%S` WARN $1"
# [D]: >> 0-1: +BASH_FUNC_path_remove()=() {  if [[ $PATH == "$1" ]]; then
# [D]: >> 0-1: +BASH_FUNC_powerai_save_var_initial()=() {  local package="$1";
# [D]: >> 0-1: +BASH_FUNC_python_path_remove()=() {  if echo $PYTHONPATH | /bin/grep -q $1; then
# [D]: >> 0-1: +BASH_FUNC_trace_env()=() {  log_info "Trace envrionment";
# [D]: >> 0-1: +BUILD_OS_ARCH=ppc64le
# [D]: >> 0-1: +BUILD_OS_ID=rhel
# [D]: >> 0-1: +BUILD_OS_VERSION_ID=7.6
# [D]: >> 0-1: +CAFFE_BIN=/opt/anaconda3/envs/dlipy3/bin
# [D]: >> 0-1: +COMPONENT=tensorflow
# [D]: >> 0-1: +CONDA_DEFAULT_ENV=dlipy3
# [D]: >> 0-1: +CONDA_EXE=/opt/anaconda3/bin/conda
# [D]: >> 0-1: +CONDA_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +CONDA_PROMPT_MODIFIER=(dlipy3)
# [D]: >> 0-1: +CONDA_SHLVL=1
# [D]: >> 0-1: +CUDA_TOOLKIT_LIB_PATH=/opt/anaconda3/envs/dlipy3/cuda/lib:
# [D]: >> 0-1:  CUDA_VISIBLE_DEVICES=3
# [D]: >> 0-1: +DATA_PATH=hymenoptera_data
# [D]: >> 0-1:  DEPLOY_MODE=cluster
# [D]: >> 0-1: +DLI_CONDA_ENV_NAME=dlipy3
# [D]: >> 0-1:  DLI_CONDA_ENV_PREFIX_DEFAULT=dli
# [D]: >> 0-1:  DLI_CONDA_HOME=/opt/anaconda3
# [D]: >> 0-1: +DLI_CONDA_LIBPATH=/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1:  DLI_DATA_FS=/dlidata/
# [D]: >> 0-1:  DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# [D]: >> 0-1: -DLI_EXTRA_CONF=...
# [D]: >> 0-1: +DLI_ELASTIC_PROFILE=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf/profile.elastic
# [D]: >> 0-1: +DLI_EXECID=Admin-2809611603258194-1703562770
# [D]: >> 0-1: +DLI_FABRIC_BUILDFILE=/dlishared//fabric/1.2.3/build.version
# [D]: >> 0-1:  DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +DLI_IS_ELASTIC=true
# [D]: >> 0-1: +DLI_LOGGER_LEVEL=debug
# [D]: >> 0-1:  DLI_RESULT_FS=/dliresult/
# [D]: >> 0-1: +DLI_SHARED_FS=/dlishared/
# [D]: >> 0-1:  DLI_SPARK_APP_NAME=ElasticTrain-PyTorch
# [D]: >> 0-1: +DLI_WORK_DIR=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1:  DL_NFS_PATH=/dlishared/
# [D]: >> 0-1:  DRIVER_EXECUTOR_SHAREDKEY=41a58df6-b722-4522-9c73-8558b085b237
# [D]: >> 0-1:  EGO_ACTIVITY_PID=-1
# [D]: >> 0-1: @@ -19,12 +217,33 @@
# [D]: >> 0-1:  EGO_TOP=/opt/ibm/spectrumcomputing
# [D]: >> 0-1:  FABRIC_BACKEND=pytorch
# [D]: >> 0-1:  FABRIC_FIRST_HOST_EXECUTOR=true
# [D]: >> 0-1: +FABRIC_HOME=/dlishared//fabric/1.2.3
# [D]: >> 0-1: +GREP=/bin/grep
# [D]: >> 0-1:  HOME=/home/egoadmin
# [D]: >> 0-1: +HOSTNAME_F=colonia05.platform
# [D]: >> 0-1:  JAVA_HOME=/opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le
# [D]: >> 0-1:  LAST_UPDATED_TIMESTAMP=1580185149401
# [D]: >> 0-1: -LD_LIBRARY_PATH=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/8300:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib
# [D]: >> 0-1: -PATH=/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/8300:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# [D]: >> 0-1: +MODEL_PATH=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1: +MPI_ROOT=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OMP_NUM_THREADS=16
# [D]: >> 0-1: +OPAL_PREFIX=/opt/anaconda3/envs/dlipy3
# [D]: >> 0-1: +OS_DISTRO=rhel7
# [D]: >> 0-1: +OS_ID=rhel
# [D]: >> 0-1: +OS_VER=7.6
# [D]: >> 0-1: +PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# [D]: >> 0-1: +POWERAI_caffe_CAFFE_BIN=unset
# [D]: >> 0-1: +POWERAI_caffe_OMP_NUM_THREADS=16
# [D]: >> 0-1: +POWERAI_pytorch_OMP_NUM_THREADS=16
# [D]: >> 0-1: +PS1=(dlipy3)
# [D]: >> 0-1: +PS_PATH=/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2
# [D]: >> 0-1:  PWD=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/executor-0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542
# [D]: >> 0-1: +PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2:
# [D]: >> 0-1: +RDMA_BUFFER_SIZE=1073741824
# [D]: >> 0-1: +RDMA_DEVICE_NAME=
# [D]: >> 0-1: +RDMA_DEVICE_PORT=
# [D]: >> 0-1: +RDMA_ENABLED=false
# [D]: >> 0-1: +RESUME_WEIGHT_PATH=null
# [D]: >> 0-1:  SHLVL=2
# [D]: >> 0-1:  SIG_DEPLOY_USER=egoadmin
# [D]: >> 0-1:  SPARK_APP_DRIVER_MEMORY=4G
# [D]: >> 0-1: @@ -92,6 +311,34 @@
# [D]: >> 0-1:  SPARK_PRINT_LAUNCH_COMMAND=1
# [D]: >> 0-1:  SPARK_SCALA_VERSION=2.10
# [D]: >> 0-1:  SPARK_USER=egoadmin
# [D]: >> 0-1: +SYS_PYTHON_MAJOR=3
# [D]: >> 0-1: +SYS_PYTHON_MINOR=6
# [D]: >> 0-1: +TF_INCLUDE_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow/include
# [D]: >> 0-1: +TF_LIBRARY_DIR=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1: +TF_PKG_PATH=/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow
# [D]: >> 0-1:  USER=egoadmin
# [D]: >> 0-1: +USER_UID=1001
# [D]: >> 0-1:  _=/bin/env
# [D]: >> 0-1: +_CE_CONDA=
# [D]: >> 0-1: +_CE_M=
# [D]: >> 0-1: +_CONDA_ROOT=/opt/anaconda3
# [D]: >> 0-1: +is_powerai=true
# [D]: >> 0-1: +is_rhel=true
# [D]: >> 0-1: +is_ubuntu=false
# [D]: >> 0-1:  tmpdir=/tmp/PpcaOaUV
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: >> 0-1: +}
# [D]: final: >> CUDA_VISIBLE_DEVICES=3
# Check GPU memory utilization
# CUDA_VISIBLE_DEVICES is set to 3
# Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data
# Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# 20/02/21 23:47:23 INFO Trace envrionment
# CUDA_VISIBLE_DEVICES=3
# DLI_CONDA_HOME=/opt/anaconda3
# DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# DL_NFS_PATH=/dlishared/
# DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# DLI_LOGGER_LEVEL=debug
# PYTHON_VERSION=
# SPARK_EGO_USER_FIRST_JARS=
# LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/8300:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib
# PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2:
# PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# RDMA_ENABLED=false
# RDMA_BUFFER_SIZE=1073741824
# RDMA_DEVICE_NAME=
# RDMA_DEVICE_PORT=
# DLI_IS_ELASTIC=true
# USER=egoadmin
# USER_UID=1001
# DLI_EXECID=Admin-2809611603258194-1703562770
# SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/
# 20/02/21 23:47:23 INFO finish spark environment setup.

# %% [markdown]
# ## Retrieve Executor Stderr log
# #### set the parameter executor_id

# %%
executor_id = '0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542'

r = requests.get(sc_rest_url+'/instances/'+sig_id+'/applications/'+driver_id +'/'+executor_id+'/logs/stderr/download',
                 auth=myauth, headers={'Accept': 'application/octet-stream'}, verify=False)

print(r.text)
# Out:
# +++ export SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ SPARK_EGO_PYTHON_KILL_WORKER_PGROUP=true
# +++ '[' -z '' ']'
# +++ export GLOG_logtostderr=true
# +++ GLOG_logtostderr=true
# +++ '[' -z '' -a -n '' -a -f '' ']'
# +++ '[' -n '' -a -f '' ']'
# +++ '[' true = true ']'
# +++ checkGPUMemory
# +++ echo 'Check GPU memory utilization'
# +++ echo 'CUDA_VISIBLE_DEVICES is set to 3'
# +++ utilization_high=1
# +++ timeout_secs=30
# +++ time_sleep=0
# +++ '[' 0 -lt 30 -a 1 -eq 1 ']'
# +++ utilization_high=0
# ++++ echo 3
# ++++ tr , ' '
# +++ for gpuid in '$(echo $CUDA_VISIBLE_DEVICES | tr '\'','\'' '\'' '\'')'
# ++++ nvidia-smi -i 3 --query-gpu=utilization.memory --format=csv,nounits,noheader
# +++ utilization=0
# +++ '[' 0 -gt 90 ']'
# +++ '[' 0 -eq 1 ']'
# +++ '[' 0 -lt 30 -a 0 -eq 1 ']'
# +++ '[' 0 -eq 1 ']'
# +++ export NCCL_P2P_DISABLE=1
# +++ NCCL_P2P_DISABLE=1
# +++ handle_BYOF_EDT_Job
# +++ '[' true = true -a Admin-2809611603258194-1703562770x '!=' x ']'
# +++ '[' /dlidata/ '!=' '' ']'
# +++ export DATA_DIR=/dlidata//hymenoptera_data
# +++ DATA_DIR=/dlidata//hymenoptera_data
# +++ local batch_path=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ export RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ RESULT_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# +++ '[' -n /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/ ']'
# ++++ basename /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/
# +++ local log_subdir=0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# +++ export LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# +++ LOG_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# +++ mkdir -p /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# +++ export SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# +++ SAVED_MODEL_DIR=/dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# +++ echo 'Exposed the environment variable DATA_DIR to: /dlidata//hymenoptera_data'
# +++ echo 'Exposed the environment variable RESULT_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770'
# +++ echo 'Exposed the environment variable LOG_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform'
# +++ echo 'Exposed the environment variable SAVED_MODEL_DIR to: /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model'
# +++ echo /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/
# +++ grep logs/driver-
# +++ trace_env
# +++ log_info 'Trace envrionment'
# ++++ date '+%y/%m/%d %H:%M:%S'
# +++ echo '20/02/21 23:47:23 INFO Trace envrionment'
# +++ echo CUDA_VISIBLE_DEVICES=3
# +++ echo DLI_CONDA_HOME=/opt/anaconda3
# +++ echo DLI_FABRIC_HOME=/dlishared//fabric/1.2.3
# +++ echo DL_NFS_PATH=/dlishared/
# +++ echo DLI_ELASTIC_CONF_DIR=/opt/ibm/spectrumcomputing/dli/1.2.3/fabric/conf
# +++ echo DLI_LOGGER_LEVEL=debug
# +++ echo PYTHON_VERSION=
# +++ echo SPARK_EGO_USER_FIRST_JARS=
# +++ echo 'LD_LIBRARY_PATH=/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/8300:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/anaconda3/envs/dlipy2/lib:/opt/anaconda3/envs/dlipy2/lib/python2.7/site-packages/tensorflow:/dlishared//fabric/1.2.3/native:/dlishared//fabric/1.2.3/third-native/libs/ppc64le:$LD_LIBRARY_PATH:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/lib:/opt/anaconda3/envs/dlipy3/cuda/lib::/opt/anaconda3/envs/dlipy3/lib/python3.6/site-packages/tensorflow:/opt/anaconda3/envs/dlipy3/lib'
# +++ echo PYTHONPATH=/dlishared//tools/dli_utils/:/dlishared//fabric/1.2.3/libs/fabric.zip:/dlishared//tools/dli_utils:/dlishared//fabric/1.2.3/tools:/dliresult/egoadmin/batchworkdir/Admin-2809611603258194-1703562770/_submitted_code/pytorch_edt_cssc2:
# +++ echo PATH=/opt/anaconda3/envs/dlipy3/bin:/opt/anaconda3/condabin:/opt/anaconda3/bin:/usr/local/bin:/bin:/usr/bin:/opt/ibm/spectrumcomputing/3.8/linux3.10-glibc2.17-ppc64le/bin
# +++ echo RDMA_ENABLED=false
# +++ echo RDMA_BUFFER_SIZE=1073741824
# +++ echo RDMA_DEVICE_NAME=
# +++ echo RDMA_DEVICE_PORT=
# +++ echo DLI_IS_ELASTIC=true
# +++ echo USER=egoadmin
# +++ echo USER_UID=1001
# +++ echo DLI_EXECID=Admin-2809611603258194-1703562770
# +++ echo SPARK_LOG_STDOUTSTDERR_DIR=/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/
# +++ false
# +++ set +x
# Spark Command: /opt/ibm/spectrumcomputing/jre/8.0.6.0/linux-ppc64le/bin/java -cp /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/ego/*:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/8300:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/egoadmin/33851:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/conf/:/var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/jars/* -Dspark.ssl.ego.workload.enabled=false -Dspark.ssl.ego.gui.enabled=false -Dspark.ssl.enabled=false -Dspark.rpc.framesize=2047 -Dspark.shuffle.service.port=7341 -Dspark.driver.port=35089 -Dspark.ui.port=0 -Dspark.master.rest.port=6070 -Djava.security.egd=file:/dev/./urandom -Xmx4096m org.apache.spark.executor.EGOExecutorBackend --driver-url spark://EGODRIVERScheduler@colonia05.platform:35089 --executor-id 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542 --hostname colonia05.platform --cores 1 --app-id app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322 --resourceType GPU
# ========================================
# 20/02/21 23:47:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 20/02/21 23:47:25 INFO EGOExecutorBackend:  The args is : [Ljava.lang.String;@54439b3e
# 20/02/21 23:47:25 INFO EGOExecutorBackend: Started daemon with process name: 9805@colonia05.platform
# 20/02/21 23:47:25 INFO SignalUtils: Registered signal handler for TERM
# 20/02/21 23:47:25 INFO SignalUtils: Registered signal handler for HUP
# 20/02/21 23:47:25 INFO SignalUtils: Registered signal handler for INT
# 20/02/21 23:47:25 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:25 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:25 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:25 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:25 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:26 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:35089 after 78 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:26 WARN SparkConf: The configuration key 'spark.akka.frameSize' has been deprecated as of Spark 1.6 and may be removed in the future. Please use the new key 'spark.rpc.message.maxSize' instead.
# 20/02/21 23:47:26 INFO SecurityManager: Changing view acls to: egoadmin
# 20/02/21 23:47:26 INFO SecurityManager: Changing modify acls to: egoadmin
# 20/02/21 23:47:26 INFO SecurityManager: Changing view acls groups to:
# 20/02/21 23:47:26 INFO SecurityManager: Changing modify acls groups to:
# 20/02/21 23:47:26 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(egoadmin); groups with view permissions: Set(); users  with modify permissions: Set(egoadmin); groups with modify permissions: Set()
# 20/02/21 23:47:26 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:35089 after 1 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:26 INFO DiskBlockManager: Created local directory at /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/blockmgr-0a603a54-25a4-4d26-ad13-7d7663b1d905
# 20/02/21 23:47:26 INFO MemoryStore: MemoryStore started with capacity 2.2 GB
# 20/02/21 23:47:26 INFO EGOExecutorBackend: Connecting to driver: spark://EGODRIVERScheduler@colonia05.platform:35089
# 20/02/21 23:47:26 INFO EGOExecutorBackend: getLogPath /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/logs/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform/
# 20/02/21 23:47:26 INFO EGOExecutorBackend: Successfully registered with driver
# 20/02/21 23:47:26 INFO Executor: Starting executor ID 0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542 on host colonia05.platform
# 20/02/21 23:47:26 INFO Utils: Incrementing port number property = true.
# 20/02/21 23:47:26 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 45870.
# 20/02/21 23:47:26 INFO NettyBlockTransferService: Server created on colonia05.platform:45870
# 20/02/21 23:47:26 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/21 23:47:26 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542, colonia05.platform, 45870, None)
# 20/02/21 23:47:26 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542, colonia05.platform, 45870, None)
# 20/02/21 23:47:26 INFO BlockManager: external shuffle service port = 7341
# 20/02/21 23:47:26 INFO BlockManager: Registering executor with local external shuffle service.
# 20/02/21 23:47:26 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:7341 after 1 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:26 INFO BlockManager: Initialized BlockManager: BlockManagerId(0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542, colonia05.platform, 45870, None)
# 20/02/21 23:47:26 INFO EGOExecutorBackend: Got assigned task 0 with concurrent number(1)
# 20/02/21 23:47:26 INFO Executor: Task 0 took 0 ms in queue
# 20/02/21 23:47:26 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 20/02/21 23:47:27 INFO Executor: [task] [startingDeserialization] taskName:task 0.0 in stage 0.0 taskId:0 deserializeStartTime:1582325246982
# 20/02/21 23:47:27 INFO Executor: Fetching spark://colonia05.platform:35089/files/pytorch_mnist_EDT.py with timestamp 1582325237946
# 20/02/21 23:47:27 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:35089 after 1 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:27 INFO Utils: Fetching spark://colonia05.platform:35089/files/pytorch_mnist_EDT.py to /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/fetchFileTemp4700965863006414588.tmp
# 20/02/21 23:47:27 INFO Utils: Copying /tmp/63027c69-543b-451c-9a03-9c850784725f_egoadmin_egoadmin/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/7304499081582325237946_cache to /var/conductor/dli-edt/spark-2.3.3-hadoop-2.7/work/app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322/executor-0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542/./pytorch_mnist_EDT.py
# 20/02/21 23:47:27 INFO Executor: [task] [started] taskName:task 0.0 in stage 0.0 taskId:0 startTime:1582325247128
# 20/02/21 23:47:27 INFO TorrentBroadcast: Started reading broadcast variable 1
# 20/02/21 23:47:27 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:33350 after 2 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:27 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 3.8 KB, free 2.2 GB)
# 20/02/21 23:47:27 INFO TorrentBroadcast: Reading broadcast variable 1 took 155 ms
# 20/02/21 23:47:27 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 6.1 KB, free 2.2 GB)
# 20/02/21 23:47:27 INFO TorrentBroadcast: Started reading broadcast variable 0
# 20/02/21 23:47:27 INFO MemoryStore: Block broadcast_0_piece8 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:27 INFO MemoryStore: Block broadcast_0_piece12 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:27 INFO MemoryStore: Block broadcast_0_piece1 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece16 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece5 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece11 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece4 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO TransportClientFactory: Successfully created connection to colonia05.platform/10.3.64.217:33916 after 0 ms (0 ms spent in bootstraps)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece9 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece3 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece13 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece18 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece7 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece17 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece2 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece14 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece19 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece20 stored as bytes in memory (estimated size 3.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece10 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece6 stored as bytes in memory (estimated size 4.0 MB, free 2.2 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece15 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/21 23:47:28 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 4.0 MB, free 2.1 GB)
# 20/02/21 23:47:28 INFO TorrentBroadcast: Reading broadcast variable 0 took 692 ms
# 20/02/21 23:47:29 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 584.0 B, free 2.1 GB)
# <> DATA_DIR /dlidata//hymenoptera_data
# <> RESULT_DIR /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770
# <> LOG_DIR /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/log/0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.colonia05.platform
# <> SAVED_MODEL_DIR /dliresult//egoadmin/batchworkdir/Admin-2809611603258194-1703562770/model
# Using pytorch backend.
# /dlishared/fabric/1.2.3/libs/fabric.zip/fabric_zmqservice/rep_stream_handler.py:15: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
# libunformatworker.so loaded successfully
# Using spark scheduler.
# 2020-02-21 23:47:30,456 - root - INFO - spark
# 2020-02-21 23:47:30,457 - root - INFO - create dataset
# 2020-02-21 23:47:30,460 - root - INFO - create dataloader
# 2020-02-21 23:47:30,460 - root - INFO - pytorch_backend init_dataloader
# 2020-02-21 23:47:30,460 - root - INFO - ! dataset size 244, batch size 64
# 2020-02-21 23:47:30,460 - root - INFO - worker-a7c9f0ac-f805-4455-868e-8468ef6b590b: action: send batch setting
# 2020-02-21 23:47:30,461 - root - INFO - zmq connected, url: tcp://10.3.64.217:37325
# 2020-02-21 23:47:30,627 - root - INFO - setup model
# 2020-02-21 23:47:30,627 - root - INFO - _worker_loop - worker 0 start pid: 13162
# 2020-02-21 23:47:30,627 - root - INFO - resume weight from None
# 2020-02-21 23:47:32,664 - root - INFO - CUDA Device set to: 0
# 2020-02-21 23:47:32,666 - root - INFO - init_ese_worker, grad size 1026
# UnformatedEseWorker created.
# work ptr is: 0x10027b3fb20
# 2020-02-21 23:47:32,915 - root - INFO -  ese engine created!
# 2020-02-21 23:47:32,917 - root - INFO - setup optimizer
# 2020-02-21 23:47:32,917 - root - INFO - client registration
# 2020-02-21 23:47:32,917 - root - INFO - worker-a7c9f0ac-f805-4455-868e-8468ef6b590b register sync variable !
# 2020-02-21 23:47:32,917 - root - INFO - start heart beat
# 2020-02-21 23:47:32,917 - root - INFO - !ADD_NODE: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8
# 2020-02-21 23:47:32,919 - root - INFO - !ADD_NODE: worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0
# 2020-02-21 23:47:32,919 - root - INFO - add node id worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0
# 2020-02-21 23:47:32,919 - root - INFO - epoch start, total epoch 50
# 2020-02-21 23:47:32,919 - root - INFO - --------START TRAINING--------
# 2020-02-21 23:47:32,920 - root - INFO - <=== Epoch 0 Begin ==>
# 2020-02-21 23:47:32,920 - root - INFO - kick off the trainer
# 2020-02-21 23:47:32,928 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: PUSH_WEIGHT, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 0
# 2020-02-21 23:47:32,928 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: HandleControlMsg: Receive PUSH_WEIGHT message.
# 2020-02-21 23:47:32,928 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: HandleControlMsg PUSH_WEIGHT: First worker in the topo, myself worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0
# 2020-02-21 23:47:32,932 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: PULL_WEIGHT, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 0
# 2020-02-21 23:47:32,933 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 1
# 2020-02-21 23:47:32,934 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 0
# 2020-02-21 23:47:32,935 - root - INFO - idx presend batch 0 pending {0, 1, 2, 3}
# 2020-02-21 23:47:32,935 - root - INFO - FabricDistributedSampler.next - tid: 0, batch_idx:[7, 26, 115, 50, 43, 130, 154, 217, 46, 191, 24, 197, 186, 222, 204, 86, 234, 218, 212, 172, 64, 144, 149, 198, 61, 110, 229, 173, 207, 193, 44, 109, 181, 47, 22, 214, 32, 136, 105, 74, 240, 11, 38, 213, 150, 68, 45, 162, 192, 135, 205, 2, 1, 95, 89, 34, 17, 221, 166, 37, 52, 60, 10, 13]
# 2020-02-21 23:47:32,935 - root - INFO - _process_next_indices - put to index queue: tid=0
# 2020-02-21 23:47:32,935 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 1
# 2020-02-21 23:47:32,935 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 0, batch_indices [7, 26, 115, 50, 43, 130, 154, 217, 46, 191, 24, 197, 186, 222, 204, 86, 234, 218, 212, 172, 64, 144, 149, 198, 61, 110, 229, 173, 207, 193, 44, 109, 181, 47, 22, 214, 32, 136, 105, 74, 240, 11, 38, 213, 150, 68, 45, 162, 192, 135, 205, 2, 1, 95, 89, 34, 17, 221, 166, 37, 52, 60, 10, 13]
# 2020-02-21 23:47:32,936 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-21 23:47:32,936 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[194, 182, 160, 20, 99, 164, 151, 59, 203, 239, 69, 201, 15, 236, 80, 9, 141, 127, 143, 142, 57, 81, 116, 227, 242, 152, 70, 216, 92, 196, 41, 140, 231, 117, 96, 183, 79, 12, 177, 101, 153, 71, 90, 118, 84, 111, 72, 6, 219, 54, 93, 33, 128, 156, 0, 56, 134, 199, 168, 241, 163, 76, 159, 21]
# 2020-02-21 23:47:32,936 - root - INFO - _process_next_indices - put to index queue: tid=1
# 2020-02-21 23:47:33,435 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 1, batch_indices [194, 182, 160, 20, 99, 164, 151, 59, 203, 239, 69, 201, 15, 236, 80, 9, 141, 127, 143, 142, 57, 81, 116, 227, 242, 152, 70, 216, 92, 196, 41, 140, 231, 117, 96, 183, 79, 12, 177, 101, 153, 71, 90, 118, 84, 111, 72, 6, 219, 54, 93, 33, 128, 156, 0, 56, 134, 199, 168, 241, 163, 76, 159, 21]
# 2020-02-21 23:47:33,447 - root - INFO - loader.next - read idx:0, batches_outstanding:0
# 2020-02-21 23:47:33,447 - root - INFO - loader.next - randomly handle batch 0
# 2020-02-21 23:47:33,447 - root - INFO - Start training batch 0
# 2020-02-21 23:47:34,387 - root - INFO - sync local
# 2020-02-21 23:47:34,392 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 2
# 2020-02-21 23:47:34,392 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:47:34,393 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 2, 'correction': tensor(29), 'count': 64, 'loss': -0.2486114203929901}
# Timestamp 1582325254395, Iteration 1
# batches :1 -0.2486114203929901
# Iteration 2: tag train_accuracy, simple_value 0.45312
# Iteration 2: tag train_loss, simple_value -0.24861
# 2020-02-21 23:47:34,395 - root - INFO - Batch 0 training finished
# 2020-02-21 23:47:34,395 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:47:34,395 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-21 23:47:34,395 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[194, 182, 160, 20, 99, 164, 151, 59, 203, 239, 69, 201, 15, 236, 80, 9, 141, 127, 143, 142, 57, 81, 116, 227, 242, 152, 70, 216, 92, 196, 41, 140, 231, 117, 96, 183, 79, 12, 177, 101, 153, 71, 90, 118, 84, 111, 72, 6, 219, 54, 93, 33, 128, 156, 0, 56, 134, 199, 168, 241, 163, 76, 159, 21]
# 2020-02-21 23:47:34,395 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 2
# 2020-02-21 23:47:34,396 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-21 23:47:34,396 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[63, 23, 147, 206, 208, 30, 224, 19, 226, 131, 75, 126, 158, 210, 58, 106, 85, 36, 42, 148, 157, 25, 185, 40, 139, 119, 137, 122, 83, 165, 121, 215, 167, 175, 108, 195, 62, 107, 132, 98, 35, 171, 155, 129, 78, 123, 176, 29, 73, 31, 113, 48, 14, 65, 230, 55, 145, 87, 125, 114, 138, 94, 27, 161]
# 2020-02-21 23:47:34,396 - root - INFO - _process_next_indices - put to index queue: tid=2
# 2020-02-21 23:47:34,396 - root - INFO - loader.next - read idx:1, batches_outstanding:0
# 2020-02-21 23:47:34,396 - root - INFO - loader.next - randomly handle batch 1
# 2020-02-21 23:47:34,397 - root - INFO - Start training batch 1
# 2020-02-21 23:47:34,397 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 2, batch_indices [63, 23, 147, 206, 208, 30, 224, 19, 226, 131, 75, 126, 158, 210, 58, 106, 85, 36, 42, 148, 157, 25, 185, 40, 139, 119, 137, 122, 83, 165, 121, 215, 167, 175, 108, 195, 62, 107, 132, 98, 35, 171, 155, 129, 78, 123, 176, 29, 73, 31, 113, 48, 14, 65, 230, 55, 145, 87, 125, 114, 138, 94, 27, 161]
# 2020-02-21 23:47:34,404 - root - INFO - sync local
# 2020-02-21 23:47:34,416 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_UP, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 2
# 2020-02-21 23:47:34,416 - root - INFO - HandleControlMsg: new communicate id is CgDoFgAAAAD+gAAAAAAAACaKBwMAp5ggCAAAAP4/AADol7ev/j8AABA3uTQAAQAAiHXcs/4/AADA1g+0/j8AAODMAJz+PwAAWnZNb0mVpnkaIwAA/j8AALDx/ab+PwAAQJi3r/4/AAD//wMAAAAAAJC0ELT+PwAAAH8LDQEAAAA=
# 2020-02-21 23:47:34,416 - root - INFO - ese-worker reset engine, local grads buffer
# 2020-02-21 23:47:34,416 - root - INFO - ------cluster begin-------
# 2020-02-21 23:47:34,416 - root - INFO - ['worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0']
# 2020-02-21 23:47:34,417 - root - INFO - ------cluster end-------
# 2020-02-21 23:47:34,417 - root - INFO - Initializing DDL with options:-ddl_worker_count 1 -ddl_worker_index 0 -ddl_device_index 0 -ddl_group_id CgDoFgAAAAD+gAAAAAAAACaKBwMAp5ggCAAAAP4/AADol7ev/j8AABA3uTQAAQAAiHXcs/4/AADA1g+0/j8AAODMAJz+PwAAWnZNb0mVpnkaIwAA/j8AALDx/ab+PwAAQJi3r/4/AAD//wMAAAAAAJC0ELT+PwAAAH8LDQEAAAA=
# colonia05:13049:13049 [0] NCCL INFO NET/Socket : Using [0]ib0:fe80::268a:703:a7:9820%ib0<0>
# colonia05:13049:13049 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# colonia05:13049:13049 [0] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# NCCL version 2.4.7nvb1+cuda10.1
# colonia05:13049:13049 [0] NCCL INFO NCCL_P2P_DISABLE set by environment to 1.
# colonia05:13049:13049 [0] NCCL INFO Using 256 threads, Min Comp Cap 6, Trees enabled up to size -2
# colonia05:13049:13049 [0] NCCL INFO comm 0x3eff63024d50 rank 0 nranks 1 cudaDev 0 nvmlDev 3 - Init COMPLETE
# 2020-02-21 23:47:34,486 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 Receive SYNC_UP round 1 group{'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}} changed? True
# 2020-02-21 23:47:34,486 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x10027b3fb20
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-21 23:47:34,487 - root - INFO - optmizer step local 3
# 2020-02-21 23:47:34,490 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_DONE, sender worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0, global step 2
# 2020-02-21 23:47:34,494 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 3
# 2020-02-21 23:47:34,494 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:47:34,494 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 3, 'correction': tensor(30), 'count': 64, 'loss': -0.2925989627838135}
# Timestamp 1582325254497, Iteration 2
# batches :2 -0.2925989627838135
# Iteration 3: tag train_accuracy, simple_value 0.46094
# Iteration 3: tag train_loss, simple_value -0.2926
# 2020-02-21 23:47:34,496 - root - INFO - Batch 1 training finished
# 2020-02-21 23:47:34,496 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:47:34,496 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-21 23:47:34,496 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[63, 23, 147, 206, 208, 30, 224, 19, 226, 131, 75, 126, 158, 210, 58, 106, 85, 36, 42, 148, 157, 25, 185, 40, 139, 119, 137, 122, 83, 165, 121, 215, 167, 175, 108, 195, 62, 107, 132, 98, 35, 171, 155, 129, 78, 123, 176, 29, 73, 31, 113, 48, 14, 65, 230, 55, 145, 87, 125, 114, 138, 94, 27, 161]
# 2020-02-21 23:47:34,496 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 3
# 2020-02-21 23:47:34,497 - root - INFO - idx presend batch 3 pending {3}
# 2020-02-21 23:47:34,497 - root - INFO - FabricDistributedSampler.next - tid: 3, batch_idx:[233, 169, 202, 178, 188, 18, 16, 184, 228, 49, 66, 243, 180, 237, 4, 91, 235, 225, 102, 28, 238, 211, 170, 174, 223, 112, 67, 8, 77, 189, 146, 220, 82, 190, 39, 187, 100, 179, 97, 232, 53, 104, 103, 51, 124, 120, 200, 133, 3, 209, 5, 88]
# 2020-02-21 23:47:34,498 - root - INFO -
#  final batch 52
# 2020-02-21 23:47:34,498 - root - INFO - _process_next_indices - put to index queue: tid=3
# 2020-02-21 23:47:34,917 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: heartbeat
# 2020-02-21 23:47:34,953 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 3, batch_indices [233, 169, 202, 178, 188, 18, 16, 184, 228, 49, 66, 243, 180, 237, 4, 91, 235, 225, 102, 28, 238, 211, 170, 174, 223, 112, 67, 8, 77, 189, 146, 220, 82, 190, 39, 187, 100, 179, 97, 232, 53, 104, 103, 51, 124, 120, 200, 133, 3, 209, 5, 88]
# 2020-02-21 23:47:34,958 - root - INFO - loader.next - read idx:2, batches_outstanding:0
# 2020-02-21 23:47:34,959 - root - INFO - loader.next - randomly handle batch 2
# 2020-02-21 23:47:34,959 - root - INFO - Start training batch 2
# 2020-02-21 23:47:34,967 - root - INFO - sync local
# 2020-02-21 23:47:34,971 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 4
# 2020-02-21 23:47:34,991 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:47:34,991 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 4, 'correction': tensor(43), 'count': 64, 'loss': -20.104394912719727}
# Timestamp 1582325254994, Iteration 3
# batches :3 -20.104394912719727
# Iteration 4: tag train_accuracy, simple_value 0.53125
# Iteration 4: tag train_loss, simple_value -20.10439
# 2020-02-21 23:47:34,993 - root - INFO - Batch 2 training finished
# 2020-02-21 23:47:34,993 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:47:34,994 - root - INFO - _process_next_indices - all data index cached
# 2020-02-21 23:47:35,359 - root - INFO - loader.next - read idx:3, batches_outstanding:-1
# 2020-02-21 23:47:35,359 - root - INFO - loader.next - randomly handle batch 3
# 2020-02-21 23:47:35,359 - root - INFO - Start training batch 3
# 2020-02-21 23:47:35,367 - root - INFO - sync local
# 2020-02-21 23:47:35,371 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_UP, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 4
# 2020-02-21 23:47:35,372 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 Receive SYNC_UP round 2 group{'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}} changed? False
# 2020-02-21 23:47:35,372 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x10027b3fb20
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-21 23:47:35,389 - root - INFO - optmizer step local 6
# 2020-02-21 23:47:35,391 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_DONE, sender worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0, global step 4
# 2020-02-21 23:47:35,395 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: END_EPOCH, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 0
# 2020-02-21 23:47:35,395 - root - INFO - sync: end of the epoch
# 2020-02-21 23:47:35,395 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:47:35,395 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 0, 'correction': tensor(41), 'count': 52, 'loss': -20.243711471557617}
# Timestamp 1582325255398, Iteration 4
# batches :4 -20.243711471557617
# Iteration 4: tag train_accuracy, simple_value 0.78846
# Iteration 4: tag train_loss, simple_value -20.24371
# 2020-02-21 23:47:35,397 - root - INFO - Batch 3 training finished
# 2020-02-21 23:47:35,398 - root - INFO - loader reset, batch_sample.is_final:True
# 2020-02-21 23:47:35,398 - root - INFO - <=== Epoch 0 End ==>
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.ExternalShuffle.shuffle-client.usedDirectMemory, value=-1
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.ExternalShuffle.shuffle-client.usedHeapMemory, value=16777216
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.largeRead_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.read_bytes, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.read_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.write_bytes, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.write_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.largeRead_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.read_bytes, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.read_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.write_bytes, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.write_ops, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.activeGpuTasks, value=1
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.completeGpuTasks, value=0
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.currentPool_size, value=1
# 20/02/21 23:47:36 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.maxPool_size, value=2147483647
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.bytesRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.bytesWritten, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.cpuTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.deserializeCpuTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.deserializeTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.diskBytesSpilled, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.jvmGCTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.memoryBytesSpilled, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.recordsRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.recordsWritten, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.resultSerializationTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.resultSize, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.runTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleBytesWritten, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleFetchWaitTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleLocalBlocksFetched, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleLocalBytesRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRecordsRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRecordsWritten, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBlocksFetched, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBytesRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBytesReadToDisk, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleTotalBytesRead, count=0
# 20/02/21 23:47:36 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleWriteTime, count=0
# 20/02/21 23:47:36 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:36 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:36 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:47:36 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 2020-02-21 23:47:36,918 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: heartbeat
# 2020-02-21 23:47:37,057 - root - INFO - <=== Epoch 1 Begin ==>
# 2020-02-21 23:47:37,057 - root - INFO - kick off the trainer
# 2020-02-21 23:47:37,062 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 1
# 2020-02-21 23:47:37,063 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 0
# 2020-02-21 23:47:37,064 - root - INFO - idx presend batch 0 pending {0, 1, 2, 3}
# 2020-02-21 23:47:37,064 - root - INFO - FabricDistributedSampler.next - tid: 0, batch_idx:[13, 174, 167, 2, 129, 148, 227, 159, 43, 233, 132, 20, 111, 85, 102, 192, 14, 125, 170, 110, 187, 119, 166, 230, 204, 198, 57, 71, 33, 107, 113, 135, 152, 75, 156, 24, 38, 90, 163, 209, 202, 83, 39, 217, 177, 221, 240, 236, 48, 115, 108, 127, 121, 0, 172, 5, 145, 92, 186, 51, 11, 146, 3, 114]
# 2020-02-21 23:47:37,064 - root - INFO - _process_next_indices - put to index queue: tid=0
# 2020-02-21 23:47:37,064 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 1
# 2020-02-21 23:47:37,065 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 0, batch_indices [13, 174, 167, 2, 129, 148, 227, 159, 43, 233, 132, 20, 111, 85, 102, 192, 14, 125, 170, 110, 187, 119, 166, 230, 204, 198, 57, 71, 33, 107, 113, 135, 152, 75, 156, 24, 38, 90, 163, 209, 202, 83, 39, 217, 177, 221, 240, 236, 48, 115, 108, 127, 121, 0, 172, 5, 145, 92, 186, 51, 11, 146, 3, 114]
# 2020-02-21 23:47:37,065 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-21 23:47:37,065 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[128, 1, 78, 18, 34, 136, 97, 213, 81, 193, 220, 63, 154, 158, 169, 23, 183, 94, 235, 229, 207, 191, 25, 70, 117, 12, 142, 190, 149, 7, 124, 55, 53, 173, 60, 223, 212, 241, 87, 37, 225, 17, 40, 232, 206, 36, 185, 175, 76, 41, 137, 139, 49, 64, 168, 35, 205, 58, 6, 109, 238, 239, 61, 65]
# 2020-02-21 23:47:37,065 - root - INFO - _process_next_indices - put to index queue: tid=1
# 2020-02-21 23:47:37,635 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 1, batch_indices [128, 1, 78, 18, 34, 136, 97, 213, 81, 193, 220, 63, 154, 158, 169, 23, 183, 94, 235, 229, 207, 191, 25, 70, 117, 12, 142, 190, 149, 7, 124, 55, 53, 173, 60, 223, 212, 241, 87, 37, 225, 17, 40, 232, 206, 36, 185, 175, 76, 41, 137, 139, 49, 64, 168, 35, 205, 58, 6, 109, 238, 239, 61, 65]
# 2020-02-21 23:47:37,640 - root - INFO - loader.next - read idx:0, batches_outstanding:0
# 2020-02-21 23:47:37,640 - root - INFO - loader.next - randomly handle batch 0
# 2020-02-21 23:47:37,640 - root - INFO - Start training batch 0
# 2020-02-21 23:47:37,648 - root - INFO - sync local
# 2020-02-21 23:47:37,652 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 2
# 2020-02-21 23:47:37,673 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:47:37,673 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 2, 'correction': tensor(36), 'count': 64, 'loss': -57.57344436645508}
# Timestamp 1582325257675, Iteration 5
# batches :5 -57.57344436645508
# Iteration 6: tag train_accuracy, simple_value 0.66379
# Iteration 6: tag train_loss, simple_value -57.57344
# 2020-02-21 23:47:37,675 - root - INFO - Batch 0 training finished
# 2020-02-21 23:47:37,675 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:47:37,675 - root - INFO - idx presend batch 1 pending {1, 2, 3}
# 2020-02-21 23:47:37,675 - root - INFO - FabricDistributedSampler.next - tid: 1, batch_idx:[128, 1, 78, 18, 34, 136, 97, 213, 81, 193, 220, 63, 154, 158, 169, 23, 183, 94, 235, 229, 207, 191, 25, 70, 117, 12, 142, 190, 149, 7, 124, 55, 53, 173, 60, 223, 212, 241, 87, 37, 225, 17, 40, 232, 206, 36, 185, 175, 76, 41, 137, 139, 49, 64, 168, 35, 205, 58, 6, 109, 238, 239, 61, 65]
# 2020-02-21 23:47:37,675 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 2
# 2020-02-21 23:47:37,676 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-21 23:47:37,676 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[218, 67, 214, 29, 179, 224, 197, 216, 242, 155, 46, 98, 8, 176, 153, 162, 130, 96, 15, 234, 50, 211, 21, 208, 82, 42, 184, 16, 180, 203, 122, 79, 86, 243, 141, 103, 150, 196, 44, 143, 88, 47, 231, 181, 56, 188, 118, 138, 62, 222, 68, 182, 171, 151, 116, 9, 215, 157, 26, 32, 19, 147, 69, 77]
# 2020-02-21 23:47:37,676 - root - INFO - _process_next_indices - put to index queue: tid=2
# 2020-02-21 23:47:38,114 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 2, batch_indices [218, 67, 214, 29, 179, 224, 197, 216, 242, 155, 46, 98, 8, 176, 153, 162, 130, 96, 15, 234, 50, 211, 21, 208, 82, 42, 184, 16, 180, 203, 122, 79, 86, 243, 141, 103, 150, 196, 44, 143, 88, 47, 231, 181, 56, 188, 118, 138, 62, 222, 68, 182, 171, 151, 116, 9, 215, 157, 26, 32, 19, 147, 69, 77]
# 2020-02-21 23:47:38,119 - root - INFO - loader.next - read idx:1, batches_outstanding:0
# 2020-02-21 23:47:38,120 - root - INFO - loader.next - randomly handle batch 1
# 2020-02-21 23:47:38,120 - root - INFO - Start training batch 1
# 2020-02-21 23:47:38,128 - root - INFO - sync local
# 2020-02-21 23:47:38,132 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_UP, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 2
# 2020-02-21 23:47:38,132 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 Receive SYNC_UP round 3 group{'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}} changed? False
# 2020-02-21 23:47:38,132 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x10027b3fb20
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# ...
# Timestamp 1582325432019, Iteration 198
# batches :198 -17565.51953125
# Iteration 199: tag train_accuracy, simple_value 0.64444
# Iteration 199: tag train_loss, simple_value -17565.51953
# 2020-02-21 23:50:32,019 - root - INFO - Batch 1 training finished
# 2020-02-21 23:50:32,019 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:50:32,019 - root - INFO - idx presend batch 2 pending {2, 3}
# 2020-02-21 23:50:32,019 - root - INFO - FabricDistributedSampler.next - tid: 2, batch_idx:[14, 122, 190, 221, 189, 19, 202, 215, 145, 214, 92, 183, 225, 101, 99, 140, 86, 131, 212, 110, 5, 79, 138, 157, 204, 114, 152, 219, 111, 66, 74, 120, 153, 165, 177, 232, 84, 191, 25, 78, 3, 82, 87, 226, 2, 106, 241, 95, 223, 49, 237, 11, 234, 229, 220, 203, 9, 16, 41, 29, 155, 129, 169, 240]
# 2020-02-21 23:50:32,019 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 action: GET BATCH INDEX pending 3
# 2020-02-21 23:50:32,019 - root - INFO - idx presend batch 3 pending {3}
# 2020-02-21 23:50:32,020 - root - INFO - FabricDistributedSampler.next - tid: 3, batch_idx:[130, 67, 227, 12, 15, 35, 55, 235, 213, 170, 156, 230, 224, 209, 81, 123, 27, 218, 69, 116, 187, 174, 149, 1, 216, 180, 8, 182, 199, 144, 56, 124, 10, 194, 65, 185, 119, 108, 31, 164, 61, 186, 88, 43, 217, 125, 57, 83, 59, 48, 172, 113]
# 2020-02-21 23:50:32,020 - root - INFO -
#  final batch 52
# 2020-02-21 23:50:32,020 - root - INFO - _process_next_indices - put to index queue: tid=3
# 2020-02-21 23:50:32,462 - root - INFO - _worker_loop - worker 0 put data to data_queue: tid 3, batch_indices [130, 67, 227, 12, 15, 35, 55, 235, 213, 170, 156, 230, 224, 209, 81, 123, 27, 218, 69, 116, 187, 174, 149, 1, 216, 180, 8, 182, 199, 144, 56, 124, 10, 194, 65, 185, 119, 108, 31, 164, 61, 186, 88, 43, 217, 125, 57, 83, 59, 48, 172, 113]
# 2020-02-21 23:50:32,468 - root - INFO - loader.next - read idx:2, batches_outstanding:0
# 2020-02-21 23:50:32,468 - root - INFO - loader.next - randomly handle batch 2
# 2020-02-21 23:50:32,468 - root - INFO - Start training batch 2
# 2020-02-21 23:50:32,476 - root - INFO - sync local
# 2020-02-21 23:50:32,478 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: NEW_TASK, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 4
# 2020-02-21 23:50:32,500 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:50:32,501 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 4, 'correction': tensor(44), 'count': 64, 'loss': -17874.28515625}
# Timestamp 1582325432503, Iteration 199
# batches :199 -17874.28515625
# Iteration 200: tag train_accuracy, simple_value 0.65574
# Iteration 200: tag train_loss, simple_value -17874.28516
# 2020-02-21 23:50:32,502 - root - INFO - Batch 2 training finished
# 2020-02-21 23:50:32,503 - root - INFO - loader.next - process next indices, batches_outstanding=1
# 2020-02-21 23:50:32,503 - root - INFO - _process_next_indices - all data index cached
# 2020-02-21 23:50:32,952 - root - INFO - loader.next - read idx:3, batches_outstanding:-1
# 2020-02-21 23:50:32,953 - root - INFO - loader.next - randomly handle batch 3
# 2020-02-21 23:50:32,953 - root - INFO - Start training batch 3
# 2020-02-21 23:50:32,961 - root - INFO - sync local
# 2020-02-21 23:50:32,963 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_UP, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 4
# 2020-02-21 23:50:32,963 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 Receive SYNC_UP round 100 group{'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0'}} changed? False
# 2020-02-21 23:50:32,963 - root - INFO - <JUN> before the allreduce call
# intput worker ptr is: 0x10027b3fb20
# eseAllReduce is called.
# allreduce size of data: 4104
# allreduce: syncInterval = 2 reduce Alpha = 0.5
# Before ddl allreduce
# after ddl allreduce
# UnformatedEseWorker allreduce done.
# 2020-02-21 23:50:32,982 - root - INFO - optmizer step local 300
# 2020-02-21 23:50:32,983 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: SYNC_DONE, sender worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0, global step 4
# 2020-02-21 23:50:32,986 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: STOP_WORKER, sender server-d41ff670-a042-4a8f-940f-6431682a716a, global step 0
# 2020-02-21 23:50:32,986 - root - INFO - stop heart beat
# 2020-02-21 23:50:32,986 - root - INFO - sync: stop worker!
# 2020-02-21 23:50:32,987 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0 end heart beat
# 2020-02-21 23:50:32,987 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy
# 2020-02-21 23:50:32,987 - root - INFO - worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0: action: update accuracy {'sender': 'worker-2f0cb92c-0ba0-4ad8-8a30-0a7d128d7ab8:0', 'global_step': 4, 'correction': tensor(39), 'count': 52, 'loss': -17781.22265625}
# Timestamp 1582325432989, Iteration 200
# batches :200 -17781.22265625
# Iteration 200: tag train_accuracy, simple_value 0.75
# Iteration 200: tag train_loss, simple_value -17781.22266
# 2020-02-21 23:50:32,989 - root - INFO - Batch 3 training finished
# 2020-02-21 23:50:32,989 - root - INFO - loader reset, batch_sample.is_final:True
# 2020-02-21 23:50:32,989 - root - INFO - <=== Epoch 49 End ==>
# 2020-02-21 23:50:34,640 - root - INFO - --------END TRAINING: completed iteration 200 --------
# 2020-02-21 23:50:34,640 - root - INFO - disconnect zmq
# 2020-02-21 23:50:34,641 - root - INFO - zmq closed
# 20/02/21 23:50:34 INFO PythonRunner: Times: total = 187206, boot = 451, init = 2570, finish = 184185
# 20/02/21 23:50:34 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1460 bytes result sent to driver
# 20/02/21 23:50:34 INFO Executor: [task] [finished] taskName:task 0.0 in stage 0.0 taskId:0 finishTime:1582325434652 duration:187264 state:TaskState.FINISHED resourceType:GPU
# 20/02/21 23:50:35 INFO EGOExecutorBackend: Driver commanded a shutdown
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.ExternalShuffle.shuffle-client.usedDirectMemory, value=-1
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.ExternalShuffle.shuffle-client.usedHeapMemory, value=16777216
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.largeRead_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.read_bytes, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.read_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.write_bytes, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.file.write_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.largeRead_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.read_bytes, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.read_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.write_bytes, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.filesystem.hdfs.write_ops, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.activeGpuTasks, value=0
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.completeGpuTasks, value=1
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.currentPool_size, value=1
# 20/02/21 23:50:35 INFO metrics: type=GAUGE, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.threadpool.maxPool_size, value=2147483647
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.fileCacheHits, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.filesDiscovered, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.hiveClientCalls, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.parallelListingJobCount, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.HiveExternalCatalog.partitionsFetched, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.bytesRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.bytesWritten, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.cpuTime, count=79834504
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.deserializeCpuTime, count=292662844
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.deserializeTime, count=406
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.diskBytesSpilled, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.jvmGCTime, count=183
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.memoryBytesSpilled, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.recordsRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.recordsWritten, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.resultSerializationTime, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.resultSize, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.runTime, count=187264
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleBytesWritten, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleFetchWaitTime, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleLocalBlocksFetched, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleLocalBytesRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRecordsRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRecordsWritten, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBlocksFetched, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBytesRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleRemoteBytesReadToDisk, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleTotalBytesRead, count=0
# 20/02/21 23:50:35 INFO metrics: type=COUNTER, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.executor.shuffleWriteTime, count=0
# 20/02/21 23:50:35 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.compilationTime, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:35 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.generatedClassSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:35 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.generatedMethodSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:35 INFO metrics: type=HISTOGRAM, name=app-20200221234718-0044-05dd8bd4-c7ff-4a65-9a5e-36f848afd322.0-ea6cdd44-67f6-4e84-bafd-0b7ae2577542.CodeGenerator.sourceCodeSize, count=0, min=0, max=0, mean=0.0, stddev=0.0, median=0.0, p75=0.0, p95=0.0, p98=0.0, p99=0.0, p999=0.0
# 20/02/21 23:50:35 INFO MemoryStore: MemoryStore cleared
# 20/02/21 23:50:35 INFO BlockManager: BlockManager stopped
# 20/02/21 23:50:35 INFO ShutdownHookManager: Shutdown hook called

# %% [markdown]
# ## Output

# %% [markdown]
# ## Further information and useful links
# [Back to top](#Contents)
