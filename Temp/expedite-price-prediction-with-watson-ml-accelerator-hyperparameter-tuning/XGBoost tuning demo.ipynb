# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

import json
import time
import urllib

system = 'colonia'

if system == 'colonia':
    hostname = 'colonia04'
    myauth = ('Admin','Admin')
    protocol = 'http'
    port = 9280
    sigName = 'dli-hpo'
    trainFile = '/dlidata/dataset/price_prediction/pp_train.dmatrix'
    valFile = '/dlidata/dataset/price_prediction/pp_val.dmatrix'
elif system == 'ma1gpu':
    hostname = 'ma1gpu03.ma.platformlab.ibm.com'
    myauth = ('username','password')
    protocol = 'https'
    port = 9243
    sigName = 'wml-ig'
    trainFile = '/ma1gpu01_nfsv4/martin/shared_fs_userdata/datasets/higgs/train/HIGGS_train.dmatrix'
    testFile = '/ma1gpu01_nfsv4/martin/shared_fs_userdata/datasets/higgs/test/HIGGS_test.dmatrix'
    valFile = '/ma1gpu01_nfsv4/martin/shared_fs_userdata/datasets/higgs/val/HIGGS_val.dmatrix'

commonHeaders={'accept': 'application/json'}

startTuneUrl='%s://%s:%d/platform/rest/deeplearning/v1/hypersearch' % (protocol, hostname, port)

req = requests.Session()

# %%
import tarfile
import tempfile
import os
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))


data =  {
        'modelSpec': 
        {
            'sigName': sigName,
            'args': '--exec-start XGboost --cs-datastore-meta type=fs \
                     --gpuPerWorker 1 --model-main main.py \
                     --model-dir xgb-model \
                     --trainFile %s \
                     --valFile %s' % (trainFile, valFile)
        },
'algoDef':
        {
            'algorithm': 'Random',
            'maxRunTime': 30,
            'maxJobNum': 100,
            'maxParalleJobNum': 4,
            'objectiveMetric' : 'mse_val',
            'objective' : 'minimize'
        },
        'hyperParams':
        [
             {
                 'name': 'learning_rate',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': -2,
                 'maxDbVal': 0,
                 'power': 10,
             },
             {
                 'name': 'num_rounds',
                 'type': 'Range',
                 'dataType': 'INT',
                 'minIntVal': 1,
                 'maxIntVal': 1000,
                 'step': 1,
             },
             {
                 'name': 'max_depth',
                 'type': 'Range',
                 'dataType': 'INT',
                 'minIntVal': 1,
                 'maxIntVal': 14,
                 'step': 1,
             },
             {
                 'name': 'lambda',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': -2,
                 'maxDbVal': 5,
                 'power': 10,
             },
             {
                 'name': 'colsample_bytree',
                 'type': 'Range',
                 'dataType': 'DOUBLE',
                 'minDbVal': 0.01,
                 'maxDbVal': 1.0,
                 'step': 0.01,
             },


         ]
    }

mydata={'data':json.dumps(data)}

MODEL_DIR_SUFFIX = ".modelDir.tar"
tempFile = tempfile.mktemp(MODEL_DIR_SUFFIX)
make_tarfile(tempFile, './xgb-model')
files = {'file': open(tempFile, 'rb')}
create = req.post(startTuneUrl, headers=commonHeaders, data=mydata, files=files, verify=False, auth=myauth)
if not create.ok:
   print('submit tune job failed: code=%s, %s'%(create.status_code, create.content))
else:
   print('submit tune job succeed with hponame: %s'%create.json())
# Out:
# submit tune job succeed with hponame: Admin-hpo-83966261958354

# %%
import time

hpoName = create.json()

getHpoUrl = '%s://%s:%d/platform/rest/deeplearning/v1/hypersearch/%s' % (protocol, hostname, port, hpoName)

res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=myauth)
if not res.ok:
    print('get hpo task failed: code=%s, %s'%(res.status_code, res.content))
else:
    json_out=res.json()

    while json_out['state'] in ['SUBMITTED','RUNNING']:
        print('Hpo task %s state %s progress %s%%'%(hpoName, json_out['state'], json_out['progress']))
        time.sleep(20)
        res = req.get(getHpoUrl, headers=commonHeaders, verify=False, auth=myauth)
        json_out=res.json()

    print('Hpo task %s completes with state %s'%(hpoName, json_out['state']))
    print(json.dumps(json_out, indent=4, sort_keys=True))
# Out:
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 0%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 4%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 8%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 12%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 12%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 12%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 12%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 16%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 20%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 20%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 20%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 20%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 20%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 24%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 28%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 32%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 32%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 32%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 32%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 36%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 36%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 36%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 36%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 36%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 40%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 40%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 40%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 40%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 44%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 48%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 48%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 48%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 48%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 52%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 56%
# Hpo task Admin-hpo-83966261958354 state RUNNING progress 56%
# Hpo task Admin-hpo-83966261958354 completes with state FINISHED
# {
#     "best": {
#         "appId": "Admin-84189701779622-1370733872",
#         "driverId": "driver-20191108160851-0342-bacfbcb3-ed76-4f70-92f5-65062f92d1cb",
#         "endTime": "2019-11-08 16:11:07",
#         "hyperParams": [
#             {
#                 "dataType": "double",
#                 "fixedVal": "0.9597590292372464",
#                 "name": "learning_rate",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "int",
#                 "fixedVal": "565",
#                 "name": "num_rounds",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "int",
#                 "fixedVal": "13",
#                 "name": "max_depth",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "double",
#                 "fixedVal": "1584.7191653582931",
#                 "name": "lambda",
#                 "userDefined": false
#             },
#             {
#                 "dataType": "double",
#                 "fixedVal": "0.47",
#                 "name": "colsample_bytree",
#                 "userDefined": false
#             }
#         ],
#         "id": 6,
#         "maxiteration": 0,
#         "metricVal": 1036.0960693359375,
#         "startTime": "2019-11-08 16:08:51",
#         "state": "FINISHED"
#     },
#     "complete": 60,
#     "createtime": "2019-11-08 16:05:07",
#     "creator": "Admin",
#     "duration": "00:30:24",
#     "experiments": [
#         {
#             "appId": "Admin-83968041893146-1410190338",
#             "driverId": "driver-20191108160510-0336-e3c772ed-bdb9-4422-89a5-d3d99cf42e58",
#             "endTime": "2019-11-08 16:06:35",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.6985298618593879",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "150",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "45228.17677047343",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.88",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 0,
#             "maxiteration": 0,
#             "metricVal": 1124.1365966796875,
#             "startTime": "2019-11-08 16:05:10",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-83974222760858-766214280",
#             "driverId": "driver-20191108160516-0337-dab4bfd7-be81-41c2-b61b-6f89a8ab28db",
#             "endTime": "2019-11-08 16:06:36",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5994721287420203",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "272",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "59106.84142945056",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.79",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 1,
#             "maxiteration": 0,
#             "metricVal": 1118.4549560546875,
#             "startTime": "2019-11-08 16:05:16",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-83980086307905-160968447",
#             "driverId": "driver-20191108160522-0338-e8905b2a-d32d-4352-8db6-335a1f5d2a82",
#             "endTime": "2019-11-08 16:06:36",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.6974897126117182",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "173",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "12",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "35660.074438220014",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.2",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 2,
#             "maxiteration": 0,
#             "metricVal": 1139.6383056640625,
#             "startTime": "2019-11-08 16:05:22",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-83986170636896-795470547",
#             "driverId": "driver-20191108160528-0339-d7eec154-1b86-475f-9f49-9ad9ac9a6e7f",
#             "endTime": "2019-11-08 16:08:37",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.

#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.986838084321535",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "805",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "5",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "32835.64397688097",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.9",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 52,
#             "maxiteration": 0,
#             "metricVal": 1073.1273193359375,
#             "startTime": "2019-11-08 16:32:35",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-85619321734922-10834777",
#             "driverId": "driver-20191108163241-0389-5eae9c9b-a436-4db4-8f66-e5d83927eb9b",
#             "endTime": "2019-11-08 16:35:02",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.23822646898987496",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "857",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "13",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "69359.58919385422",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.52",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 53,
#             "maxiteration": 0,
#             "metricVal": 1093.9312744140625,
#             "startTime": "2019-11-08 16:32:41",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-85625342050348-419472853",
#             "driverId": "driver-20191108163247-0390-c24a5afc-def8-44c7-b0d0-0992d7ddfcf6",
#             "endTime": "2019-11-08 16:34:02",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.12788625528307748",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "394",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "6",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "79597.9031315885",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.25",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 54,
#             "maxiteration": 0,
#             "metricVal": 1225.8934326171875,
#             "startTime": "2019-11-08 16:32:47",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-85631419634769-1700213097",
#             "driverId": "driver-20191108163253-0391-7d23283d-c294-4d55-bbe1-e75ad4518ddf",
#             "endTime": "2019-11-08 16:34:00",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.09398838779442388",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "630",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "8",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "88297.84783214537",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.38",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 55,
#             "maxiteration": 0,
#             "metricVal": 1189.3162841796875,
#             "startTime": "2019-11-08 16:32:53",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-85763231518188-1000162547",
#             "driverId": "driver-20191108163505-0392-7f899231-8831-4678-93e9-72c162da64d0",
#             "endTime": "2019-11-08 16:35:30",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.7841186907198179",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "215",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "2361.517652542393",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.02",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 56,
#             "maxiteration": 0,
#             "metricVal": 1405.728759765625,
#             "startTime": "2019-11-08 16:35:05",
#             "state": "FINISHED"
#         },
#         {
#             "appId": "Admin-85769253397149-1865179591",
#             "driverId": "driver-20191108163511-0393-cb874bc0-e85e-4fcf-84d4-20522d80c9d5",
#             "endTime": "2019-11-08 16:35:29",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.4774841509396769",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "813",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "12",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "9134.873165146102",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.57",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 57,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-11-08 16:35:11",
#             "state": "FAILED"
#         },
#         {
#             "appId": "Admin-85775151043227-1844813409",
#             "driverId": "driver-20191108163517-0394-175f9c59-665e-47f1-92ae-e8960d23eab5",
#             "endTime": "2019-11-08 16:35:28",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5213126930816911",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "115",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "5",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "99904.3565962359",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.2",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 58,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-11-08 16:35:17",
#             "state": "FAILED"
#         },
#         {
#             "appId": "Admin-85781179920978-1271163344",
#             "driverId": "driver-20191108163523-0395-64e6bc01-68ee-4465-89fb-a00760e1ffd9",
#             "endTime": "2019-11-08 16:35:31",
#             "hyperParams": [
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.5418887788143011",
#                     "name": "learning_rate",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "809",
#                     "name": "num_rounds",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "int",
#                     "fixedVal": "3",
#                     "name": "max_depth",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "44625.342392533275",
#                     "name": "lambda",
#                     "userDefined": false
#                 },
#                 {
#                     "dataType": "double",
#                     "fixedVal": "0.26",
#                     "name": "colsample_bytree",
#                     "userDefined": false
#                 }
#             ],
#             "id": 59,
#             "maxiteration": 0,
#             "metricVal": 9999.99,
#             "startTime": "2019-11-08 16:35:23",
#             "state": "FAILED"
#         }
#     ],
#     "failed": 3,
#     "hpoName": "Admin-hpo-83966261958354",
#     "progress": "60",
#     "running": 0,
#     "state": "FINISHED"
# }
